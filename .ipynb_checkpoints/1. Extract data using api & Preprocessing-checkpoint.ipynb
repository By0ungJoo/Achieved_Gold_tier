# %% [markdown]
# # 골드 티어 달성을 위한  League of Legend API 분석

# %% [markdown]
# #### 1. Riot Api 획득 및 적용
# + https://developer.riotgames.com/ 에서 api key 획득 가능

# %%
import requests
import json
import pandas as pd
import numpy as np
from time import sleep
import sys
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm
import time

# %% [markdown]
# ### 1. 닉네임 검색을 통한 정보 검색

# %% [markdown]
# #### https://developer.riotgames.com/app/517336/apis 참고

# %%
apiDefault = {
    'region': 'RGAPI-44052313-9ba2-4401-8e9b-e46f82ca3430',  # 한국서버
    'key': 'RGAPI-57b165cc-ecd7-4302-a1bd-4c3cd1eb801f',  # api key
    'summonerName': '뱀꼬치',  # 인게임 닉네임
}

# api 호출시 사용되는 url
url = "https://kr.api.riotgames.com/lol/summoner/v4/summoners/by-name/%EB%B1%80%EA%BC%AC%EC%B9%98?api_key=" + apiDefault['key']

# get method 를 통해 api 호출
r = requests.get(url)

r.json()
# Out:
# {'id': 'zCg-Fo_0oVscbgtb1g-B_A5e6M-bPgl286uskb12th5TwQ',
#  'accountId': 'uKu9_3GADEi9gSVwUPYi4aA5bZRhMSMAgTRTSsLx5oYt',
#  'puuid': 'VsaPcKfnhHhusZcXkYwSsNahibTH5HLnMJsnB1voKG0tH5OC03i_j2cMsaBj3d3ha5HAAxtALQ7yPw',
#  'name': '뱀꼬치',
#  'profileIconId': 4573,
#  'revisionDate': 1626709186521,
#  'summonerLevel': 374}

# %% [markdown]
# ### 2. 현재 계정 리그 정보 호출

# %%
url = 'https://kr.api.riotgames.com/lol/league/v4/entries/by-summoner/zCg-Fo_0oVscbgtb1g-B_A5e6M-bPgl286uskb12th5TwQ?api_key=' + apiDefault['key']
r = requests.get(url)

# 솔로랭크 정보만 추출하여 Dict형으로 저장 
info_data = r.json()[1]

# # DataFrame으로 변환
info_data = pd.Series(info_data, index = info_data.keys())
info_data = pd.DataFrame(info_data).T

# # 필요없는 행 삭제
info_data.drop(['leagueId', 'summonerId', 'veteran', 'inactive', 'freshBlood', 'hotStreak'], axis = 1, inplace = True)

# # 승률 컬럼 추가 
info_data['win_rate(%)'] = (info_data['wins'] / (info_data['wins'] + info_data['losses'])) *100

info_data
# Out:
#          queueType    tier rank summonerName leaguePoints wins losses  \
# 0  RANKED_SOLO_5x5  SILVER  III          뱀꼬치           16  343    361
#
#   win_rate(%)
# 0     48.7216

# %%
# 승, 패 int로 수정 
info_data['wins'] = int(info_data['wins']) 
info_data['wins']
info_data['losses'] = int(info_data['losses'])
info_data['losses']
# Out:
# 0    361
# Name: losses, dtype: int64

# %%
# info_data로 확인한 결과 13시즌 총 진행 판수 704판 진행 확인 game_data로 gameId 및 기타 내용 저장
url = ['https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/uKu9_3GADEi9gSVwUPYi4aA5bZRhMSMAgTRTSsLx5oYt?queue=420&season=13&api_key=' + apiDefault['key'],
       'https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/uKu9_3GADEi9gSVwUPYi4aA5bZRhMSMAgTRTSsLx5oYt?queue=420&season=13&beginIndex=101&api_key=' + apiDefault['key'], 
       'https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/uKu9_3GADEi9gSVwUPYi4aA5bZRhMSMAgTRTSsLx5oYt?queue=420&season=13&beginIndex=201&api_key=' + apiDefault['key'], 
       'https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/uKu9_3GADEi9gSVwUPYi4aA5bZRhMSMAgTRTSsLx5oYt?queue=420&season=13&beginIndex=301&api_key=' + apiDefault['key'], 
       'https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/uKu9_3GADEi9gSVwUPYi4aA5bZRhMSMAgTRTSsLx5oYt?queue=420&season=13&beginIndex=401&api_key=' + apiDefault['key'], 
       'https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/uKu9_3GADEi9gSVwUPYi4aA5bZRhMSMAgTRTSsLx5oYt?queue=420&season=13&beginIndex=501&api_key=' + apiDefault['key'], 
       'https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/uKu9_3GADEi9gSVwUPYi4aA5bZRhMSMAgTRTSsLx5oYt?queue=420&season=13&beginIndex=601&api_key=' + apiDefault['key']] 

url_list = []
for i in range(len(url)):
    r = requests.get(url[i])
    url_list.append(r.json())

# %%
pre = []
for i in range(len(url_list)):
    pre.append(url_list[i])

a = pre[0]['matches'] + pre[1]['matches'] + pre[2]['matches'] + pre[3]['matches'] + pre[4]['matches'] + pre[5]['matches'] +pre[6]['matches']
game_data = pd.DataFrame(a)

pd.options.display.max_rows = 700
game_data
# Out:
#     platformId      gameId  champion  queue  season      timestamp  \
# 0           KR  5334404274        35    420      13  1626673994082
# 1           KR  5334242624        56    420      13  1626663114292
# 2           KR  5333610758       235    420      13  1626621083921
# 3           KR  5333454235        81    420      13  1626618959831
# 4           KR  5332976006       887    420      13  1626606146954
# 5           KR  5332961992        82    420      13  1626604901684
# 6           KR  5332521087       517    420      13  1626592689153
# 7           KR  5331486384        35    420      13  1626543060469
# 8           KR  5331413637       131    420      13  1626541188392
# 9           KR  5331308088        78    420      13  1626538972771
# 10          KR  5331370333       202    420      13  1626536792846
# 11          KR  5331253212       145    420      13  1626534643704
# 12          KR  5331116012        96    420      13  1626532492394
# 13          KR  5330998829        18    420      13  1626530658031
# 14          KR  5330658751        61    420      13  1626527784340
# 15          KR  5325909418        19    420      13  1626344759137
# 16          KR  5325869354        18    420      13  1626340217966
# 17          KR  5325801969       412    420      13  1626336678664
# 18          KR  5324063905       517    420      13  1626264211833
# 19          KR  5323601571       136    420      13  1626246974544
# 20          KR  5323443080       163    420      13  1626238676903
# 21          KR  5321690587       163    420      13  1626169479609
# 22          KR  5319918929        78    420      13  1626086895473
# 23          KR  5318870398        18    420      13  1626021921870
# 24          KR  5318707028        35    420      13  1626019448579
# 25          KR  5318761641        67    420      13  1626017519027
# 26          KR  5318645133        51    420      13  1626014931124
# 27          KR  5318185394        56    420      13  1626004913511
# 28          KR  5316167041        35    420      13  1625932768917
# 29          KR  5315833362        56    420      13  1625924290233
# 30          KR  5315742240        78    420      13  1625921664506
# 31          KR  5312656919       145    420      13  1625823935749
# 32          KR  5312603372        78    420      13  1625822304008
# 33          KR  5311642689        78    420      13  1625758019038
# 34          KR  5310390107        51    420      13  1625720723858
# 35          KR  5309733206       136    420      13  1625678307902
# 36          KR  5309720773        35    420      13  1625676344170
# 37          KR  5309636131       517    420      13  1625674092703
# 38          KR  5309358337        36    420      13  1625664717127
# 39          KR  5308268781        78    420      13  1625632528706
# 40          KR  5308264634        78    420      13  1625629392539
# 41          KR  5306723375        56    420      13  1625556995181
# 42          KR  5305064441        35    420      13  1625482126360
# 43          KR  5304869075        35    420      13  1625480085572
# 44          KR  5303441970       222    420      13  1625403010539
# 45          KR  5303295587        81    420      13  1625401018737
# 46          KR  5303227392       236    420      13  1625399141932
# 47          KR  5303016963        67    420      13  1625393015378
# 48          KR  5302972940       145    420      13  1625389115882
# 49          KR  5302868167        78    420      13  1625387608424
# 50          KR  5301494153       517    420      13  1625328037513
# 51          KR  5301388471        78    420      13  1625324341270
# 52          KR  5298736404        78    420      13  1625237144177
# 53          KR  5296206585        56    420      13  1625139889763
# 54          KR  5295608169        51    420      13  1625127770818
# 55          KR  5295673821       234    420      13  1625126120620
# 56          KR  5294514931        35    420      13  1625059911334
# 57          KR  5294325726        78    420      13  1625057224310
# 58          KR  5292015123        35    420      13  1624960693573
# 59          KR  5292031658        35    420      13  1624959411432
# 60          KR  5291927489        78    420      13  1624957107944
# 61          KR  5291900877        78    420      13  1624953817544
# 62          KR  5291815754        78    420      13  1624951471840
# 63          KR  5290542363        56    420      13  1624882393325
# 64          KR  5290484888        56    420      13  1624880115485
# 65          KR  5290328364        35    420      13  1624877412129
# 66          KR  5290372115        81    420      13  1624875117187
# 67          KR  5290237856        18    420      13  1624873039752
# 68          KR  5290240401       131    420      13  1624869667845
# 69          KR  5290174059        35    420      13  1624866766341
# 70          KR  5288813772       107    420      13  1624797775324
# 71          KR  5288733033        56    420      13  1624795028832
# 72          KR  5288673391       101    420      13  1624792265503
# 73          KR  5288578035        17    420      13  1624790548785
# 74          KR  5288512866        56    420      13  1624788710869
# 75          KR  5288466508       412    420      13  1624786788984
# 76          KR  5288344388        78    420      13  1624782599172
# 77          KR  5288238728        89    420      13  1624780793716
# 78          KR  5283682965        78    420      13  1624610344649
# 79          KR  5283357057        78    420      13  1624607822779
# 80          KR  5283095936        35    420      13  1624596968264
# 81          KR  5281761307       145    420      13  1624525432142
# 82          KR  5281604463        78    420      13  1624521572168
# 83          KR  5281578092        67    420      13  1624518748912
# 84          KR  5281531603        81    420      13  1624515152100
# 85          KR  5281398676        18    420      13  1624513270574
# 86          KR  5281395387        51    420      13  1624511336143
# 87          KR  5281411718        35    420      13  1624509001156
# 88          KR  5281354502        35    420      13  1624503586947
# 89          KR  5280878910        81    420      13  1624459554310
# 90          KR  5280737060        78    420      13  1624455907977
# 91          KR  5280378045        78    420      13  1624453300874
# 92          KR  5279468395        78    420      13  1624414084001
# 93          KR  5279477201        78    420      13  1624412800471
# 94          KR  5278498716        78    420      13  1624370445420
# 95          KR  5278461550        78    420      13  1624368182083
# 96          KR  5278343452        78    420      13  1624365811585
# 97          KR  5278246436        78    420      13  1624363608619
# 98          KR  5276556167       234    420      13  1624277668782
# 99          KR  5276418802        78    420      13  1624275040205
# 100         KR  5276176026        78    420      13  1624260500308
# 101         KR  5276037434        35    420      13  1624256070472
# 102         KR  5275954457        60    420      13  1624253674524
# 103         KR  5275717120        78    420      13  1624248603733
# 104         KR  5275681596        78    420      13  1624243842745
# 105         KR  5275573683        35    420      13  1624236092205
# 106         KR  5269144868        35    420      13  1623997475687
# 107         KR  5268805724       517    420      13  1623991701512
# 108         KR  5268861597       517    420      13  1623989178132
# 109         KR  5266965446        60    420      13  1623905461272
# 110         KR  5266913609       517    420      13  1623903279167
# 111         KR  5266748798        89    420      13  1623890558055
# 112         KR  5266360578       517    420      13  1623851463280
# 113         KR  5266215004       517    420      13  1623849675759
# 114         KR  5266148379        78    420      13  1623848102730
# 115         KR  5266032110        60    420      13  1623845536800
# 116         KR  5265521306        78    420      13  1623833215601
# 117         KR  5264738948        78    420      13  1623771919132
# 118         KR  5264685495        78    420      13  1623770188954
# 119         KR  5264586171        78    420      13  1623767442821
# 120         KR  5264006565        78    420      13  1623758349656
# 121         KR  5263909727        19    420      13  1623755987412
# 122         KR  5263674780        19    420      13  1623740965324
# 123         KR  5262266167       517    420      13  1623669113133
# 124         KR  5262202426       517    420      13  1623667212211
# 125         KR  5262175708        19    420      13  1623664841394
# 126         KR  5260882997        78    420      13  1623591392120
# 127         KR  5260736856        60    420      13  1623589584573
# 128         KR  5259720407       106    420      13  1623566406234
# 129         KR  5259652946         5    420      13  1623564157496
# 130         KR  5259586065        60    420      13  1623561915226
# 131         KR  5259550107        78    420      13  1623559592138
# 132         KR  5259482243         5    420      13  1623556319552
# 133         KR  5256407216        60    420      13  1623432491745
# 134         KR  5256490059        60    420      13  1623430101053
# 135         KR  5254809656        60    420      13  1623386941417
# 136         KR  5253899246        60    420      13  1623332085115
# 137         KR  5253723442        56    420      13  1623327355589
# 138         KR  5253099322        78    420      13  1623313085465
# 139         KR  5252866810        60    420      13  1623300547141
# 140         KR  5252426086        18    420      13  1623254206959
# 141         KR  5252461747        78    420      13  1623252485202
# 142         KR  5252343532        75    420      13  1623249500460
# 143         KR  5252226113       875    420      13  1623247152665
# 144         KR  5251965140        78    420      13  1623243458549
# 145         KR  5251980071        35    420      13  1623241851677
# 146         KR  5249841542        35    420      13  1623152056550
# 147         KR  5249486952        19    420      13  1623141388223
# 148         KR  5249424433        78    420      13  1623139349570
# 149         KR  5249023962        19    420      13  1623127314796
# 150         KR  5248091627        78    420      13  1623067882724
# 151         KR  5247974630        78    420      13  1623066226728
# 152         KR  5247517164        25    420      13  1623053328579
# 153         KR  5247502875        35    420      13  1623050778013
# 154         KR  5247335511        24    420      13  1623041484845
# 155         KR  5247285178        18    420      13  1623039848996
# 156         KR  5246679882        35    420      13  1622994097273
# 157         KR  5246474959        81    420      13  1622989010605
# 158         KR  5246304819       145    420      13  1622985817253
# 159         KR  5244322194        67    420      13  1622906927004
# 160         KR  5243929920        78    420      13  1622903868670
# 161         KR  5243718094         5    420      13  1622900785528
# 162         KR  5243605318        24    420      13  1622897562418
# 163         KR  5243060131        78    420      13  1622879642867
# 164         KR  5242840809        81    420      13  1622876593258
# 165         KR  5242409038       222    420      13  1622868645347
# 166         KR  5242441654       875    420      13  1622865728106
# 167         KR  5242356733       235    420      13  1622863203074
# 168         KR  5242323770       235    420      13  1622860898072
# 169         KR  5241260755       235    420      13  1622812909343
# 170         KR  5241103766       235    420      13  1622810708974
# 171         KR  5240826901        81    420      13  1622801487666
# 172         KR  5240802555        67    420      13  1622799197495
# 173         KR  5240736674        18    420      13  1622797041778
# 174         KR  5240615849        81    420      13  1622791677482
# 175         KR  5239390609       235    420      13  1622725593578
# 176         KR  5239226957       235    420      13  1622722423630
# 177         KR  5238909484        81    420      13  1622719737537
# 178         KR  5238643297        81    420      13  1622709350081
# 179         KR  5238559181       145    420      13  1622707423727
# 180         KR  5237579187        81    420      13  1622646586749
# 181         KR  5237542707        81    420      13  1622644220635
# 182         KR  5237483571       145    420      13  1622642010271
# 183         KR  5237226676        18    420      13  1622636775658
# 184         KR  5237048888        81    420      13  1622630789951
# 185         KR  5236943379        78    420      13  1622623695554
# 186         KR  5236825182        51    420      13  1622619395407
# 187         KR  5235564679        78    420      13  1622550745163
# 188         KR  5235348342        78    420      13  1622548305448
# 189         KR  5235440446       222    420      13  1622546174767
# 190         KR  5234833514        78    420      13  1622533410848
# 191         KR  5234820566        78    420      13  1622531677243
# 192         KR  5234429119        78    420      13  1622509517442
# 193         KR  5234016659        78    420      13  1622473722109
# 194         KR  5233767812       875    420      13  1622470710709
# 195         KR  5233155133        67    420      13  1622448165703
# 196         KR  5232227652        81    420      13  1622392893514
# 197         KR  5232203827        67    420      13  1622390846039
# 198         KR  5230692646        19    420      13  1622355765817
# 199         KR  5230598104       875    420      13  1622354284239
# 200         KR  5230632583        24    420      13  1622352615366
# 201         KR  5230574136        51    420      13  1622349742612
# 202         KR  5230510929        81    420      13  1622348081884
# 203         KR  5229806311        81    420      13  1622308873380
# 204         KR  5229692667        18    420      13  1622307043739
# 205         KR  5229329897        51    420      13  1622298448622
# 206         KR  5229254170        35    420      13  1622294941145
# 207         KR  5229083677        24    420      13  1622292185856
# 208         KR  5227090879        24    420      13  1622220756884
# 209         KR  5227004253        24    420      13  1622218659312
# 210         KR  5226947518        24    420      13  1622216883532
# 211         KR  5226624800        51    420      13  1622209153631
# 212         KR  5226652192        81    420      13  1622208654140
# 213         KR  5226531384       106    420      13  1622206010980
# 214         KR  5226399535        78    420      13  1622205480845
# 215         KR  5226441081       101    420      13  1622203257921
# 216         KR  5225921617        24    420      13  1622196288905
# 217         KR  5225844803        67    420      13  1622193496597
# 218         KR  5225870428        24    420      13  1622191627722
# 219         KR  5225639297        24    420      13  1622186674046
# 220         KR  5225324103        81    420      13  1622164730657
# 221         KR  5224424543        18    420      13  1622120928298
# 222         KR  5224368964       222    420      13  1622119371818
# 223         KR  5224322808        51    420      13  1622117452686
# 224         KR  5220376709        18    420      13  1621946392234
# 225         KR  5220242799        18    420      13  1621941664726
# 226         KR  5220174957        51    420      13  1621938618796
# 227         KR  5220060046       875    420      13  1621931076028
# 228         KR  5219992946        51    420      13  1621927612016
# 229         KR  5219728822        82    420      13  1621924752561
# 230         KR  5218678315        51    420      13  1621859250923
# 231         KR  5218632033        35    420      13  1621856964939
# 232         KR  5218495971        67    420      13  1621855251274
# 233         KR  5218432272       222    420      13  1621853371594
# 234         KR  5218096456        35    420      13  1621845614290
# 235         KR  5217978329        78    420      13  1621841317588
# 236         KR  5217990537       235    420      13  1621837066797
# 237         KR  5216850102        51    420      13  1621774606189
# 238         KR  5215524306        35    420      13  1621740702156
# 239         KR  5209481292        51    420      13  1621509613505
# 240         KR  5209212552       875    420      13  1621496695820
# 241         KR  5209108129        18    420      13  1621494438023
# 242         KR  5209134314        98    420      13  1621492615945
# 243         KR  5209041258       875    420      13  1621490462114
# 244         KR  5209016600        25    420      13  1621487862805
# 245         KR  5207972427       875    420      13  1621430660813
# 246         KR  5207950615       875    420      13  1621430189436
# 247         KR  5207862798        98    420      13  1621428105162
# 248         KR  5207832493        35    420      13  1621425514726
# 249         KR  5207585159       106    420      13  1621420171779
# 250         KR  5207610261        78    420      13  1621418580451
# 251         KR  5207226437        35    420      13  1621417263821
# 252         KR  5204847420        35    420      13  1621341127600
# 253         KR  5204797174        25    420      13  1621338323100
# 254         KR  5204547059        35    420      13  1621330070978
# 255         KR  5204540195        25    420      13  1621326862371
# 256         KR  5204358380        25    420      13  1621326173151
# 257         KR  5203994197        35    420      13  1621313422574
# 258         KR  5203539347        51    420      13  1621266757835
# 259         KR  5203316412        35    420      13  1621261933391
# 260         KR  5202831839        35    420      13  1621252331799
# 261         KR  5202655614        35    420      13  1621250236689
# 262         KR  5202720145       106    420      13  1621248349556
# 263         KR  5202611069       235    420      13  1621244562530
# 264         KR  5202481970        18    420      13  1621240399838
# 265         KR  5202104252        18    420      13  1621225974626
# 266         KR  5201511563        18    420      13  1621180237873
# 267         KR  5201234475       145    420      13  1621171973335
# 268         KR  5201044519        18    420      13  1621169460245
# 269         KR  5200229532       106    420      13  1621155152380
# 270         KR  5200142661       222    420      13  1621153134174
# 271         KR  5200105687       141    420      13  1621151454023
# 272         KR  5199998206        78    420      13  1621149497979
# 273         KR  5199780269        18    420      13  1621141415125
# 274         KR  5196300540        86    420      13  1621011530949
# 275         KR  5195502370       234    420      13  1620998461299
# 276         KR  5195253408       222    420      13  1620992975812
# 277         KR  5195060239        67    420      13  1620983685573
# 278         KR  5194844578        51    420      13  1620981199670
# 279         KR  5193130006        67    420      13  1620900611739
# 280         KR  5193027406        67    420      13  1620899309617
# 281         KR  5192972856       235    420      13  1620896909839
# 282         KR  5192513079        77    420      13  1620881115421
# 283         KR  5192339598        67    420      13  1620878953268
# 284         KR  5192277613        67    420      13  1620877042975
# 285         KR  5191589709       222    420      13  1620824871341
# 286         KR  5191590015        67    420      13  1620822081867
# 287         KR  5191046700       222    420      13  1620817403334
# 288         KR  5189193208       106    420      13  1620729858849
# 289         KR  5189026806        82    420      13  1620727143445
# 290         KR  5189071790       145    420      13  1620725661782
# 291         KR  5189030265       145    420      13  1620723964499
# 292         KR  5188922532        81    420      13  1620720494419
# 293         KR  5188819161        78    420      13  1620718550321
# 294         KR  5188775169        51    420      13  1620716192953
# 295         KR  5188743598        98    420      13  1620714667017
# 296         KR  5188689176       235    420      13  1620712868338
# 297         KR  5187313317        81    420      13  1620639798143
# 298         KR  5187179118       235    420      13  1620637843960
# 299         KR  5187115243       235    420      13  1620635247337
# 300         KR  5187031512       235    420      13  1620628976761
# 301         KR  5186285636       235    420      13  1620579680448
# 302         KR  5186291324       235    420      13  1620577408644
# 303         KR  5186207647        51    420      13  1620575840983
# 304         KR  5186066513        51    420      13  1620571415385
# 305         KR  5183505519       429    420      13  1620484774356
# 306         KR  5183306815        81    420      13  1620482518647
# 307         KR  5182560043        51    420      13  1620465909997
# 308         KR  5181284235       222    420      13  1620407010943
# 309         KR  5181206531        51    420      13  1620404515836
# 310         KR  5180394060        51    420      13  1620391236665
# 311         KR  5180163544        16    420      13  1620384644626
# 312         KR  5180095040       235    420      13  1620381285579
# 313         KR  5178256895       106    420      13  1620303869359
# 314         KR  5178230352       429    420      13  1620301736723
# 315         KR  5178003398        51    420      13  1620295802601
# 316         KR  5177879580       222    420      13  1620293742907
# 317         KR  5177592466        51    420      13  1620276013831
# 318         KR  5176452361        25    420      13  1620220297811
# 319         KR  5173414734        81    420      13  1620133402043
# 320         KR  5173275850       887    420      13  1620131115757
# 321         KR  5173157741       222    420      13  1620128924844
# 322         KR  5173048443        51    420      13  1620126209881
# 323         KR  5173033465        77    420      13  1620121751993
# 324         KR  5172900366       235    420      13  1620116180401
# 325         KR  5172216161        25    420      13  1620101130412
# 326         KR  5172232395       141    420      13  1620099693014
# 327         KR  5172068500        78    420      13  1620096455677
# 328         KR  5170788909        35    420      13  1620038733361
# 329         KR  5170618890        77    420      13  1620030757831
# 330         KR  5170614154       876    420      13  1620028691792
# 331         KR  5170181206       141    420      13  1620018067414
# 332         KR  5170027339        78    420      13  1620016028588
# 333         KR  5169625995        78    420      13  1619972685825
# 334         KR  5169620967       876    420      13  1619970576221
# 335         KR  5167060415        78    420      13  1619889897783
# 336         KR  5166943359        77    420      13  1619887313425
# 337         KR  5166859274        78    420      13  1619886054302
# 338         KR  5165808039        77    420      13  1619866620956
# 339         KR  5165800874        78    420      13  1619864424336
# 340         KR  5165655019        35    420      13  1619862458612
# 341         KR  5165398707        77    420      13  1619860576270
# 342         KR  5165442647       141    420      13  1619858890467
# 343         KR  5165222918        25    420      13  1619856260321
# 344         KR  5165074090        81    420      13  1619853627179
# 345         KR  5162489845       222    420      13  1619773049786
# 346         KR  5161808811        90    420      13  1619757295953
# 347         KR  5160505967        86    420      13  1619696286586
# 348         KR  5160406062        81    420      13  1619692902024
# 349         KR  5160340109        75    420      13  1619690434638
# 350         KR  5160253382        35    420      13  1619687812891
# 351         KR  5159626889       429    420      13  1619672153771
# 352         KR  5159507224       145    420      13  1619666501188
# 353         KR  5159494276        35    420      13  1619664282226
# 354         KR  5159452940       141    420      13  1619663097576
# 355         KR  5159491511        35    420      13  1619662086192
# 356         KR  5159349533        25    420      13  1619660035953
# 357         KR  5157067945       141    420      13  1619544139031
# 358         KR  5157074857        75    420      13  1619542209031
# 359         KR  5157130848       429    420      13  1619540393770
# 360         KR  5155070102        35    420      13  1619451777836
# 361         KR  5155014945       141    420      13  1619449847037
# 362         KR  5154679266       429    420      13  1619441389071
# 363         KR  5154722178        35    420      13  1619439292265
# 364         KR  5154595434       141    420      13  1619436929167
# 365         KR  5154495243       145    420      13  1619432814869
# 366         KR  5154199216        35    420      13  1619429624868
# 367         KR  5154253972       222    420      13  1619427188486
# 368         KR  5154210897       141    420      13  1619425494811
# 369         KR  5153768618       141    420      13  1619412351040
# 370         KR  5153455949       141    420      13  1619368636712
# 371         KR  5153502835        81    420      13  1619367305488
# 372         KR  5153438637        81    420      13  1619365424769
# 373         KR  5153425294        35    420      13  1619363795855
# 374         KR  5153261282       141    420      13  1619358990028
# 375         KR  5152148121        67    420      13  1619334973852
# 376         KR  5152212250        35    420      13  1619333201332
# 377         KR  5152096937        35    420      13  1619331331288
# 378         KR  5152051952        82    420      13  1619329244059
# 379         KR  5151835267        35    420      13  1619326568118
# 380         KR  5150749174         5    420      13  1619271785436
# 381         KR  5147764501       107    420      13  1619171646325
# 382         KR  5147735074         5    420      13  1619167244852
# 383         KR  5147361829        35    420      13  1619147983805
# 384         KR  5147119554        35    420      13  1619146077076
# 385         KR  5146511748        90    420      13  1619097541911
# 386         KR  5146374668        35    420      13  1619095340753
# 387         KR  5146247336         5    420      13  1619092843381
# 388         KR  5146240277         5    420      13  1619090281296
# 389         KR  5146203093        35    420      13  1619087388778
# 390         KR  5146078930        86    420      13  1619085255326
# 391         KR  5146053720        75    420      13  1619082409969
# 392         KR  5145819150       887    420      13  1619080068868
# 393         KR  5145773685        81    420      13  1619077018865
# 394         KR  5145593390        67    420      13  1619071234873
# 395         KR  5145581366        67    420      13  1619069931398
# 396         KR  5145423246       429    420      13  1619054888886
# 397         KR  5145164678        82    420      13  1619023879901
# 398         KR  5145141639       429    420      13  1619021914908
# 399         KR  5145078010       887    420      13  1619020046481
# 400         KR  5144559568       429    420      13  1619009948288
# 401         KR  5144363862       887    420      13  1619004561675
# 402         KR  5144317617       429    420      13  1619002112637
# 403         KR  5144273966       516    420      13  1619000316618
# 404         KR  5144260146        36    420      13  1618998256869
# 405         KR  5144176132       887    420      13  1618996095565
# 406         KR  5144115893       887    420      13  1618990685878
# 407         KR  5144122989       235    420      13  1618989194078
# 408         KR  5144005280       887    420      13  1618984823510
# 409         KR  5143156644        81    420      13  1618935328846
# 410         KR  5142273146       887    420      13  1618903839152
# 411         KR  5141965163       887    420      13  1618892599358
# 412         KR  5141548175       429    420      13  1618846295385
# 413         KR  5141575641       887    420      13  1618845290114
# 414         KR  5141191813       516    420      13  1618836681906
# 415         KR  5140918169        51    420      13  1618832814697
# 416         KR  5140903851        81    420      13  1618830864293
# 417         KR  5140718203        35    420      13  1618827571285
# 418         KR  5140714847        35    420      13  1618825841363
# 419         KR  5140617088       145    420      13  1618821543988
# 420         KR  5139805990        25    420      13  1618762101950
# 421         KR  5139663297        25    420      13  1618756485246
# 422         KR  5139598148        25    420      13  1618754986193
# 423         KR  5139514494        78    420      13  1618753508337
# 424         KR  5139453511        78    420      13  1618750549396
# 425         KR  5139366925        78    420      13  1618748753881
# 426         KR  5136281812        78    420      13  1618647782803
# 427         KR  5135935133       429    420      13  1618637725811
# 428         KR  5135933501       235    420      13  1618637048679
# 429         KR  5135940326       235    420      13  1618635723259
# 430         KR  5133223486        18    420      13  1618537515221
# 431         KR  5133251698        81    420      13  1618535988250
# 432         KR  5132916687       516    420      13  1618502455784
# 433         KR  5132677472         5    420      13  1618498690634
# 434         KR  5132081366        78    420      13  1618477410814
# 435         KR  5131928105        78    420      13  1618475453579
# 436         KR  5131594217       429    420      13  1618460767589
# 437         KR  5130819005        82    420      13  1618407794528
# 438         KR  5130891478        56    420      13  1618405451101
# 439         KR  5130735324       429    420      13  1618403346030
# 440         KR  5130679924       429    420      13  1618401537206
# 441         KR  5130191367       429    420      13  1618388279787
# 442         KR  5129608543       429    420      13  1618366379872
# 443         KR  5129605625        81    420      13  1618363463524
# 444         KR  5129013360        82    420      13  1618322186153
# 445         KR  5128992000       429    420      13  1618319586111
# 446         KR  5128836327       234    420      13  1618317195830
# 447         KR  5127997886       429    420      13  1618288154873
# 448         KR  5126750818        81    420      13  1618220971248
# 449         KR  5126619253       429    420      13  1618219329472
# 450         KR  5126663134       429    420      13  1618217280596
# 451         KR  5126486480        81    420      13  1618208422846
# 452         KR  5126288704        82    420      13  1618201812450
# 453         KR  5126343871        83    420      13  1618199360721
# 454         KR  5126283204       133    420      13  1618197458935
# 455         KR  5125747183        90    420      13  1618159397914
# 456         KR  5125713196        81    420      13  1618156882435
# 457         KR  5123203388        81    420      13  1618064849954
# 458         KR  5123064914        81    420      13  1618062540350
# 459         KR  5121921189        11    420      13  1618033439007
# 460         KR  5120237051        56    420      13  1617962242282
# 461         KR  5120291674        35    420      13  1617960521430
# 462         KR  5120099131        82    420      13  1617957826228
# 463         KR  5120133563        81    420      13  1617955559163
# 464         KR  5120057241        81    420      13  1617953261378
# 465         KR  5120033987        81    420      13  1617951161947
# 466         KR  5119176378       145    420      13  1617894818956
# 467         KR  5119131338       145    420      13  1617892660705
# 468         KR  5118041387        81    420      13  1617858506618
# 469         KR  5116949590        81    420      13  1617800171496
# 470         KR  5116952950        81    420      13  1617798205594
# 471         KR  5116896668        81    420      13  1617796515941
# 472         KR  5115977257        51    420      13  1617765057613
# 473         KR  5115945312       516    420      13  1617763029867
# 474         KR  5115942511        90    420      13  1617760500919
# 475         KR  5115911083        35    420      13  1617758023777
# 476         KR  5115848909       106    420      13  1617756654157
# 477         KR  5114386437        35    420      13  1617680185176
# 478         KR  5114325532        35    420      13  1617678419739
# 479         KR  5114238223        56    420      13  1617671725457
# 480         KR  5114285506        81    420      13  1617669502173
# 481         KR  5113982427        81    420      13  1617637279946
# 482         KR  5113289764        67    420      13  1617623779681
# 483         KR  5112895925       350    420      13  1617603463301
# 484         KR  5112785778        81    420      13  1617602071128
# 485         KR  5112665041        81    420      13  1617596229503
# 486         KR  5112662188       235    420      13  1617594061960
# 487         KR  5112560178        51    420      13  1617591447677
# 488         KR  5112319747        51    420      13  1617590230389
# 489         KR  5112048114        54    420      13  1617551875024
# 490         KR  5108013937        81    420      13  1617433742682
# 491         KR  5108060347       235    420      13  1617432939811
# 492         KR  5107914653        75    420      13  1617430946338
# 493         KR  5107876163        81    420      13  1617428593999
# 494         KR  5106831088        51    420      13  1617378031117
# 495         KR  5106542890       145    420      13  1617371099154
# 496         KR  5106333187       145    420      13  1617366049700
# 497         KR  5105866860       235    420      13  1617361181715
# 498         KR  5105872597        81    420      13  1617359557234
# 499         KR  5105374236        25    420      13  1617336354105
# 500         KR  5105360010       235    420      13  1617333254364
# 501         KR  5105277427        75    420      13  1617331366398
# 502         KR  5105235920        98    420      13  1617329776516
# 503         KR  5105273206       235    420      13  1617327743811
# 504         KR  5104382134        81    420      13  1617280863598
# 505         KR  5104297112        81    420      13  1617279290159
# 506         KR  5104220701        56    420      13  1617276649095
# 507         KR  5104059064        74    420      13  1617271440897
# 508         KR  5104094200       235    420      13  1617268796452
# 509         KR  5103796399        51    420      13  1617258386083
# 510         KR  5102337698        51    420      13  1617191381270
# 511         KR  5102381973       235    420      13  1617189329626
# 512         KR  5102108126        75    420      13  1617182371826
# 513         KR  5102103765        83    420      13  1617179953422
# 514         KR  5102031738        51    420      13  1617173701536
# 515         KR  5101968896        67    420      13  1617172204533
# 516         KR  5101858975       145    420      13  1617165772918
# 517         KR  5101188356        54    420      13  1617121529740
# 518         KR  5100481096       145    420      13  1617100821818
# 519         KR  5100266442        81    420      13  1617098370776
# 520         KR  5099923893        58    420      13  1617079017648
# 521         KR  5099887202        81    420      13  1617074415895
# 522         KR  5099000170        81    420      13  1617023741383
# 523         KR  5097683012        56    420      13  1616946398362
# 524         KR  5097587491        83    420      13  1616944170237
# 525         KR  5097543573       235    420      13  1616942550446
# 526         KR  5097333118        54    420      13  1616936830506
# 527         KR  5095146119       145    420      13  1616859935914
# 528         KR  5094477200        83    420      13  1616850316933
# 529         KR  5094278005        56    420      13  1616845455374
# 530         KR  5094173124        82    420      13  1616840992028
# 531         KR  5094007492        81    420      13  1616838741028
# 532         KR  5092386687        67    420      13  1616773553514
# 533         KR  5092165698       145    420      13  1616768011179
# 534         KR  5089895817        75    420      13  1616671662852
# 535         KR  5089890399        83    420      13  1616669328148
# 536         KR  5089695777       145    420      13  1616661851072
# 537         KR  5089642744        82    420      13  1616660148487
# 538         KR  5089547319        67    420      13  1616657093881
# 539         KR  5089379568        83    420      13  1616652554001
# 540         KR  5089445380        83    420      13  1616650030044
# 541         KR  5089470931       235    420      13  1616646912080
# 542         KR  5083208137       234    420      13  1616343103797
# 543         KR  5083174388       516    420      13  1616341060271
# 544         KR  5083079692        74    420      13  1616339189618
# 545         KR  5082953045       145    420      13  1616333826632
# 546         KR  5082932806       145    420      13  1616331519985
# 547         KR  5081767886        56    420      13  1616308185741
# 548         KR  5081537672        67    420      13  1616305067081
# 549         KR  5081442516        81    420      13  1616302683861
# 550         KR  5080891390        77    420      13  1616258770077
# 551         KR  5080747067       101    420      13  1616256965732
# 552         KR  5080595258        82    420      13  1616251111474
# 553         KR  5077399768       107    420      13  1616154783389
# 554         KR  5077329048        61    420      13  1616150757704
# 555         KR  5077272648        81    420      13  1616147639604
# 556         KR  5076936099       235    420      13  1616144414676
# 557         KR  5072218378        81    420      13  1615903673556
# 558         KR  5070024332        81    420      13  1615805889674
# 559         KR  5068847507        18    420      13  1615736104582
# 560         KR  5068820720       235    420      13  1615730990265
# 561         KR  5065728530        67    420      13  1615638239863
# 562         KR  5064793246        82    420      13  1615615614254
# 563         KR  5064686249        67    420      13  1615613215779
# 564         KR  5064611282        81    420      13  1615606395902
# 565         KR  5063914044        36    420      13  1615563921643
# 566         KR  5063815558        67    420      13  1615562049060
# 567         KR  5063730961        38    420      13  1615560222316
# 568         KR  5063549186        55    420      13  1615557818639
# 569         KR  5063379473       235    420      13  1615554857450
# 570         KR  5063441028        67    420      13  1615553135363
# 571         KR  5059759492       133    420      13  1615380587322
# 572         KR  5059463168        81    420      13  1615371917386
# 573         KR  5057959117        81    420      13  1615297518859
# 574         KR  5056483482       235    420      13  1615215195101
# 575         KR  5054125809        18    420      13  1615120555683
# 576         KR  5053345597       145    420      13  1615106991611
# 577         KR  5053001513       235    420      13  1615097530618
# 578         KR  5052924130        16    420      13  1615095235709
# 579         KR  5052870292        16    420      13  1615093607466
# 580         KR  5052823971        67    420      13  1615091624851
# 581         KR  5049069624        67    420      13  1614957099946
# 582         KR  5048782564        25    420      13  1614948485021
# 583         KR  5048715170        18    420      13  1614946606180
# 584         KR  5048558524       145    420      13  1614944707494
# 585         KR  5048552190        81    420      13  1614942661103
# 586         KR  5048021243        98    420      13  1614929847822
# 587         KR  5047774044        54    420      13  1614921362648
# 588         KR  5047760055        67    420      13  1614918842039
# 589         KR  5047651484        51    420      13  1614912676446
# 590         KR  5047359172       145    420      13  1614910847593
# 591         KR  5046789986       235    420      13  1614867215164
# 592         KR  5046739354        18    420      13  1614864307449
# 593         KR  5046579793       120    420      13  1614861567263
# 594         KR  5045027466       145    420      13  1614778155630
# 595         KR  5044860212       235    420      13  1614773319748
# 596         KR  5042667012       235    420      13  1614691775034
# 597         KR  5041019924       145    420      13  1614609664456
# 598         KR  5041002338       145    420      13  1614607481887
# 599         KR  5040871899        67    420      13  1614604625427
# 600         KR  5040820970        54    420      13  1614602515785
# 601         KR  5037957974       145    420      13  1614517956440
# 602         KR  5036823984        67    420      13  1614493003292
# 603         KR  5036679298        75    420      13  1614491153542
# 604         KR  5036712672       145    420      13  1614489097921
# 605         KR  5035768820        81    420      13  1614445444986
# 606         KR  5035733800       235    420      13  1614443550945
# 607         KR  5035684527       133    420      13  1614441073229
# 608         KR  5035577735        98    420      13  1614439330613
# 609         KR  5032802260        74    420      13  1614347798239
# 610         KR  5030871399        75    420      13  1614266279297
# 611         KR  5030630450       145    420      13  1614263217700
# 612         KR  5030441271       150    420      13  1614261170788
# 613         KR  5030242103       235    420      13  1614258864622
# 614         KR  5030160885        25    420      13  1614256287242
# 615         KR  5030053590        77    420      13  1614254418991
# 616         KR  5029736927       235    420      13  1614245555167
# 617         KR  5029102335       145    420      13  1614227292306
# 618         KR  5027628381       235    420      13  1614165887894
# 619         KR  5025910001       145    420      13  1614089271965
# 620         KR  5025510342       875    420      13  1614079742100
# 621         KR  5025405633       235    420      13  1614078317164
# 622         KR  5023366734       235    420      13  1613999816375
# 623         KR  5023185987        67    420      13  1613996883555
# 624         KR  5023031122        17    420      13  1613990378064
# 625         KR  5019953864       235    420      13  1613886324315
# 626         KR  5018090011       145    420      13  1613821512362
# 627         KR  5017564549       235    420      13  1613811396171
# 628         KR  5017520007       235    420      13  1613809883803
# 629         KR  5013288884       145    420      13  1613654493767
# 630         KR  5013244595       235    420      13  1613651258991
# 631         KR  5010833129        77    420      13  1613566930648
# 632         KR  5010575476       145    420      13  1613564750748
# 633         KR  5008540877       145    420      13  1613480654343
# 634         KR  5005609522        57    420      13  1613384733974
# 635         KR  5004151928        77    420      13  1613313644670
# 636         KR  5003844013        67    420      13  1613309437626
# 637         KR  5001401775       235    420      13  1613233315376
# 638         KR  5001332512        74    420      13  1613230990807
# 639         KR  4999718725        67    420      13  1613201455873
# 640         KR  4999558915        54    420      13  1613199000776
# 641         KR  4999339106       164    420      13  1613196462028
# 642         KR  4997750758       133    420      13  1613133023826
# 643         KR  4997176689       235    420      13  1613124033079
# 644         KR  4995447757       133    420      13  1613055168579
# 645         KR  4995289893       145    420      13  1613053167842
# 646         KR  4995177095       145    420      13  1613050487289
# 647         KR  4994509815       164    420      13  1613041808510
# 648         KR  4991529317        67    420      13  1612954639971
# 649         KR  4984813463        67    420      13  1612709082393
# 650         KR  4984608670        75    420      13  1612705963229
# 651         KR  4980121137       516    420      13  1612595540949
# 652         KR  4979993579        67    420      13  1612593602255
# 653         KR  4978740877        98    420      13  1612539619310
# 654         KR  4978498430        82    420      13  1612536871120
# 655         KR  4975320031        74    420      13  1612436635519
# 656         KR  4972955645        81    420      13  1612350644337
# 657         KR  4965738552       235    420      13  1612096592228
# 658         KR  4965654599        77    420      13  1612095529367
# 659         KR  4965019436       145    420      13  1612081282103
# 660         KR  4964887898        77    420      13  1612078384759
# 661         KR  4957579411       145    420      13  1611837305515
# 662         KR  4957430803        82    420      13  1611832244735
# 663         KR  4955455795       120    420      13  1611757752529
# 664         KR  4955319656       145    420      13  1611756169925
# 665         KR  4955280110       235    420      13  1611753971043
# 666         KR  4955014683       360    420      13  1611747723681
# 667         KR  4952977640       234    420      13  1611669509581
# 668         KR  4952900275        77    420      13  1611667507989
# 669         KR  4952695505        67    420      13  1611664518946
# 670         KR  4952322962       145    420      13  1611661184748
# 671         KR  4949688746       133    420      13  1611573440670
# 672         KR  4947954891       234    420      13  1611495400954
# 673         KR  4947876333       234    420      13  1611493703341
# 674         KR  4946438496        82    420      13  1611470187242
# 675         KR  4946362385        57    420      13  1611468246245
# 676         KR  4938808573       145    420      13  1611237555264
# 677         KR  4936167419       133    420      13  1611148735694
# 678         KR  4935938236         6    420      13  1611146350977
# 679         KR  4935826389        18    420      13  1611143149660
# 680         KR  4935851967       145    420      13  1611141931374
# 681         KR  4933889183        31    420      13  1611062718533
# 682         KR  4933550423        98    420      13  1611055357287
# 683         KR  4931437006        82    420      13  1610974301336
# ...
# 108          DUO     MID
# 109         NONE  JUNGLE
# 110         SOLO     MID
# 111  DUO_SUPPORT  BOTTOM
# 112    DUO_CARRY     MID
# 113         SOLO     MID
# 114  DUO_SUPPORT    NONE
# 115         NONE  JUNGLE
# 116         NONE  JUNGLE
# 117         NONE  JUNGLE
# 118         NONE  JUNGLE
# 119         NONE  JUNGLE
# 120         NONE  JUNGLE
# 121         NONE  JUNGLE
# 122         NONE  JUNGLE
# 123         SOLO     MID
# 124         SOLO     MID
# 125         NONE  JUNGLE
# 126  DUO_SUPPORT    NONE
# 127         NONE  JUNGLE
# 128         NONE  JUNGLE
# 129         NONE  JUNGLE
# 130         NONE  JUNGLE
# 131         NONE  JUNGLE
# 132         NONE  JUNGLE
# 133         NONE  JUNGLE
# 134         NONE  JUNGLE
# 135         NONE  JUNGLE
# 136          DUO    NONE
# 137         NONE  JUNGLE
# 138         NONE  JUNGLE
# 139         NONE  JUNGLE
# 140    DUO_CARRY  BOTTOM
# 141         NONE  JUNGLE
# 142         SOLO     TOP
# 143         SOLO     TOP
# 144         NONE  JUNGLE
# 145         NONE  JUNGLE
# 146         NONE  JUNGLE
# 147         NONE  JUNGLE
# 148         NONE  JUNGLE
# 149         NONE  JUNGLE
# 150         NONE  JUNGLE
# 151         NONE  JUNGLE
# 152         NONE  JUNGLE
# 153         NONE  JUNGLE
# 154         SOLO     TOP
# 155  DUO_SUPPORT    NONE
# 156         NONE  JUNGLE
# 157    DUO_CARRY  BOTTOM
# 158    DUO_CARRY  BOTTOM
# 159    DUO_CARRY  BOTTOM
# 160  DUO_SUPPORT     TOP
# 161         NONE  JUNGLE
# 162         SOLO     TOP
# 163  DUO_SUPPORT    NONE
# 164    DUO_CARRY  BOTTOM
# 165    DUO_CARRY  BOTTOM
# 166          DUO     MID
# 167  DUO_SUPPORT  BOTTOM
# 168  DUO_SUPPORT    NONE
# 169  DUO_SUPPORT  BOTTOM
# 170    DUO_CARRY  BOTTOM
# 171          DUO     MID
# 172    DUO_CARRY  BOTTOM
# 173          DUO     MID
# 174    DUO_CARRY  BOTTOM
# 175    DUO_CARRY  BOTTOM
# 176    DUO_CARRY  BOTTOM
# 177    DUO_CARRY  BOTTOM
# 178    DUO_CARRY  BOTTOM
# 179    DUO_CARRY  BOTTOM
# 180          DUO    NONE
# 181    DUO_CARRY  BOTTOM
# 182    DUO_CARRY  BOTTOM
# 183    DUO_CARRY  BOTTOM
# 184    DUO_CARRY  BOTTOM
# 185         NONE  JUNGLE
# 186    DUO_CARRY  BOTTOM
# 187         NONE  JUNGLE
# 188         NONE  JUNGLE
# 189    DUO_CARRY  BOTTOM
# 190         NONE  JUNGLE
# 191  DUO_SUPPORT    NONE
# 192         NONE  JUNGLE
# 193         NONE  JUNGLE
# 194         SOLO     TOP
# 195    DUO_CARRY  BOTTOM
# 196    DUO_CARRY  BOTTOM
# 197    DUO_CARRY  BOTTOM
# 198         NONE  JUNGLE
# 199  DUO_SUPPORT    NONE
# 200         SOLO     TOP
# 201    DUO_CARRY  BOTTOM
# 202    DUO_CARRY  BOTTOM
# 203    DUO_CARRY  BOTTOM
# 204    DUO_CARRY  BOTTOM
# 205    DUO_CARRY  BOTTOM
# 206         NONE  JUNGLE
# 207         SOLO     TOP
# 208          DUO     MID
# 209         SOLO     TOP
# 210         SOLO     TOP
# 211    DUO_CARRY  BOTTOM
# 212          DUO    NONE
# 213         NONE  JUNGLE
# 214          DUO    NONE
# 215         SOLO     MID
# 216          DUO     MID
# 217    DUO_CARRY  BOTTOM
# 218  DUO_SUPPORT     TOP
# 219         SOLO     TOP
# 220    DUO_CARRY  BOTTOM
# 221    DUO_CARRY  BOTTOM
# 222          DUO    NONE
# 223    DUO_CARRY  BOTTOM
# 224  DUO_SUPPORT     MID
# 225          DUO     MID
# 226    DUO_CARRY  BOTTOM
# 227         SOLO     TOP
# 228    DUO_CARRY  BOTTOM
# 229  DUO_SUPPORT    NONE
# 230    DUO_CARRY  BOTTOM
# 231         NONE  JUNGLE
# 232    DUO_CARRY  BOTTOM
# 233    DUO_CARRY  BOTTOM
# 234         NONE  JUNGLE
# 235         NONE  JUNGLE
# 236  DUO_SUPPORT  BOTTOM
# 237    DUO_CARRY  BOTTOM
# 238         NONE  JUNGLE
# 239    DUO_CARRY  BOTTOM
# 240         SOLO     TOP
# 241    DUO_CARRY  BOTTOM
# 242         SOLO     TOP
# 243         SOLO     TOP
# 244         NONE  JUNGLE
# 245         SOLO     TOP
# 246          DUO    NONE
# 247         SOLO     TOP
# 248         NONE  JUNGLE
# 249         NONE  JUNGLE
# 250         NONE  JUNGLE
# 251  DUO_SUPPORT    NONE
# 252         NONE  JUNGLE
# 253         NONE  JUNGLE
# 254         NONE  JUNGLE
# 255         NONE  JUNGLE
# 256          DUO    NONE
# 257         NONE  JUNGLE
# 258    DUO_CARRY  BOTTOM
# 259         NONE  JUNGLE
# 260         NONE  JUNGLE
# 261         NONE  JUNGLE
# 262         NONE  JUNGLE
# 263  DUO_SUPPORT  BOTTOM
# 264    DUO_CARRY  BOTTOM
# 265          DUO    NONE
# 266    DUO_CARRY  BOTTOM
# 267    DUO_CARRY     MID
# 268    DUO_CARRY  BOTTOM
# 269         NONE  JUNGLE
# 270    DUO_CARRY  BOTTOM
# 271         NONE  JUNGLE
# 272         NONE  JUNGLE
# 273    DUO_CARRY  BOTTOM
# 274         SOLO     TOP
# 275         NONE  JUNGLE
# 276    DUO_CARRY  BOTTOM
# 277    DUO_CARRY  BOTTOM
# 278    DUO_CARRY  BOTTOM
# 279    DUO_CARRY  BOTTOM
# 280  DUO_SUPPORT    NONE
# 281          DUO     MID
# 282         NONE  JUNGLE
# 283    DUO_CARRY  BOTTOM
# 284         SOLO  BOTTOM
# 285    DUO_CARRY  BOTTOM
# 286    DUO_CARRY  BOTTOM
# 287          DUO  BOTTOM
# 288         SOLO     TOP
# 289         SOLO     TOP
# 290          DUO    NONE
# 291    DUO_CARRY  BOTTOM
# 292    DUO_CARRY  BOTTOM
# 293         NONE  JUNGLE
# 294          DUO     MID
# 295  DUO_SUPPORT    NONE
# 296    DUO_CARRY  BOTTOM
# 297    DUO_CARRY  BOTTOM
# 298    DUO_CARRY  BOTTOM
# 299  DUO_SUPPORT  BOTTOM
# 300  DUO_SUPPORT  BOTTOM
# 301  DUO_SUPPORT  BOTTOM
# 302  DUO_SUPPORT  BOTTOM
# 303    DUO_CARRY  BOTTOM
# 304    DUO_CARRY  BOTTOM
# 305         SOLO     TOP
# 306    DUO_CARRY  BOTTOM
# 307    DUO_CARRY  BOTTOM
# 308  DUO_SUPPORT    NONE
# 309    DUO_CARRY  BOTTOM
# 310    DUO_CARRY  BOTTOM
# 311  DUO_SUPPORT  BOTTOM
# 312    DUO_CARRY  BOTTOM
# 313         NONE  JUNGLE
# 314         NONE  JUNGLE
# 315    DUO_CARRY  BOTTOM
# 316    DUO_CARRY  BOTTOM
# 317    DUO_CARRY  BOTTOM
# 318         NONE  JUNGLE
# 319    DUO_CARRY  BOTTOM
# 320         SOLO     TOP
# 321    DUO_CARRY  BOTTOM
# 322    DUO_CARRY  BOTTOM
# 323         NONE  JUNGLE
# 324  DUO_SUPPORT  BOTTOM
# 325          DUO    NONE
# 326  DUO_SUPPORT    NONE
# 327         NONE  JUNGLE
# 328         NONE  JUNGLE
# 329         NONE  JUNGLE
# 330         NONE  JUNGLE
# 331         NONE  JUNGLE
# 332         NONE  JUNGLE
# 333         NONE  JUNGLE
# 334         NONE  JUNGLE
# 335         NONE  JUNGLE
# 336         NONE  JUNGLE
# 337  DUO_SUPPORT    NONE
# 338         NONE  JUNGLE
# 339         NONE  JUNGLE
# 340         NONE  JUNGLE
# 341         NONE  JUNGLE
# 342         NONE  JUNGLE
# 343         NONE  JUNGLE
# 344    DUO_CARRY  BOTTOM
# 345    DUO_CARRY  BOTTOM
# 346         SOLO     TOP
# 347         SOLO     TOP
# 348    DUO_CARRY  BOTTOM
# 349         SOLO     TOP
# 350         NONE  JUNGLE
# 351         SOLO     TOP
# 352    DUO_CARRY  BOTTOM
# 353         NONE  JUNGLE
# 354  DUO_SUPPORT    NONE
# 355          DUO    NONE
# 356         NONE  JUNGLE
# 357  DUO_SUPPORT    NONE
# 358         SOLO     TOP
# 359    DUO_CARRY     TOP
# 360         NONE  JUNGLE
# 361         NONE  JUNGLE
# 362          DUO     MID
# 363         NONE  JUNGLE
# 364         NONE  JUNGLE
# 365         SOLO  BOTTOM
# 366         NONE  JUNGLE
# 367    DUO_CARRY  BOTTOM
# 368         NONE  JUNGLE
# 369         NONE  JUNGLE
# 370         NONE  JUNGLE
# 371  DUO_SUPPORT    NONE
# 372    DUO_CARRY  BOTTOM
# 373         NONE  JUNGLE
# 374         NONE  JUNGLE
# 375    DUO_CARRY  BOTTOM
# 376         NONE  JUNGLE
# 377         NONE  JUNGLE
# 378         SOLO     TOP
# 379         NONE  JUNGLE
# 380         NONE  JUNGLE
# 381         NONE  JUNGLE
# 382         NONE  JUNGLE
# 383         NONE  JUNGLE
# 384         NONE  JUNGLE
# 385         SOLO     MID
# 386         NONE  JUNGLE
# 387         NONE  JUNGLE
# 388         NONE  JUNGLE
# 389         NONE  JUNGLE
# 390          DUO     TOP
# 391         SOLO     TOP
# 392         SOLO     TOP
# 393    DUO_CARRY  BOTTOM
# 394          DUO     MID
# 395  DUO_SUPPORT    NONE
# 396         NONE  JUNGLE
# 397          DUO     TOP
# 398          DUO     TOP
# 399         SOLO     TOP
# 400         NONE  JUNGLE
# 401         SOLO     TOP
# 402         NONE  JUNGLE
# 403         SOLO     TOP
# 404          DUO     MID
# 405         SOLO     TOP
# 406          DUO     TOP
# 407  DUO_SUPPORT    NONE
# 408         SOLO     TOP
# 409    DUO_CARRY  BOTTOM
# 410         SOLO     TOP
# 411         SOLO     TOP
# 412         SOLO     TOP
# 413          DUO    NONE
# 414         SOLO     TOP
# 415    DUO_CARRY  BOTTOM
# 416    DUO_CARRY  BOTTOM
# 417         NONE  JUNGLE
# 418         NONE  JUNGLE
# 419    DUO_CARRY  BOTTOM
# 420         NONE  JUNGLE
# 421         NONE  JUNGLE
# 422         NONE  JUNGLE
# 423         NONE  JUNGLE
# 424         NONE  JUNGLE
# 425         NONE  JUNGLE
# 426         NONE  JUNGLE
# 427         SOLO     TOP
# 428          DUO    NONE
# 429  DUO_SUPPORT    NONE
# 430    DUO_CARRY  BOTTOM
# 431    DUO_CARRY  BOTTOM
# 432         SOLO     TOP
# 433         NONE  JUNGLE
# 434         NONE  JUNGLE
# 435         NONE  JUNGLE
# 436         NONE  JUNGLE
# 437         SOLO     TOP
# 438         NONE  JUNGLE
# 439         NONE  JUNGLE
# 440         SOLO     TOP
# 441         SOLO     TOP
# 442         SOLO     TOP
# 443    DUO_CARRY  BOTTOM
# 444         SOLO     TOP
# 445         SOLO     TOP
# 446         NONE  JUNGLE
# 447         SOLO     TOP
# 448    DUO_CARRY  BOTTOM
# 449  DUO_SUPPORT    NONE
# 450         SOLO     TOP
# 451    DUO_CARRY  BOTTOM
# 452         SOLO     TOP
# 453          DUO    NONE
# 454         SOLO     TOP
# 455         SOLO     MID
# 456    DUO_CARRY  BOTTOM
# 457    DUO_CARRY  BOTTOM
# 458    DUO_CARRY  BOTTOM
# 459  DUO_SUPPORT    NONE
# 460         NONE  JUNGLE
# 461         NONE  JUNGLE
# 462         SOLO     TOP
# 463    DUO_CARRY  BOTTOM
# 464    DUO_CARRY  BOTTOM
# 465    DUO_CARRY  BOTTOM
# 466          DUO    NONE
# 467    DUO_CARRY  BOTTOM
# 468  DUO_SUPPORT    NONE
# 469    DUO_CARRY  BOTTOM
# 470    DUO_CARRY  BOTTOM
# 471    DUO_CARRY  BOTTOM
# 472    DUO_CARRY  BOTTOM
# 473         SOLO     TOP
# 474          DUO     MID
# 475         NONE  JUNGLE
# 476  DUO_SUPPORT    NONE
# 477         NONE  JUNGLE
# 478         NONE  JUNGLE
# 479         NONE  JUNGLE
# 480    DUO_CARRY  BOTTOM
# 481    DUO_CARRY  BOTTOM
# 482    DUO_CARRY  BOTTOM
# 483  DUO_SUPPORT  BOTTOM
# 484  DUO_SUPPORT    NONE
# 485          DUO    NONE
# 486    DUO_CARRY  BOTTOM
# 487    DUO_CARRY  BOTTOM
# 488          DUO    NONE
# 489         SOLO     TOP
# 490    DUO_CARRY  BOTTOM
# 491          DUO    NONE
# 492         SOLO     TOP
# 493    DUO_CARRY  BOTTOM
# 494    DUO_CARRY  BOTTOM
# 495    DUO_CARRY  BOTTOM
# 496    DUO_CARRY  BOTTOM
# 497  DUO_SUPPORT  BOTTOM
# 498          DUO    NONE
# 499  DUO_SUPPORT  BOTTOM
# 500  DUO_SUPPORT  BOTTOM
# 501         SOLO     TOP
# 502         SOLO     TOP
# 503          DUO     MID
# 504    DUO_CARRY  BOTTOM
# 505  DUO_SUPPORT    NONE
# 506         NONE  JUNGLE
# 507         SOLO     TOP
# 508    DUO_CARRY  BOTTOM
# 509         SOLO  BOTTOM
# 510    DUO_CARRY  BOTTOM
# 511    DUO_CARRY  BOTTOM
# 512         SOLO     TOP
# 513          DUO     TOP
# 514          DUO     MID
# 515          DUO    NONE
# 516         SOLO  BOTTOM
# 517         SOLO     TOP
# 518  DUO_SUPPORT    NONE
# 519    DUO_CARRY  BOTTOM
# 520         SOLO     TOP
# 521    DUO_CARRY  BOTTOM
# 522    DUO_CARRY  BOTTOM
# 523         NONE  JUNGLE
# 524         SOLO     TOP
# 525    DUO_CARRY  BOTTOM
# 526         SOLO     TOP
# 527          DUO     TOP
# 528          DUO     MID
# 529         NONE  JUNGLE
# 530         NONE  JUNGLE
# 531    DUO_CARRY  BOTTOM
# 532    DUO_CARRY  BOTTOM
# 533    DUO_CARRY  BOTTOM
# 534         SOLO     TOP
# 535          DUO     MID
# 536    DUO_CARRY  BOTTOM
# 537         SOLO     TOP
# 538         SOLO     TOP
# 539  DUO_SUPPORT    NONE
# 540         SOLO     TOP
# 541    DUO_CARRY  BOTTOM
# 542         NONE  JUNGLE
# 543         SOLO     TOP
# 544         SOLO     TOP
# 545    DUO_CARRY  BOTTOM
# 546    DUO_CARRY  BOTTOM
# 547         NONE  JUNGLE
# 548    DUO_CARRY  BOTTOM
# 549          DUO    NONE
# 550         NONE  JUNGLE
# 551         SOLO     MID
# 552         SOLO     TOP
# 553         SOLO     TOP
# 554         SOLO     MID
# 555    DUO_CARRY  BOTTOM
# 556          DUO  BOTTOM
# 557    DUO_CARRY  BOTTOM
# 558          DUO    NONE
# 559         SOLO  BOTTOM
# 560    DUO_CARRY  BOTTOM
# 561    DUO_CARRY  BOTTOM
# 562         SOLO     TOP
# 563  DUO_SUPPORT    NONE
# 564    DUO_CARRY  BOTTOM
# 565         NONE  JUNGLE
# 566    DUO_CARRY  BOTTOM
# 567         SOLO     MID
# 568          DUO     MID
# 569    DUO_CARRY  BOTTOM
# 570  DUO_SUPPORT    NONE
# 571         SOLO     TOP
# 572    DUO_CARRY  BOTTOM
# 573          DUO    NONE
# 574    DUO_CARRY  BOTTOM
# 575    DUO_CARRY  BOTTOM
# 576    DUO_CARRY  BOTTOM
# 577    DUO_CARRY  BOTTOM
# 578  DUO_SUPPORT  BOTTOM
# 579  DUO_SUPPORT  BOTTOM
# 580    DUO_CARRY  BOTTOM
# 581          DUO    NONE
# 582  DUO_SUPPORT  BOTTOM
# 583  DUO_SUPPORT    NONE
# 584    DUO_CARRY  BOTTOM
# 585    DUO_CARRY  BOTTOM
# 586  DUO_SUPPORT    NONE
# 587         SOLO     TOP
# 588         SOLO     TOP
# 589          DUO    NONE
# 590    DUO_CARRY  BOTTOM
# 591  DUO_SUPPORT  BOTTOM
# 592    DUO_CARRY  BOTTOM
# 593         NONE  JUNGLE
# 594    DUO_CARRY  BOTTOM
# 595    DUO_CARRY  BOTTOM
# 596    DUO_CARRY  BOTTOM
# 597    DUO_CARRY  BOTTOM
# 598    DUO_CARRY  BOTTOM
# 599    DUO_CARRY  BOTTOM
# 600         SOLO     TOP
# 601    DUO_CARRY  BOTTOM
# 602    DUO_CARRY  BOTTOM
# 603  DUO_SUPPORT    NONE
# 604    DUO_CARRY  BOTTOM
# 605    DUO_CARRY  BOTTOM
# 606    DUO_CARRY  BOTTOM
# 607         SOLO     TOP
# 608         SOLO     TOP
# 609         SOLO     TOP
# 610         SOLO     TOP
# 611    DUO_CARRY  BOTTOM
# 612         SOLO     TOP
# 613    DUO_CARRY  BOTTOM
# 614  DUO_SUPPORT  BOTTOM
# 615         NONE  JUNGLE
# 616  DUO_SUPPORT    NONE
# 617    DUO_CARRY  BOTTOM
# 618  DUO_SUPPORT    NONE
# 619    DUO_CARRY  BOTTOM
# 620  DUO_SUPPORT     TOP
# 621  DUO_SUPPORT    NONE
# 622    DUO_CARRY  BOTTOM
# 623         SOLO  BOTTOM
# 624         SOLO     TOP
# 625    DUO_CARRY  BOTTOM
# 626    DUO_CARRY  BOTTOM
# 627    DUO_CARRY  BOTTOM
# 628  DUO_SUPPORT    NONE
# 629    DUO_CARRY  BOTTOM
# 630    DUO_CARRY  BOTTOM
# 631         NONE  JUNGLE
# 632         SOLO  BOTTOM
# 633    DUO_CARRY  BOTTOM
# 634  DUO_SUPPORT  BOTTOM
# 635         NONE  JUNGLE
# 636    DUO_CARRY  BOTTOM
# 637    DUO_CARRY  BOTTOM
# 638          DUO     TOP
# 639    DUO_CARRY  BOTTOM
# 640         SOLO     TOP
# 641         SOLO     TOP
# 642         SOLO     TOP
# 643    DUO_CARRY  BOTTOM
# 644         SOLO     TOP
# 645          DUO    NONE
# 646    DUO_CARRY  BOTTOM
# 647         SOLO     TOP
# 648    DUO_CARRY  BOTTOM
# 649    DUO_CARRY  BOTTOM
# 650         SOLO     TOP
# 651         SOLO     TOP
# 652    DUO_CARRY  BOTTOM
# 653         SOLO     TOP
# 654         SOLO     TOP
# 655         SOLO     TOP
# 656    DUO_CARRY  BOTTOM
# 657    DUO_CARRY  BOTTOM
# 658          DUO    NONE
# 659    DUO_CARRY  BOTTOM
# 660         NONE  JUNGLE
# 661    DUO_CARRY  BOTTOM
# 662         SOLO     TOP
# 663         NONE  JUNGLE
# 664    DUO_CARRY  BOTTOM
# 665          DUO     MID
# 666    DUO_CARRY  BOTTOM
# 667  DUO_SUPPORT  BOTTOM
# 668         NONE  JUNGLE
# 669         SOLO     TOP
# 670    DUO_CARRY  BOTTOM
# 671         SOLO     TOP
# 672         NONE  JUNGLE
# 673         NONE  JUNGLE
# 674         NONE  JUNGLE
# 675  DUO_SUPPORT  BOTTOM
# 676    DUO_CARRY  BOTTOM
# 677         SOLO     TOP
# 678         SOLO     TOP
# 679    DUO_CARRY  BOTTOM
# 680  DUO_SUPPORT    NONE
# 681         SOLO     TOP
# 682         SOLO     TOP
# 683         SOLO     TOP
# 684          DUO     MID
# 685         SOLO     TOP
# 686    DUO_CARRY  BOTTOM
# 687         SOLO     MID
# 688         SOLO     TOP
# 689    DUO_CARRY  BOTTOM
# 690         SOLO     TOP
# 691  DUO_SUPPORT  BOTTOM
# 692         SOLO     TOP
# 693    DUO_CARRY  BOTTOM
# 694    DUO_CARRY  BOTTOM
# 695  DUO_SUPPORT    NONE
# 696         SOLO  BOTTOM
# 697         NONE  JUNGLE
# 698         SOLO     TOP
# 699         SOLO     TOP

# %%
# 최근 100게임 세부 데이터 불러오기
detail = []
detail2 = []
for i in tqdm(range(700)):
    url = F"https://kr.api.riotgames.com/lol/match/v4/matches/{game_data['gameId'][i]}?api_key={apiDefault['key']}"
    r = requests.get(url)
    b = r.json()
    for j in range(10):
        if b['participantIdentities'][j]['player']['summonerName'] == '뱀꼬치':
            detail.append(b['participants'][j])
        else:
            pass
    sleep(1)
# Out:
# 100%|██████████| 700/700 [16:24<00:00,  1.41s/it]

# %%
a = detail

# %%
detail1 = []
for i in tqdm(range(700)):
    url = F"https://kr.api.riotgames.com/lol/match/v4/matches/{game_data['gameId'][i]}?api_key={apiDefault['key']}"
    req = requests.get(url)
    b = json.loads(req.text)
    if a[i]['stats']['win'] == True:
        if b['teams'][0]['win'] == 'Win':
            detail1.append(b['teams'][0])
        elif b['teams'][1]['win'] == 'Win':
            detail1.append(b['teams'][1])

    elif a[i]['stats']['win'] == False:
        if b['teams'][0]['win'] == 'Fail':
            detail1.append(b['teams'][0])
        elif b['teams'][1]['win'] == 'Fail':
            detail1.append(b['teams'][1])
    sleep(1)
detail1
# Out:
# 100%|██████████| 700/700 [16:20<00:00,  1.40s/it]
# [{'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 9,
#   'inhibitorKills': 2,
#   'baronKills': 0,
#   'dragonKills': 4,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 111, 'pickTurn': 6},
#    {'championId': 54, 'pickTurn': 7},
#    {'championId': 360, 'pickTurn': 8},
#    {'championId': 134, 'pickTurn': 9},
#    {'championId': 64, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 234, 'pickTurn': 1},
#    {'championId': 350, 'pickTurn': 2},
#    {'championId': 39, 'pickTurn': 3},
#    {'championId': 64, 'pickTurn': 4},
#    {'championId': 5, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 25, 'pickTurn': 1},
#    {'championId': 54, 'pickTurn': 2},
#    {'championId': 157, 'pickTurn': 3},
#    {'championId': 104, 'pickTurn': 4},
#    {'championId': 360, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 6,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 223, 'pickTurn': 1},
#    {'championId': 25, 'pickTurn': 2},
#    {'championId': 360, 'pickTurn': 3},
#    {'championId': -1, 'pickTurn': 4},
#    {'championId': 7, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 4,
#   'inhibitorKills': 0,
#   'baronKills': 1,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 517, 'pickTurn': 1},
#    {'championId': 360, 'pickTurn': 2},
#    {'championId': 35, 'pickTurn': 3},
#    {'championId': 111, 'pickTurn': 4},
#    {'championId': 114, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 203, 'pickTurn': 1},
#    {'championId': 114, 'pickTurn': 2},
#    {'championId': 53, 'pickTurn': 3},
#    {'championId': 101, 'pickTurn': 4},
#    {'championId': 238, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 91, 'pickTurn': 1},
#    {'championId': 420, 'pickTurn': 2},
#    {'championId': -1, 'pickTurn': 3},
#    {'championId': 234, 'pickTurn': 4},
#    {'championId': 22, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 25, 'pickTurn': 6},
#    {'championId': 64, 'pickTurn': 7},
#    {'championId': 131, 'pickTurn': 8},
#    {'championId': 360, 'pickTurn': 9},
#    {'championId': 39, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 8,
#   'inhibitorKills': 1,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 887, 'pickTurn': 6},
#    {'championId': 360, 'pickTurn': 7},
#    {'championId': 25, 'pickTurn': 8},
#    {'championId': 64, 'pickTurn': 9},
#    {'championId': 238, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 5,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 35, 'pickTurn': 6},
#    {'championId': 157, 'pickTurn': 7},
#    {'championId': 81, 'pickTurn': 8},
#    {'championId': 25, 'pickTurn': 9},
#    {'championId': 64, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 360, 'pickTurn': 6},
#    {'championId': 55, 'pickTurn': 7},
#    {'championId': 2, 'pickTurn': 8},
#    {'championId': 25, 'pickTurn': 9},
#    {'championId': 39, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 8,
#   'inhibitorKills': 2,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 114, 'pickTurn': 1},
#    {'championId': 360, 'pickTurn': 2},
#    {'championId': 7, 'pickTurn': 3},
#    {'championId': 157, 'pickTurn': 4},
#    {'championId': 25, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 3,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 154, 'pickTurn': 1},
#    {'championId': 360, 'pickTurn': 2},
#    {'championId': 25, 'pickTurn': 3},
#    {'championId': 2, 'pickTurn': 4},
#    {'championId': 238, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 8,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 122, 'pickTurn': 6},
#    {'championId': 5, 'pickTurn': 7},
#    {'championId': 360, 'pickTurn': 8},
#    {'championId': 25, 'pickTurn': 9},
#    {'championId': 7, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 11,
#   'inhibitorKills': 2,
#   'baronKills': 1,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 35, 'pickTurn': 6},
#    {'championId': 412, 'pickTurn': 7},
#    {'championId': 105, 'pickTurn': 8},
#    {'championId': 39, 'pickTurn': 9},
#    {'championId': 350, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 8,
#   'inhibitorKills': 2,
#   'baronKills': 0,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 360, 'pickTurn': 6},
#    {'championId': 875, 'pickTurn': 7},
#    {'championId': 56, 'pickTurn': 8},
#    {'championId': 117, 'pickTurn': 9},
#    {'championId': 64, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 9,
#   'inhibitorKills': 3,
#   'baronKills': 2,
#   'dragonKills': 5,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 234, 'pickTurn': 1},
#    {'championId': 238, 'pickTurn': 2},
#    {'championId': 104, 'pickTurn': 3},
#    {'championId': 360, 'pickTurn': 4},
#    {'championId': 24, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 6,
#   'inhibitorKills': 1,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 111, 'pickTurn': 6},
#    {'championId': 238, 'pickTurn': 7},
#    {'championId': 106, 'pickTurn': 8},
#    {'championId': 81, 'pickTurn': 9},
#    {'championId': 64, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 39, 'pickTurn': 6},
#    {'championId': 35, 'pickTurn': 7},
#    {'championId': 114, 'pickTurn': 8},
#    {'championId': 238, 'pickTurn': 9},
#    {'championId': 89, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 8,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 4,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 523, 'pickTurn': 6},
#    {'championId': 105, 'pickTurn': 7},
#    {'championId': 5, 'pickTurn': 8},
#    {'championId': 17, 'pickTurn': 9},
#    {'championId': 412, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 517, 'pickTurn': 6},
#    {'championId': -1, 'pickTurn': 7},
#    {'championId': 64, 'pickTurn': 8},
#    {'championId': 67, 'pickTurn': 9},
#    {'championId': 101, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 9,
#   'inhibitorKills': 2,
#   'baronKills': 1,
#   'dragonKills': 5,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 157, 'pickTurn': 1},
#    {'championId': 64, 'pickTurn': 2},
#    {'championId': 518, 'pickTurn': 3},
#    {'championId': 101, 'pickTurn': 4},
#    {'championId': 36, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 11,
#   'inhibitorKills': 3,
#   'baronKills': 0,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 238, 'pickTurn': 1},
#    {'championId': 17, 'pickTurn': 2},
#    {'championId': 360, 'pickTurn': 3},
#    {'championId': 64, 'pickTurn': 4},
#    {'championId': 81, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 3,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 360, 'pickTurn': 1},
#    {'championId': 104, 'pickTurn': 2},
#    {'championId': 122, 'pickTurn': 3},
#    {'championId': 25, 'pickTurn': 4},
#    {'championId': 64, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 10,
#   'inhibitorKills': 3,
#   'baronKills': 1,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 64, 'pickTurn': 6},
#    {'championId': -1, 'pickTurn': 7},
#    {'championId': 25, 'pickTurn': 8},
#    {'championId': 238, 'pickTurn': 9},
#    {'championId': 517, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 11,
#   'inhibitorKills': 3,
#   'baronKills': 1,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 106, 'pickTurn': 1},
#    {'championId': 360, 'pickTurn': 2},
#    {'championId': 84, 'pickTurn': 3},
#    {'championId': 5, 'pickTurn': 4},
#    {'championId': 25, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 6,
#   'inhibitorKills': 1,
#   'baronKills': 0,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 238, 'pickTurn': 6},
#    {'championId': 360, 'pickTurn': 7},
#    {'championId': 234, 'pickTurn': 8},
#    {'championId': 25, 'pickTurn': 9},
#    {'championId': 35, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 91, 'pickTurn': 1},
#    {'championId': 777, 'pickTurn': 2},
#    {'championId': 64, 'pickTurn': 3},
#    {'championId': 101, 'pickTurn': 4},
#    {'championId': 516, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 6,
#   'inhibitorKills': 0,
#   'baronKills': 1,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 360, 'pickTurn': 6},
#    {'championId': 64, 'pickTurn': 7},
#    {'championId': 5, 'pickTurn': 8},
#    {'championId': 117, 'pickTurn': 9},
#    {'championId': 83, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 8,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 64, 'pickTurn': 1},
#    {'championId': 360, 'pickTurn': 2},
#    {'championId': 58, 'pickTurn': 3},
#    {'championId': 875, 'pickTurn': 4},
#    {'championId': 777, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 10,
#   'inhibitorKills': 2,
#   'baronKills': 1,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 80, 'pickTurn': 1},
#    {'championId': 238, 'pickTurn': 2},
#    {'championId': 54, 'pickTurn': 3},
#    {'championId': 360, 'pickTurn': 4},
#    {'championId': 64, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 7,
#   'inhibitorKills': 0,
#   'baronKills': 1,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 360, 'pickTurn': 6},
#    {'championId': 238, 'pickTurn': 7},
#    {'championId': 266, 'pickTurn': 8},
#    {'championId': 5, 'pickTurn': 9},
#    {'championId': 164, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 64, 'pickTurn': 6},
#    {'championId': 58, 'pickTurn': 7},
#    {'championId': 360, 'pickTurn': 8},
#    {'championId': 238, 'pickTurn': 9},
#    {'championId': 89, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 7,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 64, 'pickTurn': 1},
#    {'championId': 238, 'pickTurn': 2},
#    {'championId': 101, 'pickTurn': 3},
#    {'championId': 143, 'pickTurn': 4},
#    {'championId': 122, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 360, 'pickTurn': 6},
#    {'championId': 53, 'pickTurn': 7},
#    {'championId': 39, 'pickTurn': 8},
#    {'championId': 60, 'pickTurn': 9},
#    {'championId': 114, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 4,
#   'inhibitorKills': 0,
#   'baronKills': 1,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 7, 'pickTurn': 6},
#    {'championId': 35, 'pickTurn': 7},
#    {'championId': 64, 'pickTurn': 8},
#    {'championId': -1, 'pickTurn': 9},
#    {'championId': 67, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 360, 'pickTurn': 1},
#    {'championId': 84, 'pickTurn': 2},
#    {'championId': 64, 'pickTurn': 3},
#    {'championId': 56, 'pickTurn': 4},
#    {'championId': 238, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 3,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 101, 'pickTurn': 1},
#    {'championId': 238, 'pickTurn': 2},
#    {'championId': 64, 'pickTurn': 3},
#    {'championId': 56, 'pickTurn': 4},
#    {'championId': 74, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 234, 'pickTurn': 6},
#    {'championId': 246, 'pickTurn': 7},
#    {'championId': 887, 'pickTurn': 8},
#    {'championId': 64, 'pickTurn': 9},
#    {'championId': 89, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 35, 'pickTurn': 6},
#    {'championId': 238, 'pickTurn': 7},
#    {'championId': 145, 'pickTurn': 8},
#    {'championId': 84, 'pickTurn': 9},
#    {'championId': 64, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': True,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 7,
#   'inhibitorKills': 1,
#   'baronKills': 2,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 39, 'pickTurn': 6},
#    {'championId': 81, 'pickTurn': 7},
#    {'championId': 64, 'pickTurn': 8},
#    {'championId': 53, 'pickTurn': 9},
#    {'championId': 875, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 6,
#   'inhibitorKills': 1,
#   'baronKills': 0,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 64, 'pickTurn': 6},
#    {'championId': 526, 'pickTurn': 7},
#    {'championId': 81, 'pickTurn': 8},
#    {'championId': 117, 'pickTurn': 9},
#    {'championId': 67, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 3,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 157, 'pickTurn': 1},
#    {'championId': 887, 'pickTurn': 2},
#    {'championId': 56, 'pickTurn': 3},
#    {'championId': 360, 'pickTurn': 4},
#    {'championId': 64, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 39, 'pickTurn': 6},
#    {'championId': 555, 'pickTurn': 7},
#    {'championId': 53, 'pickTurn': 8},
#    {'championId': 7, 'pickTurn': 9},
#    {'championId': 64, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 8,
#   'inhibitorKills': 1,
#   'baronKills': 2,
#   'dragonKills': 4,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 64, 'pickTurn': 1},
#    {'championId': 266, 'pickTurn': 2},
#    {'championId': 360, 'pickTurn': 3},
#    {'championId': 25, 'pickTurn': 4},
#    {'championId': 84, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 9,
#   'inhibitorKills': 2,
#   'baronKills': 0,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 360, 'pickTurn': 1},
#    {'championId': 238, 'pickTurn': 2},
#    {'championId': 25, 'pickTurn': 3},
#    {'championId': 56, 'pickTurn': 4},
#    {'championId': 17, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 5,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 35, 'pickTurn': 1},
#    {'championId': 64, 'pickTurn': 2},
#    {'championId': 25, 'pickTurn': 3},
#    {'championId': 266, 'pickTurn': 4},
#    {'championId': 360, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 10,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 5, 'pickTurn': 6},
#    {'championId': 887, 'pickTurn': 7},
#    {'championId': 360, 'pickTurn': 8},
#    {'championId': 83, 'pickTurn': 9},
#    {'championId': 101, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 9,
#   'inhibitorKills': 3,
#   'baronKills': 1,
#   'dragonKills': 4,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 360, 'pickTurn': 6},
#    {'championId': 223, 'pickTurn': 7},
#    {'championId': 517, 'pickTurn': 8},
#    {'championId': 91, 'pickTurn': 9},
#    {'championId': 35, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 81, 'pickTurn': 6},
#    {'championId': 64, 'pickTurn': 7},
#    {'championId': 360, 'pickTurn': 8},
#    {'championId': 236, 'pickTurn': 9},
#    {'championId': 17, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 9,
#   'inhibitorKills': 1,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 35, 'pickTurn': 6},
#    {'championId': 238, 'pickTurn': 7},
#    {'championId': 81, 'pickTurn': 8},
#    {'championId': 122, 'pickTurn': 9},
#    {'championId': 360, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 360, 'pickTurn': 1},
#    {'championId': 64, 'pickTurn': 2},
#    {'championId': 114, 'pickTurn': 3},
#    {'championId': 238, 'pickTurn': 4},
#    {'championId': -1, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 11,
#   'inhibitorKills': 4,
#   'baronKills': 2,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 89, 'pickTurn': 1},
#    {'championId': 157, 'pickTurn': 2},
#    {'championId': 24, 'pickTurn': 3},
#    {'championId': 111, 'pickTurn': 4},
#    {'championId': 64, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 117, 'pickTurn': 1},
#    {'championId': 420, 'pickTurn': 2},
#    {'championId': 99, 'pickTurn': 3},
#    {'championId': 64, 'pickTurn': 4},
#    {'championId': 101, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 8,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 64, 'pickTurn': 6},
#    {'championId': 24, 'pickTurn': 7},
#    {'championId': 35, 'pickTurn': 8},
#    {'championId': 360, 'pickTurn': 9},
#    {'championId': 131, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 53, 'pickTurn': 1},
#    {'championId': 89, 'pickTurn': 2},
#    {'championId': 58, 'pickTurn': 3},
#    {'championId': 64, 'pickTurn': 4},
#    {'championId': 777, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 7,
#   'inhibitorKills': 0,
#   'baronKills': 1,
#   'dragonKills': 4,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 157, 'pickTurn': 1},
#    {'championId': 64, 'pickTurn': 2},
#    {'championId': 517, 'pickTurn': 3},
#    {'championId': 67, 'pickTurn': 4},
#    {'championId': 360, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 9,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 4,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 13, 'pickTurn': 1},
#    {'championId': 360, 'pickTurn': 2},
#    {'championId': 89, 'pickTurn': 3},
#    {'championId': 122, 'pickTurn': 4},
#    {'championId': 64, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 3,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 64, 'pickTurn': 6},
#    {'championId': 360, 'pickTurn': 7},
#    {'championId': 7, 'pickTurn': 8},
#    {'championId': 36, 'pickTurn': 9},
#    {'championId': -1, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 81, 'pickTurn': 1},
#    {'championId': 64, 'pickTurn': 2},
#    {'championId': 875, 'pickTurn': 3},
#    {'championId': 89, 'pickTurn': 4},
#    {'championId': 238, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 3,
#   'inhibitorKills': 0,
#   'baronKills': 1,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 238, 'pickTurn': 1},
#    {'championId': 54, 'pickTurn': 2},
#    {'championId': 64, 'pickTurn': 3},
#    {'championId': 111, 'pickTurn': 4},
#    {'championId': 89, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 7,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 64, 'pickTurn': 1},
#    {'championId': 35, 'pickTurn': 2},
#    {'championId': 238, 'pickTurn': 3},
#    {'championId': 56, 'pickTurn': 4},
#    {'championId': 101, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 9,
#   'inhibitorKills': 2,
#   'baronKills': 1,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 53, 'pickTurn': 6},
#    {'championId': 360, 'pickTurn': 7},
#    {'championId': 64, 'pickTurn': 8},
#    {'championId': 35, 'pickTurn': 9},
#    {'championId': -1, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 10,
#   'inhibitorKills': 2,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 11, 'pickTurn': 1},
#    {'championId': 114, 'pickTurn': 2},
#    {'championId': 238, 'pickTurn': 3},
#    {'championId': 360, 'pickTurn': 4},
#    {'championId': 89, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 5,
#   'inhibitorKills': 0,
#   'baronKills': 1,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 117, 'pickTurn': 6},
#    {'championId': 360, 'pickTurn': 7},
#    {'championId': 238, 'pickTurn': 8},
#    {'championId': 35, 'pickTurn': 9},
#    {'championId': 114, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 8,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 360, 'pickTurn': 6},
#    {'championId': 141, 'pickTurn': 7},
#    {'championId': 25, 'pickTurn': 8},
#    {'championId': 56, 'pickTurn': 9},
#    {'championId': 114, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 35, 'pickTurn': 1},
#    {'championId': 360, 'pickTurn': 2},
#    {'championId': 145, 'pickTurn': 3},
#    {'championId': 54, 'pickTurn': 4},
#    {'championId': 517, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 7, 'pickTurn': 1},
#    {'championId': 35, 'pickTurn': 2},
#    {'championId': 360, 'pickTurn': 3},
#    {'championId': 81, 'pickTurn': 4},
#    {'championId': 36, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 238, 'pickTurn': 6},
#    {'championId': 64, 'pickTurn': 7},
#    {'championId': 89, 'pickTurn': 8},
#    {'championId': 133, 'pickTurn': 9},
#    {'championId': 35, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 11,
#   'inhibitorKills': 3,
#   'baronKills': 1,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 53, 'pickTurn': 6},
#    {'championId': 58, 'pickTurn': 7},
#    {'championId': 64, 'pickTurn': 8},
#    {'championId': 238, 'pickTurn': 9},
#    {'championId': 145, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 122, 'pickTurn': 6},
#    {'championId': 56, 'pickTurn': 7},
#    {'championId': 7, 'pickTurn': 8},
#    {'championId': 238, 'pickTurn': 9},
#    {'championId': 235, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 25, 'pickTurn': 1},
#    {'championId': 90, 'pickTurn': 2},
#    {'championId': 89, 'pickTurn': 3},
#    {'championId': 55, 'pickTurn': 4},
#    {'championId': 114, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 7,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 91, 'pickTurn': 1},
#    {'championId': 157, 'pickTurn': 2},
#    {'championId': 35, 'pickTurn': 3},
#    {'championId': 89, 'pickTurn': 4},
#    {'championId': 86, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 10,
#   'inhibitorKills': 3,
#   'baronKills': 1,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 84, 'pickTurn': 1},
#    {'championId': 117, 'pickTurn': 2},
#    {'championId': 64, 'pickTurn': 3},
#    {'championId': 35, 'pickTurn': 4},
#    {'championId': 122, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 3,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 114, 'pickTurn': 6},
#    {'championId': 350, 'pickTurn': 7},
#    {'championId': 105, 'pickTurn': 8},
#    {'championId': 35, 'pickTurn': 9},
#    {'championId': 111, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 9,
#   'inhibitorKills': 2,
#   'baronKills': 1,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 157, 'pickTurn': 6},
#    {'championId': 117, 'pickTurn': 7},
#    {'championId': 81, 'pickTurn': 8},
#    {'championId': 35, 'pickTurn': 9},
#    {'championId': 875, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 3,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 67, 'pickTurn': 1},
#    {'championId': 64, 'pickTurn': 2},
#    {'championId': 56, 'pickTurn': 3},
#    {'championId': 25, 'pickTurn': 4},
#    {'championId': 238, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 91, 'pickTurn': 1},
#    {'championId': 164, 'pickTurn': 2},
#    {'championId': 35, 'pickTurn': 3},
#    {'championId': 56, 'pickTurn': 4},
#    {'championId': 4, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 10,
#   'inhibitorKills': 3,
#   'baronKills': 2,
#   'dragonKills': 4,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 101, 'pickTurn': 1},
#    {'championId': 35, 'pickTurn': 2},
#    {'championId': 64, 'pickTurn': 3},
#    {'championId': 360, 'pickTurn': 4},
#    {'championId': 517, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 7,
#   'inhibitorKills': 0,
#   'baronKills': 1,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 35, 'pickTurn': 1},
#    {'championId': 34, 'pickTurn': 2},
#    {'championId': 64, 'pickTurn': 3},
#    {'championId': 111, 'pickTurn': 4},
#    {'championId': 238, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 53, 'pickTurn': 1},
#    {'championId': 122, 'pickTurn': 2},
#    {'championId': 91, 'pickTurn': 3},
#    {'championId': 64, 'pickTurn': 4},
#    {'championId': 235, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 9,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 55, 'pickTurn': 6},
#    {'championId': 64, 'pickTurn': 7},
#    {'championId': 89, 'pickTurn': 8},
#    {'championId': 17, 'pickTurn': 9},
#    {'championId': 360, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 875, 'pickTurn': 6},
#    {'championId': 35, 'pickTurn': 7},
#    {'championId': 157, 'pickTurn': 8},
#    {'championId': 235, 'pickTurn': 9},
#    {'championId': 64, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 157, 'pickTurn': 6},
#    {'championId': 62, 'pickTurn': 7},
#    {'championId': 517, 'pickTurn': 8},
#    {'championId': 360, 'pickTurn': 9},
#    {'championId': 64, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 39, 'pickTurn': 1},
#    {'championId': 11, 'pickTurn': 2},
#    {'championId': 517, 'pickTurn': 3},
#    {'championId': 89, 'pickTurn': 4},
#    {'championId': 360, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 10,
#   'inhibitorKills': 2,
#   'baronKills': 0,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 36, 'pickTurn': 1},
#    {'championId': 238, 'pickTurn': 2},
#    {'championId': 235, 'pickTurn': 3},
#    {'championId': 54, 'pickTurn': 4},
#    {'championId': 360, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 8,
#   'inhibitorKills': 1,
#   'baronKills': 0,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 517, 'pickTurn': 6},
#    {'championId': 67, 'pickTurn': 7},
#    {'championId': 360, 'pickTurn': 8},
#    {'championId': 64, 'pickTurn': 9},
#    {'championId': 223, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 64, 'pickTurn': 6},
#    {'championId': 360, 'pickTurn': 7},
#    {'championId': 517, 'pickTurn': 8},
#    {'championId': 25, 'pickTurn': 9},
#    {'championId': -1, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 11,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 875, 'pickTurn': 6},
#    {'championId': 84, 'pickTurn': 7},
#    {'championId': 235, 'pickTurn': 8},
#    {'championId': 64, 'pickTurn': 9},
#    {'championId': 18, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 4,
# ...
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 7,
#   'inhibitorKills': 1,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 21, 'pickTurn': 1},
#    {'championId': 122, 'pickTurn': 2},
#    {'championId': 360, 'pickTurn': 3},
#    {'championId': 234, 'pickTurn': 4},
#    {'championId': 238, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 238, 'pickTurn': 6},
#    {'championId': 77, 'pickTurn': 7},
#    {'championId': 114, 'pickTurn': 8},
#    {'championId': 35, 'pickTurn': 9},
#    {'championId': 89, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 64, 'pickTurn': 6},
#    {'championId': 360, 'pickTurn': 7},
#    {'championId': 516, 'pickTurn': 8},
#    {'championId': 89, 'pickTurn': 9},
#    {'championId': 238, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 5,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 104, 'pickTurn': 1},
#    {'championId': 238, 'pickTurn': 2},
#    {'championId': 54, 'pickTurn': 3},
#    {'championId': 81, 'pickTurn': 4},
#    {'championId': 80, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 114, 'pickTurn': 1},
#    {'championId': 57, 'pickTurn': 2},
#    {'championId': 517, 'pickTurn': 3},
#    {'championId': 145, 'pickTurn': 4},
#    {'championId': 360, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 523, 'pickTurn': 6},
#    {'championId': 122, 'pickTurn': 7},
#    {'championId': 21, 'pickTurn': 8},
#    {'championId': 104, 'pickTurn': 9},
#    {'championId': 7, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 10,
#   'inhibitorKills': 3,
#   'baronKills': 1,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 21, 'pickTurn': 6},
#    {'championId': 57, 'pickTurn': 7},
#    {'championId': 203, 'pickTurn': 8},
#    {'championId': 157, 'pickTurn': 9},
#    {'championId': 777, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 11, 'pickTurn': 1},
#    {'championId': 114, 'pickTurn': 2},
#    {'championId': 101, 'pickTurn': 3},
#    {'championId': 21, 'pickTurn': 4},
#    {'championId': 105, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 9,
#   'inhibitorKills': 3,
#   'baronKills': 1,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 114, 'pickTurn': 6},
#    {'championId': 876, 'pickTurn': 7},
#    {'championId': 145, 'pickTurn': 8},
#    {'championId': 33, 'pickTurn': 9},
#    {'championId': 238, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 9,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 84, 'pickTurn': 1},
#    {'championId': 266, 'pickTurn': 2},
#    {'championId': 55, 'pickTurn': 3},
#    {'championId': 80, 'pickTurn': 4},
#    {'championId': 21, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 35, 'pickTurn': 6},
#    {'championId': 238, 'pickTurn': 7},
#    {'championId': 60, 'pickTurn': 8},
#    {'championId': 21, 'pickTurn': 9},
#    {'championId': 58, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 7,
#   'inhibitorKills': 1,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 20, 'pickTurn': 1},
#    {'championId': 236, 'pickTurn': 2},
#    {'championId': 9, 'pickTurn': 3},
#    {'championId': 34, 'pickTurn': 4},
#    {'championId': 114, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': True,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 7,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 4,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 2, 'pickTurn': 1},
#    {'championId': 238, 'pickTurn': 2},
#    {'championId': 157, 'pickTurn': 3},
#    {'championId': 21, 'pickTurn': 4},
#    {'championId': 80, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 8,
#   'inhibitorKills': 1,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 360, 'pickTurn': 6},
#    {'championId': 114, 'pickTurn': 7},
#    {'championId': 2, 'pickTurn': 8},
#    {'championId': 84, 'pickTurn': 9},
#    {'championId': 11, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 21, 'pickTurn': 1},
#    {'championId': 67, 'pickTurn': 2},
#    {'championId': 2, 'pickTurn': 3},
#    {'championId': 34, 'pickTurn': 4},
#    {'championId': 133, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 2, 'pickTurn': 1},
#    {'championId': 238, 'pickTurn': 2},
#    {'championId': 145, 'pickTurn': 3},
#    {'championId': 114, 'pickTurn': 4},
#    {'championId': 63, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 3,
#   'inhibitorKills': 0,
#   'baronKills': 1,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 777, 'pickTurn': 6},
#    {'championId': 21, 'pickTurn': 7},
#    {'championId': 121, 'pickTurn': 8},
#    {'championId': 39, 'pickTurn': 9},
#    {'championId': 111, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 11,
#   'inhibitorKills': 3,
#   'baronKills': 3,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 114, 'pickTurn': 1},
#    {'championId': 25, 'pickTurn': 2},
#    {'championId': 236, 'pickTurn': 3},
#    {'championId': 555, 'pickTurn': 4},
#    {'championId': 157, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 114, 'pickTurn': 1},
#    {'championId': 111, 'pickTurn': 2},
#    {'championId': 2, 'pickTurn': 3},
#    {'championId': 53, 'pickTurn': 4},
#    {'championId': 517, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 122, 'pickTurn': 6},
#    {'championId': 238, 'pickTurn': 7},
#    {'championId': 57, 'pickTurn': 8},
#    {'championId': 114, 'pickTurn': 9},
#    {'championId': 89, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 114, 'pickTurn': 6},
#    {'championId': 84, 'pickTurn': 7},
#    {'championId': 60, 'pickTurn': 8},
#    {'championId': 526, 'pickTurn': 9},
#    {'championId': 202, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 5,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 21, 'pickTurn': 6},
#    {'championId': 57, 'pickTurn': 7},
#    {'championId': 89, 'pickTurn': 8},
#    {'championId': 266, 'pickTurn': 9},
#    {'championId': 61, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 360, 'pickTurn': 1},
#    {'championId': 238, 'pickTurn': 2},
#    {'championId': 80, 'pickTurn': 3},
#    {'championId': 114, 'pickTurn': 4},
#    {'championId': 2, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 84, 'pickTurn': 1},
#    {'championId': 526, 'pickTurn': 2},
#    {'championId': 202, 'pickTurn': 3},
#    {'championId': 57, 'pickTurn': 4},
#    {'championId': 80, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 3,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 202, 'pickTurn': 1},
#    {'championId': 104, 'pickTurn': 2},
#    {'championId': 57, 'pickTurn': 3},
#    {'championId': 54, 'pickTurn': 4},
#    {'championId': 105, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 7,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 236, 'pickTurn': 6},
#    {'championId': 141, 'pickTurn': 7},
#    {'championId': 80, 'pickTurn': 8},
#    {'championId': 114, 'pickTurn': 9},
#    {'championId': 202, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 11,
#   'inhibitorKills': 3,
#   'baronKills': 0,
#   'dragonKills': 4,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 9, 'pickTurn': 1},
#    {'championId': 120, 'pickTurn': 2},
#    {'championId': 202, 'pickTurn': 3},
#    {'championId': -1, 'pickTurn': 4},
#    {'championId': 57, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 10,
#   'inhibitorKills': 2,
#   'baronKills': 2,
#   'dragonKills': 4,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 114, 'pickTurn': 1},
#    {'championId': 51, 'pickTurn': 2},
#    {'championId': 2, 'pickTurn': 3},
#    {'championId': 238, 'pickTurn': 4},
#    {'championId': 202, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 99, 'pickTurn': 1},
#    {'championId': 114, 'pickTurn': 2},
#    {'championId': 104, 'pickTurn': 3},
#    {'championId': 360, 'pickTurn': 4},
#    {'championId': 412, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 11,
#   'inhibitorKills': 3,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 104, 'pickTurn': 1},
#    {'championId': 777, 'pickTurn': 2},
#    {'championId': 360, 'pickTurn': 3},
#    {'championId': 54, 'pickTurn': 4},
#    {'championId': 35, 'pickTurn': 5}]}]

# %%
c = detail1

# %%
c
# Out:
# [{'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 9,
#   'inhibitorKills': 2,
#   'baronKills': 0,
#   'dragonKills': 4,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 111, 'pickTurn': 6},
#    {'championId': 54, 'pickTurn': 7},
#    {'championId': 360, 'pickTurn': 8},
#    {'championId': 134, 'pickTurn': 9},
#    {'championId': 64, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 234, 'pickTurn': 1},
#    {'championId': 350, 'pickTurn': 2},
#    {'championId': 39, 'pickTurn': 3},
#    {'championId': 64, 'pickTurn': 4},
#    {'championId': 5, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 25, 'pickTurn': 1},
#    {'championId': 54, 'pickTurn': 2},
#    {'championId': 157, 'pickTurn': 3},
#    {'championId': 104, 'pickTurn': 4},
#    {'championId': 360, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 6,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 223, 'pickTurn': 1},
#    {'championId': 25, 'pickTurn': 2},
#    {'championId': 360, 'pickTurn': 3},
#    {'championId': -1, 'pickTurn': 4},
#    {'championId': 7, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 4,
#   'inhibitorKills': 0,
#   'baronKills': 1,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 517, 'pickTurn': 1},
#    {'championId': 360, 'pickTurn': 2},
#    {'championId': 35, 'pickTurn': 3},
#    {'championId': 111, 'pickTurn': 4},
#    {'championId': 114, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 203, 'pickTurn': 1},
#    {'championId': 114, 'pickTurn': 2},
#    {'championId': 53, 'pickTurn': 3},
#    {'championId': 101, 'pickTurn': 4},
#    {'championId': 238, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 91, 'pickTurn': 1},
#    {'championId': 420, 'pickTurn': 2},
#    {'championId': -1, 'pickTurn': 3},
#    {'championId': 234, 'pickTurn': 4},
#    {'championId': 22, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 25, 'pickTurn': 6},
#    {'championId': 64, 'pickTurn': 7},
#    {'championId': 131, 'pickTurn': 8},
#    {'championId': 360, 'pickTurn': 9},
#    {'championId': 39, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 8,
#   'inhibitorKills': 1,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 887, 'pickTurn': 6},
#    {'championId': 360, 'pickTurn': 7},
#    {'championId': 25, 'pickTurn': 8},
#    {'championId': 64, 'pickTurn': 9},
#    {'championId': 238, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 5,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 35, 'pickTurn': 6},
#    {'championId': 157, 'pickTurn': 7},
#    {'championId': 81, 'pickTurn': 8},
#    {'championId': 25, 'pickTurn': 9},
#    {'championId': 64, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 360, 'pickTurn': 6},
#    {'championId': 55, 'pickTurn': 7},
#    {'championId': 2, 'pickTurn': 8},
#    {'championId': 25, 'pickTurn': 9},
#    {'championId': 39, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 8,
#   'inhibitorKills': 2,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 114, 'pickTurn': 1},
#    {'championId': 360, 'pickTurn': 2},
#    {'championId': 7, 'pickTurn': 3},
#    {'championId': 157, 'pickTurn': 4},
#    {'championId': 25, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 3,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 154, 'pickTurn': 1},
#    {'championId': 360, 'pickTurn': 2},
#    {'championId': 25, 'pickTurn': 3},
#    {'championId': 2, 'pickTurn': 4},
#    {'championId': 238, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 8,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 122, 'pickTurn': 6},
#    {'championId': 5, 'pickTurn': 7},
#    {'championId': 360, 'pickTurn': 8},
#    {'championId': 25, 'pickTurn': 9},
#    {'championId': 7, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 11,
#   'inhibitorKills': 2,
#   'baronKills': 1,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 35, 'pickTurn': 6},
#    {'championId': 412, 'pickTurn': 7},
#    {'championId': 105, 'pickTurn': 8},
#    {'championId': 39, 'pickTurn': 9},
#    {'championId': 350, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 8,
#   'inhibitorKills': 2,
#   'baronKills': 0,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 360, 'pickTurn': 6},
#    {'championId': 875, 'pickTurn': 7},
#    {'championId': 56, 'pickTurn': 8},
#    {'championId': 117, 'pickTurn': 9},
#    {'championId': 64, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 9,
#   'inhibitorKills': 3,
#   'baronKills': 2,
#   'dragonKills': 5,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 234, 'pickTurn': 1},
#    {'championId': 238, 'pickTurn': 2},
#    {'championId': 104, 'pickTurn': 3},
#    {'championId': 360, 'pickTurn': 4},
#    {'championId': 24, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 6,
#   'inhibitorKills': 1,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 111, 'pickTurn': 6},
#    {'championId': 238, 'pickTurn': 7},
#    {'championId': 106, 'pickTurn': 8},
#    {'championId': 81, 'pickTurn': 9},
#    {'championId': 64, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 39, 'pickTurn': 6},
#    {'championId': 35, 'pickTurn': 7},
#    {'championId': 114, 'pickTurn': 8},
#    {'championId': 238, 'pickTurn': 9},
#    {'championId': 89, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 8,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 4,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 523, 'pickTurn': 6},
#    {'championId': 105, 'pickTurn': 7},
#    {'championId': 5, 'pickTurn': 8},
#    {'championId': 17, 'pickTurn': 9},
#    {'championId': 412, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 517, 'pickTurn': 6},
#    {'championId': -1, 'pickTurn': 7},
#    {'championId': 64, 'pickTurn': 8},
#    {'championId': 67, 'pickTurn': 9},
#    {'championId': 101, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 9,
#   'inhibitorKills': 2,
#   'baronKills': 1,
#   'dragonKills': 5,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 157, 'pickTurn': 1},
#    {'championId': 64, 'pickTurn': 2},
#    {'championId': 518, 'pickTurn': 3},
#    {'championId': 101, 'pickTurn': 4},
#    {'championId': 36, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 11,
#   'inhibitorKills': 3,
#   'baronKills': 0,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 238, 'pickTurn': 1},
#    {'championId': 17, 'pickTurn': 2},
#    {'championId': 360, 'pickTurn': 3},
#    {'championId': 64, 'pickTurn': 4},
#    {'championId': 81, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 3,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 360, 'pickTurn': 1},
#    {'championId': 104, 'pickTurn': 2},
#    {'championId': 122, 'pickTurn': 3},
#    {'championId': 25, 'pickTurn': 4},
#    {'championId': 64, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 10,
#   'inhibitorKills': 3,
#   'baronKills': 1,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 64, 'pickTurn': 6},
#    {'championId': -1, 'pickTurn': 7},
#    {'championId': 25, 'pickTurn': 8},
#    {'championId': 238, 'pickTurn': 9},
#    {'championId': 517, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 11,
#   'inhibitorKills': 3,
#   'baronKills': 1,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 106, 'pickTurn': 1},
#    {'championId': 360, 'pickTurn': 2},
#    {'championId': 84, 'pickTurn': 3},
#    {'championId': 5, 'pickTurn': 4},
#    {'championId': 25, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 6,
#   'inhibitorKills': 1,
#   'baronKills': 0,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 238, 'pickTurn': 6},
#    {'championId': 360, 'pickTurn': 7},
#    {'championId': 234, 'pickTurn': 8},
#    {'championId': 25, 'pickTurn': 9},
#    {'championId': 35, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 91, 'pickTurn': 1},
#    {'championId': 777, 'pickTurn': 2},
#    {'championId': 64, 'pickTurn': 3},
#    {'championId': 101, 'pickTurn': 4},
#    {'championId': 516, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 6,
#   'inhibitorKills': 0,
#   'baronKills': 1,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 360, 'pickTurn': 6},
#    {'championId': 64, 'pickTurn': 7},
#    {'championId': 5, 'pickTurn': 8},
#    {'championId': 117, 'pickTurn': 9},
#    {'championId': 83, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 8,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 64, 'pickTurn': 1},
#    {'championId': 360, 'pickTurn': 2},
#    {'championId': 58, 'pickTurn': 3},
#    {'championId': 875, 'pickTurn': 4},
#    {'championId': 777, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 10,
#   'inhibitorKills': 2,
#   'baronKills': 1,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 80, 'pickTurn': 1},
#    {'championId': 238, 'pickTurn': 2},
#    {'championId': 54, 'pickTurn': 3},
#    {'championId': 360, 'pickTurn': 4},
#    {'championId': 64, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 7,
#   'inhibitorKills': 0,
#   'baronKills': 1,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 360, 'pickTurn': 6},
#    {'championId': 238, 'pickTurn': 7},
#    {'championId': 266, 'pickTurn': 8},
#    {'championId': 5, 'pickTurn': 9},
#    {'championId': 164, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 64, 'pickTurn': 6},
#    {'championId': 58, 'pickTurn': 7},
#    {'championId': 360, 'pickTurn': 8},
#    {'championId': 238, 'pickTurn': 9},
#    {'championId': 89, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 7,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 64, 'pickTurn': 1},
#    {'championId': 238, 'pickTurn': 2},
#    {'championId': 101, 'pickTurn': 3},
#    {'championId': 143, 'pickTurn': 4},
#    {'championId': 122, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 360, 'pickTurn': 6},
#    {'championId': 53, 'pickTurn': 7},
#    {'championId': 39, 'pickTurn': 8},
#    {'championId': 60, 'pickTurn': 9},
#    {'championId': 114, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 4,
#   'inhibitorKills': 0,
#   'baronKills': 1,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 7, 'pickTurn': 6},
#    {'championId': 35, 'pickTurn': 7},
#    {'championId': 64, 'pickTurn': 8},
#    {'championId': -1, 'pickTurn': 9},
#    {'championId': 67, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 360, 'pickTurn': 1},
#    {'championId': 84, 'pickTurn': 2},
#    {'championId': 64, 'pickTurn': 3},
#    {'championId': 56, 'pickTurn': 4},
#    {'championId': 238, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 3,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 101, 'pickTurn': 1},
#    {'championId': 238, 'pickTurn': 2},
#    {'championId': 64, 'pickTurn': 3},
#    {'championId': 56, 'pickTurn': 4},
#    {'championId': 74, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 234, 'pickTurn': 6},
#    {'championId': 246, 'pickTurn': 7},
#    {'championId': 887, 'pickTurn': 8},
#    {'championId': 64, 'pickTurn': 9},
#    {'championId': 89, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 35, 'pickTurn': 6},
#    {'championId': 238, 'pickTurn': 7},
#    {'championId': 145, 'pickTurn': 8},
#    {'championId': 84, 'pickTurn': 9},
#    {'championId': 64, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': True,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 7,
#   'inhibitorKills': 1,
#   'baronKills': 2,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 39, 'pickTurn': 6},
#    {'championId': 81, 'pickTurn': 7},
#    {'championId': 64, 'pickTurn': 8},
#    {'championId': 53, 'pickTurn': 9},
#    {'championId': 875, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 6,
#   'inhibitorKills': 1,
#   'baronKills': 0,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 64, 'pickTurn': 6},
#    {'championId': 526, 'pickTurn': 7},
#    {'championId': 81, 'pickTurn': 8},
#    {'championId': 117, 'pickTurn': 9},
#    {'championId': 67, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 3,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 157, 'pickTurn': 1},
#    {'championId': 887, 'pickTurn': 2},
#    {'championId': 56, 'pickTurn': 3},
#    {'championId': 360, 'pickTurn': 4},
#    {'championId': 64, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 39, 'pickTurn': 6},
#    {'championId': 555, 'pickTurn': 7},
#    {'championId': 53, 'pickTurn': 8},
#    {'championId': 7, 'pickTurn': 9},
#    {'championId': 64, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 8,
#   'inhibitorKills': 1,
#   'baronKills': 2,
#   'dragonKills': 4,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 64, 'pickTurn': 1},
#    {'championId': 266, 'pickTurn': 2},
#    {'championId': 360, 'pickTurn': 3},
#    {'championId': 25, 'pickTurn': 4},
#    {'championId': 84, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 9,
#   'inhibitorKills': 2,
#   'baronKills': 0,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 360, 'pickTurn': 1},
#    {'championId': 238, 'pickTurn': 2},
#    {'championId': 25, 'pickTurn': 3},
#    {'championId': 56, 'pickTurn': 4},
#    {'championId': 17, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 5,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 35, 'pickTurn': 1},
#    {'championId': 64, 'pickTurn': 2},
#    {'championId': 25, 'pickTurn': 3},
#    {'championId': 266, 'pickTurn': 4},
#    {'championId': 360, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 10,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 5, 'pickTurn': 6},
#    {'championId': 887, 'pickTurn': 7},
#    {'championId': 360, 'pickTurn': 8},
#    {'championId': 83, 'pickTurn': 9},
#    {'championId': 101, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 9,
#   'inhibitorKills': 3,
#   'baronKills': 1,
#   'dragonKills': 4,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 360, 'pickTurn': 6},
#    {'championId': 223, 'pickTurn': 7},
#    {'championId': 517, 'pickTurn': 8},
#    {'championId': 91, 'pickTurn': 9},
#    {'championId': 35, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 81, 'pickTurn': 6},
#    {'championId': 64, 'pickTurn': 7},
#    {'championId': 360, 'pickTurn': 8},
#    {'championId': 236, 'pickTurn': 9},
#    {'championId': 17, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 9,
#   'inhibitorKills': 1,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 35, 'pickTurn': 6},
#    {'championId': 238, 'pickTurn': 7},
#    {'championId': 81, 'pickTurn': 8},
#    {'championId': 122, 'pickTurn': 9},
#    {'championId': 360, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 360, 'pickTurn': 1},
#    {'championId': 64, 'pickTurn': 2},
#    {'championId': 114, 'pickTurn': 3},
#    {'championId': 238, 'pickTurn': 4},
#    {'championId': -1, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 11,
#   'inhibitorKills': 4,
#   'baronKills': 2,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 89, 'pickTurn': 1},
#    {'championId': 157, 'pickTurn': 2},
#    {'championId': 24, 'pickTurn': 3},
#    {'championId': 111, 'pickTurn': 4},
#    {'championId': 64, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 117, 'pickTurn': 1},
#    {'championId': 420, 'pickTurn': 2},
#    {'championId': 99, 'pickTurn': 3},
#    {'championId': 64, 'pickTurn': 4},
#    {'championId': 101, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 8,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 64, 'pickTurn': 6},
#    {'championId': 24, 'pickTurn': 7},
#    {'championId': 35, 'pickTurn': 8},
#    {'championId': 360, 'pickTurn': 9},
#    {'championId': 131, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 53, 'pickTurn': 1},
#    {'championId': 89, 'pickTurn': 2},
#    {'championId': 58, 'pickTurn': 3},
#    {'championId': 64, 'pickTurn': 4},
#    {'championId': 777, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 7,
#   'inhibitorKills': 0,
#   'baronKills': 1,
#   'dragonKills': 4,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 157, 'pickTurn': 1},
#    {'championId': 64, 'pickTurn': 2},
#    {'championId': 517, 'pickTurn': 3},
#    {'championId': 67, 'pickTurn': 4},
#    {'championId': 360, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 9,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 4,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 13, 'pickTurn': 1},
#    {'championId': 360, 'pickTurn': 2},
#    {'championId': 89, 'pickTurn': 3},
#    {'championId': 122, 'pickTurn': 4},
#    {'championId': 64, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 3,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 64, 'pickTurn': 6},
#    {'championId': 360, 'pickTurn': 7},
#    {'championId': 7, 'pickTurn': 8},
#    {'championId': 36, 'pickTurn': 9},
#    {'championId': -1, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 81, 'pickTurn': 1},
#    {'championId': 64, 'pickTurn': 2},
#    {'championId': 875, 'pickTurn': 3},
#    {'championId': 89, 'pickTurn': 4},
#    {'championId': 238, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 3,
#   'inhibitorKills': 0,
#   'baronKills': 1,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 238, 'pickTurn': 1},
#    {'championId': 54, 'pickTurn': 2},
#    {'championId': 64, 'pickTurn': 3},
#    {'championId': 111, 'pickTurn': 4},
#    {'championId': 89, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 7,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 64, 'pickTurn': 1},
#    {'championId': 35, 'pickTurn': 2},
#    {'championId': 238, 'pickTurn': 3},
#    {'championId': 56, 'pickTurn': 4},
#    {'championId': 101, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 9,
#   'inhibitorKills': 2,
#   'baronKills': 1,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 53, 'pickTurn': 6},
#    {'championId': 360, 'pickTurn': 7},
#    {'championId': 64, 'pickTurn': 8},
#    {'championId': 35, 'pickTurn': 9},
#    {'championId': -1, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 10,
#   'inhibitorKills': 2,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 11, 'pickTurn': 1},
#    {'championId': 114, 'pickTurn': 2},
#    {'championId': 238, 'pickTurn': 3},
#    {'championId': 360, 'pickTurn': 4},
#    {'championId': 89, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 5,
#   'inhibitorKills': 0,
#   'baronKills': 1,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 117, 'pickTurn': 6},
#    {'championId': 360, 'pickTurn': 7},
#    {'championId': 238, 'pickTurn': 8},
#    {'championId': 35, 'pickTurn': 9},
#    {'championId': 114, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 8,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 360, 'pickTurn': 6},
#    {'championId': 141, 'pickTurn': 7},
#    {'championId': 25, 'pickTurn': 8},
#    {'championId': 56, 'pickTurn': 9},
#    {'championId': 114, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 35, 'pickTurn': 1},
#    {'championId': 360, 'pickTurn': 2},
#    {'championId': 145, 'pickTurn': 3},
#    {'championId': 54, 'pickTurn': 4},
#    {'championId': 517, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 7, 'pickTurn': 1},
#    {'championId': 35, 'pickTurn': 2},
#    {'championId': 360, 'pickTurn': 3},
#    {'championId': 81, 'pickTurn': 4},
#    {'championId': 36, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 238, 'pickTurn': 6},
#    {'championId': 64, 'pickTurn': 7},
#    {'championId': 89, 'pickTurn': 8},
#    {'championId': 133, 'pickTurn': 9},
#    {'championId': 35, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 11,
#   'inhibitorKills': 3,
#   'baronKills': 1,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 53, 'pickTurn': 6},
#    {'championId': 58, 'pickTurn': 7},
#    {'championId': 64, 'pickTurn': 8},
#    {'championId': 238, 'pickTurn': 9},
#    {'championId': 145, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 122, 'pickTurn': 6},
#    {'championId': 56, 'pickTurn': 7},
#    {'championId': 7, 'pickTurn': 8},
#    {'championId': 238, 'pickTurn': 9},
#    {'championId': 235, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 25, 'pickTurn': 1},
#    {'championId': 90, 'pickTurn': 2},
#    {'championId': 89, 'pickTurn': 3},
#    {'championId': 55, 'pickTurn': 4},
#    {'championId': 114, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 7,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 91, 'pickTurn': 1},
#    {'championId': 157, 'pickTurn': 2},
#    {'championId': 35, 'pickTurn': 3},
#    {'championId': 89, 'pickTurn': 4},
#    {'championId': 86, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 10,
#   'inhibitorKills': 3,
#   'baronKills': 1,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 84, 'pickTurn': 1},
#    {'championId': 117, 'pickTurn': 2},
#    {'championId': 64, 'pickTurn': 3},
#    {'championId': 35, 'pickTurn': 4},
#    {'championId': 122, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 3,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 114, 'pickTurn': 6},
#    {'championId': 350, 'pickTurn': 7},
#    {'championId': 105, 'pickTurn': 8},
#    {'championId': 35, 'pickTurn': 9},
#    {'championId': 111, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 9,
#   'inhibitorKills': 2,
#   'baronKills': 1,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 157, 'pickTurn': 6},
#    {'championId': 117, 'pickTurn': 7},
#    {'championId': 81, 'pickTurn': 8},
#    {'championId': 35, 'pickTurn': 9},
#    {'championId': 875, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 3,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 67, 'pickTurn': 1},
#    {'championId': 64, 'pickTurn': 2},
#    {'championId': 56, 'pickTurn': 3},
#    {'championId': 25, 'pickTurn': 4},
#    {'championId': 238, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 91, 'pickTurn': 1},
#    {'championId': 164, 'pickTurn': 2},
#    {'championId': 35, 'pickTurn': 3},
#    {'championId': 56, 'pickTurn': 4},
#    {'championId': 4, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 10,
#   'inhibitorKills': 3,
#   'baronKills': 2,
#   'dragonKills': 4,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 101, 'pickTurn': 1},
#    {'championId': 35, 'pickTurn': 2},
#    {'championId': 64, 'pickTurn': 3},
#    {'championId': 360, 'pickTurn': 4},
#    {'championId': 517, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 7,
#   'inhibitorKills': 0,
#   'baronKills': 1,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 35, 'pickTurn': 1},
#    {'championId': 34, 'pickTurn': 2},
#    {'championId': 64, 'pickTurn': 3},
#    {'championId': 111, 'pickTurn': 4},
#    {'championId': 238, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 53, 'pickTurn': 1},
#    {'championId': 122, 'pickTurn': 2},
#    {'championId': 91, 'pickTurn': 3},
#    {'championId': 64, 'pickTurn': 4},
#    {'championId': 235, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 9,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 55, 'pickTurn': 6},
#    {'championId': 64, 'pickTurn': 7},
#    {'championId': 89, 'pickTurn': 8},
#    {'championId': 17, 'pickTurn': 9},
#    {'championId': 360, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 875, 'pickTurn': 6},
#    {'championId': 35, 'pickTurn': 7},
#    {'championId': 157, 'pickTurn': 8},
#    {'championId': 235, 'pickTurn': 9},
#    {'championId': 64, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 157, 'pickTurn': 6},
#    {'championId': 62, 'pickTurn': 7},
#    {'championId': 517, 'pickTurn': 8},
#    {'championId': 360, 'pickTurn': 9},
#    {'championId': 64, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 39, 'pickTurn': 1},
#    {'championId': 11, 'pickTurn': 2},
#    {'championId': 517, 'pickTurn': 3},
#    {'championId': 89, 'pickTurn': 4},
#    {'championId': 360, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 10,
#   'inhibitorKills': 2,
#   'baronKills': 0,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 36, 'pickTurn': 1},
#    {'championId': 238, 'pickTurn': 2},
#    {'championId': 235, 'pickTurn': 3},
#    {'championId': 54, 'pickTurn': 4},
#    {'championId': 360, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 8,
#   'inhibitorKills': 1,
#   'baronKills': 0,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 517, 'pickTurn': 6},
#    {'championId': 67, 'pickTurn': 7},
#    {'championId': 360, 'pickTurn': 8},
#    {'championId': 64, 'pickTurn': 9},
#    {'championId': 223, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 64, 'pickTurn': 6},
#    {'championId': 360, 'pickTurn': 7},
#    {'championId': 517, 'pickTurn': 8},
#    {'championId': 25, 'pickTurn': 9},
#    {'championId': -1, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 11,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 875, 'pickTurn': 6},
#    {'championId': 84, 'pickTurn': 7},
#    {'championId': 235, 'pickTurn': 8},
#    {'championId': 64, 'pickTurn': 9},
#    {'championId': 18, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 4,
#   'inhibitorKills': 0,
#   'baronKills': 1,
# ...
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 7,
#   'inhibitorKills': 1,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 21, 'pickTurn': 1},
#    {'championId': 122, 'pickTurn': 2},
#    {'championId': 360, 'pickTurn': 3},
#    {'championId': 234, 'pickTurn': 4},
#    {'championId': 238, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 238, 'pickTurn': 6},
#    {'championId': 77, 'pickTurn': 7},
#    {'championId': 114, 'pickTurn': 8},
#    {'championId': 35, 'pickTurn': 9},
#    {'championId': 89, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 64, 'pickTurn': 6},
#    {'championId': 360, 'pickTurn': 7},
#    {'championId': 516, 'pickTurn': 8},
#    {'championId': 89, 'pickTurn': 9},
#    {'championId': 238, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 5,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 104, 'pickTurn': 1},
#    {'championId': 238, 'pickTurn': 2},
#    {'championId': 54, 'pickTurn': 3},
#    {'championId': 81, 'pickTurn': 4},
#    {'championId': 80, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 114, 'pickTurn': 1},
#    {'championId': 57, 'pickTurn': 2},
#    {'championId': 517, 'pickTurn': 3},
#    {'championId': 145, 'pickTurn': 4},
#    {'championId': 360, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 523, 'pickTurn': 6},
#    {'championId': 122, 'pickTurn': 7},
#    {'championId': 21, 'pickTurn': 8},
#    {'championId': 104, 'pickTurn': 9},
#    {'championId': 7, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 10,
#   'inhibitorKills': 3,
#   'baronKills': 1,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 21, 'pickTurn': 6},
#    {'championId': 57, 'pickTurn': 7},
#    {'championId': 203, 'pickTurn': 8},
#    {'championId': 157, 'pickTurn': 9},
#    {'championId': 777, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 11, 'pickTurn': 1},
#    {'championId': 114, 'pickTurn': 2},
#    {'championId': 101, 'pickTurn': 3},
#    {'championId': 21, 'pickTurn': 4},
#    {'championId': 105, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 9,
#   'inhibitorKills': 3,
#   'baronKills': 1,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 114, 'pickTurn': 6},
#    {'championId': 876, 'pickTurn': 7},
#    {'championId': 145, 'pickTurn': 8},
#    {'championId': 33, 'pickTurn': 9},
#    {'championId': 238, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 9,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 84, 'pickTurn': 1},
#    {'championId': 266, 'pickTurn': 2},
#    {'championId': 55, 'pickTurn': 3},
#    {'championId': 80, 'pickTurn': 4},
#    {'championId': 21, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 35, 'pickTurn': 6},
#    {'championId': 238, 'pickTurn': 7},
#    {'championId': 60, 'pickTurn': 8},
#    {'championId': 21, 'pickTurn': 9},
#    {'championId': 58, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 7,
#   'inhibitorKills': 1,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 20, 'pickTurn': 1},
#    {'championId': 236, 'pickTurn': 2},
#    {'championId': 9, 'pickTurn': 3},
#    {'championId': 34, 'pickTurn': 4},
#    {'championId': 114, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': True,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 7,
#   'inhibitorKills': 1,
#   'baronKills': 1,
#   'dragonKills': 4,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 2, 'pickTurn': 1},
#    {'championId': 238, 'pickTurn': 2},
#    {'championId': 157, 'pickTurn': 3},
#    {'championId': 21, 'pickTurn': 4},
#    {'championId': 80, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 8,
#   'inhibitorKills': 1,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 2,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 360, 'pickTurn': 6},
#    {'championId': 114, 'pickTurn': 7},
#    {'championId': 2, 'pickTurn': 8},
#    {'championId': 84, 'pickTurn': 9},
#    {'championId': 11, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 21, 'pickTurn': 1},
#    {'championId': 67, 'pickTurn': 2},
#    {'championId': 2, 'pickTurn': 3},
#    {'championId': 34, 'pickTurn': 4},
#    {'championId': 133, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 2, 'pickTurn': 1},
#    {'championId': 238, 'pickTurn': 2},
#    {'championId': 145, 'pickTurn': 3},
#    {'championId': 114, 'pickTurn': 4},
#    {'championId': 63, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 3,
#   'inhibitorKills': 0,
#   'baronKills': 1,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 777, 'pickTurn': 6},
#    {'championId': 21, 'pickTurn': 7},
#    {'championId': 121, 'pickTurn': 8},
#    {'championId': 39, 'pickTurn': 9},
#    {'championId': 111, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 11,
#   'inhibitorKills': 3,
#   'baronKills': 3,
#   'dragonKills': 3,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 114, 'pickTurn': 1},
#    {'championId': 25, 'pickTurn': 2},
#    {'championId': 236, 'pickTurn': 3},
#    {'championId': 555, 'pickTurn': 4},
#    {'championId': 157, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 114, 'pickTurn': 1},
#    {'championId': 111, 'pickTurn': 2},
#    {'championId': 2, 'pickTurn': 3},
#    {'championId': 53, 'pickTurn': 4},
#    {'championId': 517, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 0,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 122, 'pickTurn': 6},
#    {'championId': 238, 'pickTurn': 7},
#    {'championId': 57, 'pickTurn': 8},
#    {'championId': 114, 'pickTurn': 9},
#    {'championId': 89, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 114, 'pickTurn': 6},
#    {'championId': 84, 'pickTurn': 7},
#    {'championId': 60, 'pickTurn': 8},
#    {'championId': 526, 'pickTurn': 9},
#    {'championId': 202, 'pickTurn': 10}]},
#  {'teamId': 200,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 5,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 21, 'pickTurn': 6},
#    {'championId': 57, 'pickTurn': 7},
#    {'championId': 89, 'pickTurn': 8},
#    {'championId': 266, 'pickTurn': 9},
#    {'championId': 61, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 2,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 360, 'pickTurn': 1},
#    {'championId': 238, 'pickTurn': 2},
#    {'championId': 80, 'pickTurn': 3},
#    {'championId': 114, 'pickTurn': 4},
#    {'championId': 2, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 84, 'pickTurn': 1},
#    {'championId': 526, 'pickTurn': 2},
#    {'championId': 202, 'pickTurn': 3},
#    {'championId': 57, 'pickTurn': 4},
#    {'championId': 80, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 3,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 202, 'pickTurn': 1},
#    {'championId': 104, 'pickTurn': 2},
#    {'championId': 57, 'pickTurn': 3},
#    {'championId': 54, 'pickTurn': 4},
#    {'championId': 105, 'pickTurn': 5}]},
#  {'teamId': 200,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': True,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': True,
#   'towerKills': 7,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 2,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 236, 'pickTurn': 6},
#    {'championId': 141, 'pickTurn': 7},
#    {'championId': 80, 'pickTurn': 8},
#    {'championId': 114, 'pickTurn': 9},
#    {'championId': 202, 'pickTurn': 10}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 11,
#   'inhibitorKills': 3,
#   'baronKills': 0,
#   'dragonKills': 4,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 9, 'pickTurn': 1},
#    {'championId': 120, 'pickTurn': 2},
#    {'championId': 202, 'pickTurn': 3},
#    {'championId': -1, 'pickTurn': 4},
#    {'championId': 57, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': True,
#   'firstBaron': True,
#   'firstDragon': True,
#   'firstRiftHerald': False,
#   'towerKills': 10,
#   'inhibitorKills': 2,
#   'baronKills': 2,
#   'dragonKills': 4,
#   'vilemawKills': 0,
#   'riftHeraldKills': 0,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 114, 'pickTurn': 1},
#    {'championId': 51, 'pickTurn': 2},
#    {'championId': 2, 'pickTurn': 3},
#    {'championId': 238, 'pickTurn': 4},
#    {'championId': 202, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Fail',
#   'firstBlood': True,
#   'firstTower': False,
#   'firstInhibitor': False,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': True,
#   'towerKills': 1,
#   'inhibitorKills': 0,
#   'baronKills': 0,
#   'dragonKills': 0,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 99, 'pickTurn': 1},
#    {'championId': 114, 'pickTurn': 2},
#    {'championId': 104, 'pickTurn': 3},
#    {'championId': 360, 'pickTurn': 4},
#    {'championId': 412, 'pickTurn': 5}]},
#  {'teamId': 100,
#   'win': 'Win',
#   'firstBlood': False,
#   'firstTower': False,
#   'firstInhibitor': True,
#   'firstBaron': False,
#   'firstDragon': False,
#   'firstRiftHerald': False,
#   'towerKills': 11,
#   'inhibitorKills': 3,
#   'baronKills': 0,
#   'dragonKills': 1,
#   'vilemawKills': 0,
#   'riftHeraldKills': 1,
#   'dominionVictoryScore': 0,
#   'bans': [{'championId': 104, 'pickTurn': 1},
#    {'championId': 777, 'pickTurn': 2},
#    {'championId': 360, 'pickTurn': 3},
#    {'championId': 54, 'pickTurn': 4},
#    {'championId': 35, 'pickTurn': 5}]}]

# %%
from pymongo import MongoClient
conn = MongoClient('localhost', 27017)

# %% [markdown]
# # collection 삭제하고 다시 넣어야함

# %%
# lol 데이터베스 생성
db = conn.lol

# score collection 생성
col_score = db.score

# team_score collection 생성 
col_team_score = db.team_score

# socre collection에 detail 추가 
col_score.insert_many(a)

# team_score collection에 detail 추가 
col_team_score.insert_many(c)

# %%
# DB에 잘 올라갔는지 확인 / 게임 승리시 챔피언 번호 가져오기

a = list(col_score.find({ 'stats.win': True }))
b = []
for i in a:
    b.append(i['championId'])

b.sort()
b
# a = list(col_score.find({ 'stats.win': True, 'championId': 35 })) #
# Out:
# [5,
#  5,
#  5,
#  5,
#  5,
#  5,
#  6,
#  16,
#  17,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  18,
#  19,
#  19,
#  19,
#  19,
#  19,
#  19,
#  24,
#  24,
#  24,
#  24,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  31,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  35,
#  36,
#  38,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  51,
#  54,
#  54,
#  54,
#  56,
#  56,
#  56,
#  56,
#  56,
#  56,
#  56,
#  56,
#  56,
#  56,
#  56,
#  60,
#  60,
#  60,
#  60,
#  60,
#  61,
#  61,
#  67,
#  67,
#  67,
#  67,
#  67,
#  67,
#  67,
#  67,
#  67,
#  67,
#  67,
#  67,
#  67,
#  67,
#  67,
#  67,
#  67,
#  67,
#  67,
#  67,
#  67,
#  67,
#  67,
#  67,
#  74,
#  75,
#  75,
#  75,
#  75,
#  75,
#  77,
#  77,
#  77,
#  77,
#  77,
#  77,
#  77,
#  77,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  81,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  83,
#  86,
#  86,
#  86,
#  89,
#  90,
#  98,
#  98,
#  98,
#  98,
#  101,
#  106,
#  106,
#  107,
#  107,
#  131,
#  133,
#  133,
#  133,
#  133,
#  136,
#  141,
#  141,
#  141,
#  141,
#  145,
#  145,
#  145,
#  145,
#  145,
#  145,
#  145,
#  145,
#  145,
#  145,
#  145,
#  145,
#  145,
#  145,
#  145,
#  145,
#  145,
#  150,
#  163,
#  164,
#  222,
#  222,
#  222,
#  222,
#  222,
#  222,
#  234,
#  234,
#  234,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  236,
#  412,
#  429,
#  429,
#  429,
#  429,
#  429,
#  429,
#  429,
#  429,
#  429,
#  516,
#  516,
#  516,
#  517,
#  517,
#  517,
#  517,
#  875,
#  875,
#  875,
#  875,
#  875,
#  876,
#  887,
#  887,
#  887,
#  887,
#  887,
#  887]

# %%
# ChampionId가 숫자로 되어 있어 이름으로 바꾸기 위해 api 활용
# apiDefault['key']

# 챔피언 이름 정보를 받아오기 위해 현재 사용 중인 버전 확인 필요
r = requests.get('https://ddragon.leagueoflegends.com/api/versions.json') # version data 확인
current_ver = r.json()[0] # 현재 최신 버전 확인
current_ver
# Out:
# '11.14.1'

# %%
r = requests.get('http://ddragon.leagueoflegends.com/cdn/{}/data/ko_KR/champion.json'.format(current_ver))
data = r.json()
cham_df = pd.DataFrame(data)
cham_df.head()
# Out:
#              type             format  version  \
# Aatrox   champion  standAloneComplex  11.14.1
# Ahri     champion  standAloneComplex  11.14.1
# Akali    champion  standAloneComplex  11.14.1
# Alistar  champion  standAloneComplex  11.14.1
# Amumu    champion  standAloneComplex  11.14.1
#
#                                                       data
# Aatrox   {'version': '11.14.1', 'id': 'Aatrox', 'key': ...
# Ahri     {'version': '11.14.1', 'id': 'Ahri', 'key': '1...
# Akali    {'version': '11.14.1', 'id': 'Akali', 'key': '...
# Alistar  {'version': '11.14.1', 'id': 'Alistar', 'key':...
# Amumu    {'version': '11.14.1', 'id': 'Amumu', 'key': '...

# %%
r = requests.get('http://ddragon.leagueoflegends.com/cdn/{}/data/ko_KR/summoner.json'.format(current_ver))
data = r.json()
spell_df = pd.DataFrame(data)
spell_df.head()
# Out:
#                      type  version  \
# SummonerBarrier  summoner  11.14.1
# SummonerBoost    summoner  11.14.1
# SummonerDot      summoner  11.14.1
# SummonerExhaust  summoner  11.14.1
# SummonerFlash    summoner  11.14.1
#
#                                                               data
# SummonerBarrier  {'id': 'SummonerBarrier', 'name': '방어막', 'desc...
# SummonerBoost    {'id': 'SummonerBoost', 'name': '정화', 'descrip...
# SummonerDot      {'id': 'SummonerDot', 'name': '점화', 'descripti...
# SummonerExhaust  {'id': 'SummonerExhaust', 'name': '탈진', 'descr...
# SummonerFlash    {'id': 'SummonerFlash', 'name': '점멸', 'descrip...

# %%
# cham_df에 data 컬럼안에 필요한 정보가 있어 data 컬럼안에 내용을 꺼내서 기존의 cham_df와 대치 후 필요 없는 컬럼 삭제

# data 컬럼에 필요한 내용 추출
cham_list = {}
for i, cham in enumerate(cham_df.data):
    cham_list[i] = pd.Series(cham)
    
cham_df1 = pd.DataFrame(cham_list)

# cham_df와 같은 형태가 되도록 전치
cham_df = cham_df1.T

# 필요 없는 행 삭제(id, key, name 컬럼 제외 삭제)
cham_df.drop(['version', 'title', 'blurb', 'info', 'image', 'tags', 'partype', 'stats'], axis = 1, inplace = True)

# %%
cham_df.to_csv('/Users/bj/New Project/data/id.csv')

# %%
cham_df[cham_df['name'] == '뽀삐']
# Out:
#        id key name
# 89  Poppy  78   뽀삐

# %%
r = requests.get('http://ddragon.leagueoflegends.com/cdn/{}/data/ko_KR/summoner.json'.format(current_ver))
data = r.json()
spell_df = pd.DataFrame(data)
spell_df.head()
# Out:
#                      type  version  \
# SummonerBarrier  summoner  11.14.1
# SummonerBoost    summoner  11.14.1
# SummonerDot      summoner  11.14.1
# SummonerExhaust  summoner  11.14.1
# SummonerFlash    summoner  11.14.1
#
#                                                               data
# SummonerBarrier  {'id': 'SummonerBarrier', 'name': '방어막', 'desc...
# SummonerBoost    {'id': 'SummonerBoost', 'name': '정화', 'descrip...
# SummonerDot      {'id': 'SummonerDot', 'name': '점화', 'descripti...
# SummonerExhaust  {'id': 'SummonerExhaust', 'name': '탈진', 'descr...
# SummonerFlash    {'id': 'SummonerFlash', 'name': '점멸', 'descrip...

# %%
spell_list = {}
for i, spell in enumerate(spell_df.data):
    spell_list[i] = pd.Series(spell)
    
spell_df1 = pd.DataFrame(spell_list)

# # cham_df와 같은 형태가 되도록 전치
spell_df = spell_df1.T

# 필요 없는 행 삭제(id, key, name 컬럼 제외 삭제)
spell_df.drop(['description', 'tooltip', 'maxrank', 'cooldown', 'cooldownBurn','cost', 'costBurn',
               'datavalues', 'effect', 'effectBurn', 'vars', 'summonerLevel', 'modes', 'costType',
               'maxammo', 'range', 'rangeBurn', 'image', 'resource'], axis = 1, inplace = True)
spell_df = spell_df[['key', 'name', 'id']]

# %%
spell_df
# Out:
#    key         name                            id
# 0   21          방어막               SummonerBarrier
# 1    1           정화                 SummonerBoost
# 2   14           점화                   SummonerDot
# 3    3           탈진               SummonerExhaust
# 4    4           점멸                 SummonerFlash
# 5    6          유체화                 SummonerHaste
# 6    7           회복                  SummonerHeal
# 7   13           총명                  SummonerMana
# 8   30       왕을 향해!            SummonerPoroRecall
# 9   31       포로 던지기             SummonerPoroThrow
# 10  11           강타                 SummonerSmite
# 11  39           표식  SummonerSnowURFSnowball_Mark
# 12  32           표식              SummonerSnowball
# 13  12         순간이동              SummonerTeleport
# 14  54  Placeholder  Summoner_UltBook_Placeholder

# %%
spell_df.to_csv('/Users/bj/New Project/data/spell.csv')

# %%
qq = []

qq.append(dict(cham_df.iloc[:,0]))
qq.append(dict(cham_df.iloc[:,1]))
qq.append(dict(cham_df.iloc[:,2]))

print(qq)
# Out:
# [{0: 'Aatrox', 1: 'Ahri', 2: 'Akali', 3: 'Alistar', 4: 'Amumu', 5: 'Anivia', 6: 'Annie', 7: 'Aphelios', 8: 'Ashe', 9: 'AurelionSol', 10: 'Azir', 11: 'Bard', 12: 'Blitzcrank', 13: 'Brand', 14: 'Braum', 15: 'Caitlyn', 16: 'Camille', 17: 'Cassiopeia', 18: 'Chogath', 19: 'Corki', 20: 'Darius', 21: 'Diana', 22: 'DrMundo', 23: 'Draven', 24: 'Ekko', 25: 'Elise', 26: 'Evelynn', 27: 'Ezreal', 28: 'Fiddlesticks', 29: 'Fiora', 30: 'Fizz', 31: 'Galio', 32: 'Gangplank', 33: 'Garen', 34: 'Gnar', 35: 'Gragas', 36: 'Graves', 37: 'Gwen', 38: 'Hecarim', 39: 'Heimerdinger', 40: 'Illaoi', 41: 'Irelia', 42: 'Ivern', 43: 'Janna', 44: 'JarvanIV', 45: 'Jax', 46: 'Jayce', 47: 'Jhin', 48: 'Jinx', 49: 'Kaisa', 50: 'Kalista', 51: 'Karma', 52: 'Karthus', 53: 'Kassadin', 54: 'Katarina', 55: 'Kayle', 56: 'Kayn', 57: 'Kennen', 58: 'Khazix', 59: 'Kindred', 60: 'Kled', 61: 'KogMaw', 62: 'Leblanc', 63: 'LeeSin', 64: 'Leona', 65: 'Lillia', 66: 'Lissandra', 67: 'Lucian', 68: 'Lulu', 69: 'Lux', 70: 'Malphite', 71: 'Malzahar', 72: 'Maokai', 73: 'MasterYi', 74: 'MissFortune', 75: 'MonkeyKing', 76: 'Mordekaiser', 77: 'Morgana', 78: 'Nami', 79: 'Nasus', 80: 'Nautilus', 81: 'Neeko', 82: 'Nidalee', 83: 'Nocturne', 84: 'Nunu', 85: 'Olaf', 86: 'Orianna', 87: 'Ornn', 88: 'Pantheon', 89: 'Poppy', 90: 'Pyke', 91: 'Qiyana', 92: 'Quinn', 93: 'Rakan', 94: 'Rammus', 95: 'RekSai', 96: 'Rell', 97: 'Renekton', 98: 'Rengar', 99: 'Riven', 100: 'Rumble', 101: 'Ryze', 102: 'Samira', 103: 'Sejuani', 104: 'Senna', 105: 'Seraphine', 106: 'Sett', 107: 'Shaco', 108: 'Shen', 109: 'Shyvana', 110: 'Singed', 111: 'Sion', 112: 'Sivir', 113: 'Skarner', 114: 'Sona', 115: 'Soraka', 116: 'Swain', 117: 'Sylas', 118: 'Syndra', 119: 'TahmKench', 120: 'Taliyah', 121: 'Talon', 122: 'Taric', 123: 'Teemo', 124: 'Thresh', 125: 'Tristana', 126: 'Trundle', 127: 'Tryndamere', 128: 'TwistedFate', 129: 'Twitch', 130: 'Udyr', 131: 'Urgot', 132: 'Varus', 133: 'Vayne', 134: 'Veigar', 135: 'Velkoz', 136: 'Vi', 137: 'Viego', 138: 'Viktor', 139: 'Vladimir', 140: 'Volibear', 141: 'Warwick', 142: 'Xayah', 143: 'Xerath', 144: 'XinZhao', 145: 'Yasuo', 146: 'Yone', 147: 'Yorick', 148: 'Yuumi', 149: 'Zac', 150: 'Zed', 151: 'Ziggs', 152: 'Zilean', 153: 'Zoe', 154: 'Zyra'}, {0: '266', 1: '103', 2: '84', 3: '12', 4: '32', 5: '34', 6: '1', 7: '523', 8: '22', 9: '136', 10: '268', 11: '432', 12: '53', 13: '63', 14: '201', 15: '51', 16: '164', 17: '69', 18: '31', 19: '42', 20: '122', 21: '131', 22: '36', 23: '119', 24: '245', 25: '60', 26: '28', 27: '81', 28: '9', 29: '114', 30: '105', 31: '3', 32: '41', 33: '86', 34: '150', 35: '79', 36: '104', 37: '887', 38: '120', 39: '74', 40: '420', 41: '39', 42: '427', 43: '40', 44: '59', 45: '24', 46: '126', 47: '202', 48: '222', 49: '145', 50: '429', 51: '43', 52: '30', 53: '38', 54: '55', 55: '10', 56: '141', 57: '85', 58: '121', 59: '203', 60: '240', 61: '96', 62: '7', 63: '64', 64: '89', 65: '876', 66: '127', 67: '236', 68: '117', 69: '99', 70: '54', 71: '90', 72: '57', 73: '11', 74: '21', 75: '62', 76: '82', 77: '25', 78: '267', 79: '75', 80: '111', 81: '518', 82: '76', 83: '56', 84: '20', 85: '2', 86: '61', 87: '516', 88: '80', 89: '78', 90: '555', 91: '246', 92: '133', 93: '497', 94: '33', 95: '421', 96: '526', 97: '58', 98: '107', 99: '92', 100: '68', 101: '13', 102: '360', 103: '113', 104: '235', 105: '147', 106: '875', 107: '35', 108: '98', 109: '102', 110: '27', 111: '14', 112: '15', 113: '72', 114: '37', 115: '16', 116: '50', 117: '517', 118: '134', 119: '223', 120: '163', 121: '91', 122: '44', 123: '17', 124: '412', 125: '18', 126: '48', 127: '23', 128: '4', 129: '29', 130: '77', 131: '6', 132: '110', 133: '67', 134: '45', 135: '161', 136: '254', 137: '234', 138: '112', 139: '8', 140: '106', 141: '19', 142: '498', 143: '101', 144: '5', 145: '157', 146: '777', 147: '83', 148: '350', 149: '154', 150: '238', 151: '115', 152: '26', 153: '142', 154: '143'}, {0: '아트록스', 1: '아리', 2: '아칼리', 3: '알리스타', 4: '아무무', 5: '애니비아', 6: '애니', 7: '아펠리오스', 8: '애쉬', 9: '아우렐리온 솔', 10: '아지르', 11: '바드', ...

# %%
def IdToName(list):
    for i in range(len(list)):
        print(cham_df[cham_df['key'] == str(list[i])]['name'].values)

# %%
list(col_score.find({ 'stats.win': True, 'championId': 78 }))
# Out:
# [{'_id': ObjectId('60f661fab831580f0b9132d7'),
#   'participantId': 3,
#   'teamId': 100,
#   'championId': 78,
#   'spell1Id': 4,
#   'spell2Id': 11,
#   'stats': {'participantId': 3,
#    'win': True,
#    'item0': 6632,
#    'item1': 2031,
#    'item2': 3047,
#    'item3': 3742,
#    'item4': 1011,
#    'item5': 3076,
#    'item6': 3364,
#    'kills': 4,
#    'deaths': 5,
#    'assists': 11,
#    'largestKillingSpree': 3,
#    'largestMultiKill': 1,
#    'killingSprees': 1,
#    'longestTimeSpentLiving': 684,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 127974,
#    'magicDamageDealt': 9341,
#    'physicalDamageDealt': 98495,
#    'trueDamageDealt': 20137,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 8684,
#    'magicDamageDealtToChampions': 614,
#    'physicalDamageDealtToChampions': 7281,
#    'trueDamageDealtToChampions': 788,
#    'totalHeal': 7909,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 23281,
#    'damageDealtToObjectives': 33929,
#    'damageDealtToTurrets': 1545,
#    'visionScore': 11,
#    'timeCCingOthers': 27,
#    'totalDamageTaken': 22308,
#    'magicalDamageTaken': 6806,
#    'physicalDamageTaken': 14267,
#    'trueDamageTaken': 1234,
#    'goldEarned': 9744,
#    'goldSpent': 9575,
#    'turretKills': 2,
#    'inhibitorKills': 1,
#    'totalMinionsKilled': 27,
#    'neutralMinionsKilled': 98,
#    'neutralMinionsKilledTeamJungle': 39,
#    'neutralMinionsKilledEnemyJungle': 26,
#    'totalTimeCrowdControlDealt': 563,
#    'champLevel': 14,
#    'visionWardsBoughtInGame': 1,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 2,
#    'wardsKilled': 1,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 1,
#    'playerScore8': 0,
#    'playerScore9': 1,
#    'perk0': 8128,
#    'perk0Var1': 421,
#    'perk0Var2': 10,
#    'perk0Var3': 0,
#    'perk1': 8126,
#    'perk1Var1': 449,
#    'perk1Var2': 0,
#    'perk1Var3': 0,
#    'perk2': 8138,
#    'perk2Var1': 18,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8105,
#    'perk3Var1': 13,
#    'perk3Var2': 5,
#    'perk3Var3': 0,
#    'perk4': 8234,
#    'perk4Var1': 10197,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8232,
#    'perk5Var1': 7,
#    'perk5Var2': 0,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8100,
#    'perkSubStyle': 8200,
#    'statPerk0': 5008,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 3,
#    'creepsPerMinDeltas': {'10-20': 2.2, '0-10': 0.2},
#    'xpPerMinDeltas': {'10-20': 413.8, '0-10': 309.1},
#    'goldPerMinDeltas': {'10-20': 331.6, '0-10': 336.70000000000005},
#    'csDiffPerMinDeltas': {'10-20': 0.10000000000000009, '0-10': 0.1},
#    'xpDiffPerMinDeltas': {'10-20': -131.39999999999998,
#     '0-10': 31.099999999999994},
#    'damageTakenPerMinDeltas': {'10-20': 755.7, '0-10': 548.2},
#    'damageTakenDiffPerMinDeltas': {'10-20': -143.80000000000007,
#     '0-10': -266.7},
#    'role': 'NONE',
#    'lane': 'JUNGLE'}},
#  {'_id': ObjectId('60f661fab831580f0b9132df'),
#   'participantId': 4,
#   'teamId': 100,
#   'championId': 78,
#   'spell1Id': 4,
#   'spell2Id': 11,
#   'stats': {'participantId': 4,
#    'win': True,
#    'item0': 6632,
#    'item1': 2031,
#    'item2': 3047,
#    'item3': 3742,
#    'item4': 3076,
#    'item5': 1011,
#    'item6': 3364,
#    'kills': 11,
#    'deaths': 5,
#    'assists': 13,
#    'largestKillingSpree': 4,
#    'largestMultiKill': 2,
#    'killingSprees': 4,
#    'longestTimeSpentLiving': 804,
#    'doubleKills': 2,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 99701,
#    'magicDamageDealt': 8231,
#    'physicalDamageDealt': 80426,
#    'trueDamageDealt': 11043,
#    'largestCriticalStrike': 2,
#    'totalDamageDealtToChampions': 15418,
#    'magicDamageDealtToChampions': 1304,
#    'physicalDamageDealtToChampions': 12921,
#    'trueDamageDealtToChampions': 1192,
#    'totalHeal': 6246,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 31716,
#    'damageDealtToObjectives': 17664,
#    'damageDealtToTurrets': 1491,
#    'visionScore': 15,
#    'timeCCingOthers': 29,
#    'totalDamageTaken': 25163,
#    'magicalDamageTaken': 7124,
#    'physicalDamageTaken': 16497,
#    'trueDamageTaken': 1541,
#    'goldEarned': 11591,
#    'goldSpent': 9575,
#    'turretKills': 0,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 24,
#    'neutralMinionsKilled': 85,
#    'neutralMinionsKilledTeamJungle': 64,
#    'neutralMinionsKilledEnemyJungle': 0,
#    'totalTimeCrowdControlDealt': 463,
#    'champLevel': 15,
#    'visionWardsBoughtInGame': 1,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 3,
#    'wardsKilled': 1,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 1,
#    'playerScore8': 0,
#    'playerScore9': 1,
#    'perk0': 8128,
#    'perk0Var1': 1425,
#    'perk0Var2': 24,
#    'perk0Var3': 0,
#    'perk1': 8126,
#    'perk1Var1': 723,
#    'perk1Var2': 0,
#    'perk1Var3': 0,
#    'perk2': 8138,
#    'perk2Var1': 18,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8105,
#    'perk3Var1': 13,
#    'perk3Var2': 5,
#    'perk3Var3': 0,
#    'perk4': 8234,
#    'perk4Var1': 9983,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8232,
#    'perk5Var1': 4,
#    'perk5Var2': 30,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8100,
#    'perkSubStyle': 8200,
#    'statPerk0': 5008,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 4,
#    'creepsPerMinDeltas': {'10-20': 0.9, '0-10': 0.8},
#    'xpPerMinDeltas': {'10-20': 458.5, '0-10': 337.4},
#    'goldPerMinDeltas': {'10-20': 388.7, '0-10': 352.4},
#    'csDiffPerMinDeltas': {'10-20': -0.5, '0-10': 0.5},
#    'xpDiffPerMinDeltas': {'10-20': 28.599999999999994,
#     '0-10': 38.69999999999999},
#    'damageTakenPerMinDeltas': {'10-20': 867.6, '0-10': 559.2},
#    'damageTakenDiffPerMinDeltas': {'10-20': 284, '0-10': 6.400000000000006},
#    'role': 'NONE',
#    'lane': 'JUNGLE'}},
#  {'_id': ObjectId('60f661fab831580f0b9132e2'),
#   'participantId': 2,
#   'teamId': 100,
#   'championId': 78,
#   'spell1Id': 4,
#   'spell2Id': 11,
#   'stats': {'participantId': 2,
#    'win': True,
#    'item0': 6632,
#    'item1': 2031,
#    'item2': 3047,
#    'item3': 4401,
#    'item4': 1028,
#    'item5': 0,
#    'item6': 3364,
#    'kills': 4,
#    'deaths': 4,
#    'assists': 5,
#    'largestKillingSpree': 2,
#    'largestMultiKill': 1,
#    'killingSprees': 1,
#    'longestTimeSpentLiving': 353,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 115541,
#    'magicDamageDealt': 9978,
#    'physicalDamageDealt': 90621,
#    'trueDamageDealt': 14942,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 6463,
#    'magicDamageDealtToChampions': 630,
#    'physicalDamageDealtToChampions': 5395,
#    'trueDamageDealtToChampions': 438,
#    'totalHeal': 8463,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 21793,
#    'damageDealtToObjectives': 23208,
#    'damageDealtToTurrets': 1351,
#    'visionScore': 22,
#    'timeCCingOthers': 12,
#    'totalDamageTaken': 19952,
#    'magicalDamageTaken': 5344,
#    'physicalDamageTaken': 14457,
#    'trueDamageTaken': 150,
#    'goldEarned': 9732,
#    'goldSpent': 8275,
#    'turretKills': 1,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 30,
#    'neutralMinionsKilled': 124,
#    'neutralMinionsKilledTeamJungle': 85,
#    'neutralMinionsKilledEnemyJungle': 4,
#    'totalTimeCrowdControlDealt': 493,
#    'champLevel': 14,
#    'visionWardsBoughtInGame': 1,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 4,
#    'wardsKilled': 6,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': True,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': True,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 1,
#    'perk0': 8021,
#    'perk0Var1': 1201,
#    'perk0Var2': 0,
#    'perk0Var3': 0,
#    'perk1': 8009,
#    'perk1Var1': 932,
#    'perk1Var2': 0,
#    'perk1Var3': 0,
#    'perk2': 9103,
#    'perk2Var1': 21,
#    'perk2Var2': 50,
#    'perk2Var3': 0,
#    'perk3': 8014,
#    'perk3Var1': 233,
#    'perk3Var2': 0,
#    'perk3Var3': 0,
#    'perk4': 8139,
#    'perk4Var1': 368,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8135,
#    'perk5Var1': 1910,
#    'perk5Var2': 5,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8000,
#    'perkSubStyle': 8100,
#    'statPerk0': 5005,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 2,
#    'creepsPerMinDeltas': {'10-20': 0.8, '0-10': 0.8},
#    'xpPerMinDeltas': {'10-20': 422.1, '0-10': 354.8},
#    'goldPerMinDeltas': {'10-20': 291.9, '0-10': 324},
#    'csDiffPerMinDeltas': {'10-20': 8.326672684688674e-17, '0-10': -1.1},
#    'xpDiffPerMinDeltas': {'10-20': -91.89999999999998, '0-10': -44},
#    'damageTakenPerMinDeltas': {'10-20': 649.9, '0-10': 566.1},
#    'damageTakenDiffPerMinDeltas': {'10-20': -557.7,
#     '0-10': -20.399999999999977},
#    'role': 'NONE',
#    'lane': 'JUNGLE'}},
#  {'_id': ObjectId('60f661fab831580f0b9132e9'),
#   'participantId': 9,
#   'teamId': 200,
#   'championId': 78,
#   'spell1Id': 4,
#   'spell2Id': 11,
#   'stats': {'participantId': 9,
#    'win': True,
#    'item0': 6632,
#    'item1': 3143,
#    'item2': 3742,
#    'item3': 4401,
#    'item4': 3111,
#    'item5': 3075,
#    'item6': 3364,
#    'kills': 16,
#    'deaths': 4,
#    'assists': 22,
#    'largestKillingSpree': 7,
#    'largestMultiKill': 2,
#    'killingSprees': 3,
#    'longestTimeSpentLiving': 707,
#    'doubleKills': 2,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 210748,
#    'magicDamageDealt': 19114,
#    'physicalDamageDealt': 154238,
#    'trueDamageDealt': 37395,
#    'largestCriticalStrike': 24,
#    'totalDamageDealtToChampions': 41044,
#    'magicDamageDealtToChampions': 4363,
#    'physicalDamageDealtToChampions': 32379,
#    'trueDamageDealtToChampions': 4301,
#    'totalHeal': 18291,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 70154,
#    'damageDealtToObjectives': 25973,
#    'damageDealtToTurrets': 1749,
#    'visionScore': 38,
#    'timeCCingOthers': 67,
#    'totalDamageTaken': 42479,
#    'magicalDamageTaken': 5818,
#    'physicalDamageTaken': 33248,
#    'trueDamageTaken': 3412,
#    'goldEarned': 19645,
#    'goldSpent': 17750,
#    'turretKills': 1,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 64,
#    'neutralMinionsKilled': 140,
#    'neutralMinionsKilledTeamJungle': 95,
#    'neutralMinionsKilledEnemyJungle': 0,
#    'totalTimeCrowdControlDealt': 760,
#    'champLevel': 18,
#    'visionWardsBoughtInGame': 2,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 6,
#    'wardsKilled': 11,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8128,
#    'perk0Var1': 2341,
#    'perk0Var2': 33,
#    'perk0Var3': 0,
#    'perk1': 8126,
#    'perk1Var1': 1810,
#    'perk1Var2': 0,
#    'perk1Var3': 0,
#    'perk2': 8138,
#    'perk2Var1': 18,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8105,
#    'perk3Var1': 13,
#    'perk3Var2': 5,
#    'perk3Var3': 0,
#    'perk4': 8234,
#    'perk4Var1': 24595,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8232,
#    'perk5Var1': 8,
#    'perk5Var2': 30,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8100,
#    'perkSubStyle': 8200,
#    'statPerk0': 5008,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 9,
#    'creepsPerMinDeltas': {'10-20': 1.3,
#     '0-10': 0,
#     '30-end': 2.1,
#     '20-30': 2.6},
#    'xpPerMinDeltas': {'10-20': 545.3,
#     '0-10': 292.4,
#     '30-end': 724.3,
#     '20-30': 528.8},
#    'goldPerMinDeltas': {'10-20': 538.2,
#     '0-10': 268.5,
#     '30-end': 385.2,
#     '20-30': 505.79999999999995},
#    'csDiffPerMinDeltas': {'10-20': -0.09999999999999998,
#     '0-10': -0.30000000000000004,
#     '30-end': -1.8,
#     '20-30': 0.09999999999999987},
#    'xpDiffPerMinDeltas': {'10-20': 108.69999999999999,
#     '0-10': -4.700000000000003,
#     '30-end': 94.19999999999993,
#     '20-30': -73.19999999999999},
#    'damageTakenPerMinDeltas': {'10-20': 826.3,
#     '0-10': 638.5,
#     '30-end': 1340.1,
#     '20-30': 976.6},
#    'damageTakenDiffPerMinDeltas': {'10-20': -257.3999999999999,
#     '0-10': -108.70000000000002,
#     '30-end': -307.69999999999993,
#     '20-30': -25.399999999999977},
#    'role': 'NONE',
#    'lane': 'JUNGLE'}},
#  {'_id': ObjectId('60f661fab831580f0b9132f5'),
#   'participantId': 4,
#   'teamId': 100,
#   'championId': 78,
#   'spell1Id': 4,
#   'spell2Id': 11,
#   'stats': {'participantId': 4,
#    'win': True,
#    'item0': 6632,
#    'item1': 3742,
#    'item2': 4401,
#    'item3': 3111,
#    'item4': 3076,
#    'item5': 1028,
#    'item6': 3364,
#    'kills': 8,
#    'deaths': 6,
#    'assists': 18,
#    'largestKillingSpree': 3,
#    'largestMultiKill': 2,
#    'killingSprees': 2,
#    'longestTimeSpentLiving': 514,
#    'doubleKills': 1,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 136753,
#    'magicDamageDealt': 11520,
#    'physicalDamageDealt': 111653,
#    'trueDamageDealt': 13580,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 23846,
#    'magicDamageDealtToChampions': 2316,
#    'physicalDamageDealtToChampions': 19131,
#    'trueDamageDealtToChampions': 2397,
#    'totalHeal': 10160,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 38889,
#    'damageDealtToObjectives': 13941,
#    'damageDealtToTurrets': 1671,
#    'visionScore': 43,
#    'timeCCingOthers': 57,
#    'totalDamageTaken': 31408,
#    'magicalDamageTaken': 11753,
#    'physicalDamageTaken': 17809,
#    'trueDamageTaken': 1845,
#    'goldEarned': 13339,
#    'goldSpent': 12125,
#    'turretKills': 0,
#    'inhibitorKills': 2,
#    'totalMinionsKilled': 41,
#    'neutralMinionsKilled': 108,
#    'neutralMinionsKilledTeamJungle': 76,
#    'neutralMinionsKilledEnemyJungle': 8,
#    'totalTimeCrowdControlDealt': 642,
#    'champLevel': 17,
#    'visionWardsBoughtInGame': 4,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 4,
#    'wardsKilled': 8,
#    'firstBloodKill': True,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8128,
#    'perk0Var1': 1412,
#    'perk0Var2': 26,
#    'perk0Var3': 0,
#    'perk1': 8126,
#    'perk1Var1': 1160,
#    'perk1Var2': 0,
#    'perk1Var3': 0,
#    'perk2': 8138,
#    'perk2Var1': 18,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8105,
#    'perk3Var1': 13,
#    'perk3Var2': 5,
#    'perk3Var3': 0,
#    'perk4': 8234,
#    'perk4Var1': 14338,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8232,
#    'perk5Var1': 4,
#    'perk5Var2': 40,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8100,
#    'perkSubStyle': 8200,
#    'statPerk0': 5008,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 4,
#    'creepsPerMinDeltas': {'10-20': 0.8,
#     '0-10': 1.2,
#     '30-end': 2.6,
#     '20-30': 0.8},
#    'xpPerMinDeltas': {'10-20': 391.29999999999995,
#     '0-10': 307.4,
#     '30-end': 648.8,
#     '20-30': 539.7},
#    'goldPerMinDeltas': {'10-20': 331.8,
#     '0-10': 261.8,
#     '30-end': 421,
#     '20-30': 382.4},
#    'csDiffPerMinDeltas': {'10-20': -0.09999999999999998,
#     '0-10': 0.7,
#     '30-end': 1.2000000000000002,
#     '20-30': -0.6},
#    'xpDiffPerMinDeltas': {'10-20': -1.200000000000017,
#     '0-10': 10.299999999999997,
#     '30-end': 21.199999999999932,
#     '20-30': 105.19999999999999},
#    'damageTakenPerMinDeltas': {'10-20': 675.8,
#     '0-10': 507,
#     '30-end': 1216.8,
#     '20-30': 1218.3000000000002},
#    'damageTakenDiffPerMinDeltas': {'10-20': -83,
#     '0-10': -100.00000000000003,
#     '30-end': -60.40000000000009,
#     '20-30': -161.0999999999999},
#    'role': 'NONE',
#    'lane': 'JUNGLE'}},
#  {'_id': ObjectId('60f661fab831580f0b9132fa'),
#   'participantId': 4,
#   'teamId': 100,
#   'championId': 78,
#   'spell1Id': 4,
#   'spell2Id': 11,
#   'stats': {'participantId': 4,
#    'win': True,
#    'item0': 6632,
#    'item1': 3742,
#    'item2': 1029,
#    'item3': 3075,
#    'item4': 3047,
#    'item5': 1029,
#    'item6': 3364,
#    'kills': 3,
#    'deaths': 2,
#    'assists': 17,
#    'largestKillingSpree': 2,
#    'largestMultiKill': 1,
#    'killingSprees': 1,
#    'longestTimeSpentLiving': 624,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 132627,
#    'magicDamageDealt': 12286,
#    'physicalDamageDealt': 95540,
#    'trueDamageDealt': 24801,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 16043,
#    'magicDamageDealtToChampions': 2135,
#    'physicalDamageDealtToChampions': 12252,
#    'trueDamageDealtToChampions': 1654,
#    'totalHeal': 15186,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 34505,
#    'damageDealtToObjectives': 35765,
#    'damageDealtToTurrets': 1171,
#    'visionScore': 27,
#    'timeCCingOthers': 35,
#    'totalDamageTaken': 30340,
#    'magicalDamageTaken': 5159,
#    'physicalDamageTaken': 21772,
#    'trueDamageTaken': 3408,
#    'goldEarned': 12019,
#    'goldSpent': 11325,
#    'turretKills': 1,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 43,
#    'neutralMinionsKilled': 108,
#    'neutralMinionsKilledTeamJungle': 52,
#    'neutralMinionsKilledEnemyJungle': 4,
#    'totalTimeCrowdControlDealt': 497,
#    'champLevel': 16,
#    'visionWardsBoughtInGame': 3,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 5,
#    'wardsKilled': 1,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': True,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': True,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8128,
#    'perk0Var1': 735,
#    'perk0Var2': 16,
#    'perk0Var3': 0,
#    'perk1': 8126,
#    'perk1Var1': 578,
#    'perk1Var2': 0,
#    'perk1Var3': 0,
#    'perk2': 8138,
#    'perk2Var1': 18,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8105,
#    'perk3Var1': 13,
#    'perk3Var2': 5,
#    'perk3Var3': 0,
#    'perk4': 8234,
#    'perk4Var1': 14214,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8232,
#    'perk5Var1': 6,
#    'perk5Var2': 50,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8100,
#    'perkSubStyle': 8200,
#    'statPerk0': 5008,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 4,
#    'creepsPerMinDeltas': {'10-20': 1.1, '0-10': 0.8, '20-30': 2},
#    'xpPerMinDeltas': {'10-20': 516.2, '0-10': 333.6, '20-30': 606},
#    'goldPerMinDeltas': {'10-20': 377.1,
#     '0-10': 313.9,
#     '20-30': 390.29999999999995},
#    'csDiffPerMinDeltas': {'10-20': -0.9, '0-10': 0.5, '20-30': -2},
#    'xpDiffPerMinDeltas': {'10-20': -30.30000000000001,
#     '0-10': 59.5,
#     '20-30': -148.5},
#    'damageTakenPerMinDeltas': {'10-20': 992.7,
#     '0-10': 466.79999999999995,
#     '20-30': 1420.5},
#    'damageTakenDiffPerMinDeltas': {'10-20': 451.6,
#     '0-10': -144.79999999999998,
#     '20-30': 657.6999999999999},
#    'role': 'NONE',
#    'lane': 'JUNGLE'}},
#  {'_id': ObjectId('60f661fab831580f0b9132fe'),
#   'participantId': 3,
#   'teamId': 100,
#   'championId': 78,
#   'spell1Id': 4,
#   'spell2Id': 11,
#   'stats': {'participantId': 3,
#    'win': True,
#    'item0': 6632,
#    'item1': 2031,
#    'item2': 3111,
#    'item3': 4401,
#    'item4': 3742,
#    'item5': 1029,
#    'item6': 3364,
#    'kills': 9,
#    'deaths': 2,
#    'assists': 17,
#    'largestKillingSpree': 4,
#    'largestMultiKill': 2,
#    'killingSprees': 3,
#    'longestTimeSpentLiving': 558,
#    'doubleKills': 1,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 130907,
#    'magicDamageDealt': 9953,
#    'physicalDamageDealt': 101839,
#    'trueDamageDealt': 19114,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 21733,
#    'magicDamageDealtToChampions': 1613,
#    'physicalDamageDealtToChampions': 18013,
#    'trueDamageDealtToChampions': 2106,
#    'totalHeal': 11239,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 28034,
#    'damageDealtToObjectives': 34790,
#    'damageDealtToTurrets': 1220,
#    'visionScore': 31,
#    'timeCCingOthers': 38,
#    'totalDamageTaken': 25811,
#    'magicalDamageTaken': 6970,
#    'physicalDamageTaken': 17586,
#    'trueDamageTaken': 1254,
#    'goldEarned': 12101,
#    'goldSpent': 11075,
#    'turretKills': 1,
#    'inhibitorKills': 1,
#    'totalMinionsKilled': 28,
#    'neutralMinionsKilled': 114,
#    'neutralMinionsKilledTeamJungle': 55,
#    'neutralMinionsKilledEnemyJungle': 11,
#    'totalTimeCrowdControlDealt': 519,
#    'champLevel': 15,
#    'visionWardsBoughtInGame': 1,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 3,
#    'wardsKilled': 7,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': True,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': True,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 1,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8128,
#    'perk0Var1': 1322,
#    'perk0Var2': 21,
#    'perk0Var3': 0,
#    'perk1': 8126,
#    'perk1Var1': 817,
#    'perk1Var2': 0,
#    'perk1Var3': 0,
#    'perk2': 8138,
#    'perk2Var1': 18,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8105,
#    'perk3Var1': 13,
#    'perk3Var2': 5,
#    'perk3Var3': 0,
#    'perk4': 8234,
#    'perk4Var1': 11147,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8232,
#    'perk5Var1': 6,
#    'perk5Var2': 10,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8100,
#    'perkSubStyle': 8200,
#    'statPerk0': 5008,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 3,
#    'creepsPerMinDeltas': {'10-20': 1.4, '0-10': 0.1},
#    'xpPerMinDeltas': {'10-20': 574.5, '0-10': 304.4},
#    'goldPerMinDeltas': {'10-20': 404.5, '0-10': 305.79999999999995},
#    'csDiffPerMinDeltas': {'10-20': 0.30000000000000004, '0-10': -0.2},
#    'xpDiffPerMinDeltas': {'10-20': 108.70000000000002, '0-10': 1},
#    'damageTakenPerMinDeltas': {'10-20': 1050.4, '0-10': 572.2},
#    'damageTakenDiffPerMinDeltas': {'10-20': -318.1, '0-10': -368.4},
#    'role': 'NONE',
#    'lane': 'JUNGLE'}},
#  {'_id': ObjectId('60f661fab831580f0b9132ff'),
#   'participantId': 6,
#   'teamId': 200,
#   'championId': 78,
#   'spell1Id': 4,
#   'spell2Id': 11,
#   'stats': {'participantId': 6,
#    'win': True,
#    'item0': 6632,
#    'item1': 2031,
#    'item2': 3066,
#    'item3': 3075,
#    'item4': 3047,
#    'item5': 0,
#    'item6': 3364,
#    'kills': 6,
#    'deaths': 0,
#    'assists': 9,
#    'largestKillingSpree': 6,
#    'largestMultiKill': 2,
#    'killingSprees': 1,
#    'longestTimeSpentLiving': 0,
#    'doubleKills': 1,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 172352,
#    'magicDamageDealt': 15919,
#    'physicalDamageDealt': 126318,
#    'trueDamageDealt': 30114,
#    'largestCriticalStrike': 15,
#    'totalDamageDealtToChampions': 9941,
#    'magicDamageDealtToChampions': 1624,
#    'physicalDamageDealtToChampions': 7007,
#    'trueDamageDealtToChampions': 1309,
#    'totalHeal': 12108,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 29023,
#    'damageDealtToObjectives': 46690,
#    'damageDealtToTurrets': 1738,
#    'visionScore': 23,
#    'timeCCingOthers': 19,
#    'totalDamageTaken': 22257,
#    'magicalDamageTaken': 4335,
#    'physicalDamageTaken': 17222,
#    'trueDamageTaken': 700,
#    'goldEarned': 11417,
#    'goldSpent': 8550,
#    'turretKills': 1,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 20,
#    'neutralMinionsKilled': 128,
#    'neutralMinionsKilledTeamJungle': 79,
#    'neutralMinionsKilledEnemyJungle': 0,
#    'totalTimeCrowdControlDealt': 590,
#    'champLevel': 15,
#    'visionWardsBoughtInGame': 2,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 5,
#    'wardsKilled': 2,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 1,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8128,
#    'perk0Var1': 537,
#    'perk0Var2': 12,
#    'perk0Var3': 0,
#    'perk1': 8126,
#    'perk1Var1': 352,
#    'perk1Var2': 0,
#    'perk1Var3': 0,
#    'perk2': 8138,
#    'perk2Var1': 18,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8105,
#    'perk3Var1': 13,
#    'perk3Var2': 5,
#    'perk3Var3': 0,
#    'perk4': 8234,
#    'perk4Var1': 8912,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8232,
#    'perk5Var1': 7,
#    'perk5Var2': 0,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8100,
#    'perkSubStyle': 8200,
#    'statPerk0': 5008,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 6,
#    'creepsPerMinDeltas': {'10-20': 0.1, '0-10': 0.1},
#    'xpPerMinDeltas': {'10-20': 450.7, '0-10': 353.79999999999995},
#    'goldPerMinDeltas': {'10-20': 398.6, '0-10': 291.79999999999995},
#    'csDiffPerMinDeltas': {'10-20': -1, '0-10': -0.8},
#    'xpDiffPerMinDeltas': {'10-20': 44.19999999999999,
#     '0-10': 15.999999999999972},
#    'damageTakenPerMinDeltas': {'10-20': 855.9000000000001, '0-10': 564.7},
#    'damageTakenDiffPerMinDeltas': {'10-20': 238.40000000000003,
#     '0-10': 41.400000000000006},
#    'role': 'NONE',
#    'lane': 'JUNGLE'}},
#  {'_id': ObjectId('60f661fab831580f0b91330f'),
#   'participantId': 4,
#   'teamId': 100,
#   'championId': 78,
#   'spell1Id': 4,
#   'spell2Id': 11,
#   'stats': {'participantId': 4,
#    'win': True,
#    'item0': 6632,
#    'item1': 4401,
#    'item2': 1011,
#    'item3': 3047,
#    'item4': 3742,
#    'item5': 1057,
#    'item6': 3364,
#    'kills': 5,
#    'deaths': 9,
#    'assists': 20,
#    'largestKillingSpree': 4,
#    'largestMultiKill': 2,
#    'killingSprees': 1,
#    'longestTimeSpentLiving': 568,
#    'doubleKills': 1,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 155349,
#    'magicDamageDealt': 14230,
#    'physicalDamageDealt': 125201,
#    'trueDamageDealt': 15918,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 22617,
#    'magicDamageDealtToChampions': 2653,
#    'physicalDamageDealtToChampions': 17424,
#    'trueDamageDealtToChampions': 2540,
#    'totalHeal': 13180,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 54293,
#    'damageDealtToObjectives': 27513,
#    'damageDealtToTurrets': 2296,
#    'visionScore': 30,
#    'timeCCingOthers': 47,
#    'totalDamageTaken': 42200,
#    'magicalDamageTaken': 18058,
#    'physicalDamageTaken': 22455,
#    'trueDamageTaken': 1685,
#    'goldEarned': 13442,
#    'goldSpent': 12650,
#    'turretKills': 0,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 35,
#    'neutralMinionsKilled': 121,
#    'neutralMinionsKilledTeamJungle': 76,
#    'neutralMinionsKilledEnemyJungle': 5,
#    'totalTimeCrowdControlDealt': 663,
#    'champLevel': 18,
#    'visionWardsBoughtInGame': 2,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 5,
#    'wardsKilled': 5,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': True,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8128,
#    'perk0Var1': 1144,
#    'perk0Var2': 22,
#    'perk0Var3': 0,
#    'perk1': 8126,
#    'perk1Var1': 1173,
#    'perk1Var2': 0,
#    'perk1Var3': 0,
#    'perk2': 8138,
#    'perk2Var1': 18,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8105,
#    'perk3Var1': 13,
#    'perk3Var2': 5,
#    'perk3Var3': 0,
#    'perk4': 8234,
#    'perk4Var1': 16652,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8232,
#    'perk5Var1': 7,
#    'perk5Var2': 20,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8100,
#    'perkSubStyle': 8200,
#    'statPerk0': 5008,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 4,
#    'creepsPerMinDeltas': {'10-20': 0.30000000000000004,
#     '0-10': 0.8,
#     '30-end': 1.4,
#     '20-30': 1},
#    'xpPerMinDeltas': {'10-20': 415.6,
#     '0-10': 317,
#     '30-end': 804.1,
#     '20-30': 463.5},
#    'goldPerMinDeltas': {'10-20': 282.9,
#     '0-10': 248.3,
#     '30-end': 434.29999999999995,
#     '20-30': 313.4},
#    'csDiffPerMinDeltas': {'10-20': 0,
#     '0-10': -0.7000000000000001,
#     '30-end': 0.9,
#     '20-30': -0.19999999999999996},
#    'xpDiffPerMinDeltas': {'10-20': 51.400000000000006,
#     '0-10': -44.900000000000006,
#     '30-end': 669.1,
#     '20-30': -96.09999999999997},
#    'damageTakenPerMinDeltas': {'10-20': 856,
#     '0-10': 527.6,
#     '30-end': 1317.8000000000002,
#     '20-30': 1207.5},
#    'damageTakenDiffPerMinDeltas': {'10-20': -45,
#     '0-10': -78.29999999999995,
#     '30-end': 516.6,
#     '20-30': -375.80000000000007},
#    'role': 'NONE',
#    'lane': 'JUNGLE'}},
#  {'_id': ObjectId('60f661fab831580f0b913310'),
#   'participantId': 2,
#   'teamId': 100,
#   'championId': 78,
#   'spell1Id': 4,
#   'spell2Id': 11,
#   'stats': {'participantId': 2,
#    'win': True,
#    'item0': 3111,
#    'item1': 2031,
#    'item2': 6632,
#    'item3': 4401,
#    'item4': 3066,
#    'item5': 0,
#    'item6': 3364,
#    'kills': 2,
#    'deaths': 5,
#    'assists': 16,
#    'largestKillingSpree': 2,
#    'largestMultiKill': 1,
#    'killingSprees': 1,
#    'longestTimeSpentLiving': 633,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 107933,
#    'magicDamageDealt': 9876,
#    'physicalDamageDealt': 91033,
#    'trueDamageDealt': 7024,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 9323,
#    'magicDamageDealtToChampions': 907,
#    'physicalDamageDealtToChampions': 7213,
#    'trueDamageDealtToChampions': 1202,
#    'totalHeal': 8912,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 22179,
#    'damageDealtToObjectives': 13088,
#    'damageDealtToTurrets': 1480,
#    'visionScore': 31,
#    'timeCCingOthers': 24,
#    'totalDamageTaken': 24827,
#    'magicalDamageTaken': 12218,
#    'physicalDamageTaken': 11871,
#    'trueDamageTaken': 736,
#    'goldEarned': 9623,
#    'goldSpent': 8750,
#    'turretKills': 1,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 29,
#    'neutralMinionsKilled': 107,
#    'neutralMinionsKilledTeamJungle': 76,
#    'neutralMinionsKilledEnemyJungle': 8,
#    'totalTimeCrowdControlDealt': 526,
#    'champLevel': 14,
#    'visionWardsBoughtInGame': 2,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 4,
#    'wardsKilled': 9,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8128,
#    'perk0Var1': 382,
#    'perk0Var2': 10,
#    'perk0Var3': 0,
#    'perk1': 8126,
#    'perk1Var1': 439,
#    'perk1Var2': 0,
#    'perk1Var3': 0,
#    'perk2': 8138,
#    'perk2Var1': 18,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8105,
#    'perk3Var1': 13,
#    'perk3Var2': 5,
#    'perk3Var3': 0,
#    'perk4': 8234,
#    'perk4Var1': 10098,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8232,
#    'perk5Var1': 4,
#    'perk5Var2': 20,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8100,
#    'perkSubStyle': 8200,
#    'statPerk0': 5008,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 2,
#    'creepsPerMinDeltas': {'10-20': 0.6, '0-10': 0.3},
#    'xpPerMinDeltas': {'10-20': 404.8, '0-10': 300.2},
#    'goldPerMinDeltas': {'10-20': 354.9, '0-10': 221.39999999999998},
#    'csDiffPerMinDeltas': {'10-20': 0.5, '0-10': 0.3},
#    'xpDiffPerMinDeltas': {'10-20': 128.1, '0-10': -54.2},
#    'damageTakenPerMinDeltas': {'10-20': 885.3, '0-10': 538.5},
#    'damageTakenDiffPerMinDeltas': {'10-20': -83, '0-10': -57.30000000000001},
#    'role': 'NONE',
#    'lane': 'JUNGLE'}},
#  {'_id': ObjectId('60f661fab831580f0b91331c'),
#   'participantId': 10,
#   'teamId': 200,
#   'championId': 78,
#   'spell1Id': 4,
#   'spell2Id': 11,
#   'stats': {'participantId': 10,
#    'win': True,
#    'item0': 6632,
#    'item1': 2031,
#    'item2': 3047,
#    'item3': 3066,
#    'item4': 1028,
#    'item5': 1029,
#    'item6': 3364,
#    'kills': 6,
#    'deaths': 2,
#    'assists': 6,
#    'largestKillingSpree': 4,
#    'largestMultiKill': 1,
#    'killingSprees': 1,
#    'longestTimeSpentLiving': 713,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 73512,
#    'magicDamageDealt': 7078,
#    'physicalDamageDealt': 57736,
#    'trueDamageDealt': 8696,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 6173,
#    'magicDamageDealtToChampions': 374,
#    'physicalDamageDealtToChampions': 5213,
#    'trueDamageDealtToChampions': 585,
#    'totalHeal': 5567,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 12174,
#    'damageDealtToObjectives': 16243,
#    'damageDealtToTurrets': 2523,
#    'visionScore': 17,
#    'timeCCingOthers': 17,
#    'totalDamageTaken': 12961,
#    'magicalDamageTaken': 912,
#    'physicalDamageTaken': 11640,
#    'trueDamageTaken': 408,
#    'goldEarned': 7992,
#    'goldSpent': 6475,
#    'turretKills': 3,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 9,
#    'neutralMinionsKilled': 80,
#    'neutralMinionsKilledTeamJungle': 44,
#    'neutralMinionsKilledEnemyJungle': 5,
#    'totalTimeCrowdControlDealt': 346,
#    'champLevel': 11,
#    'visionWardsBoughtInGame': 1,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 4,
#    'wardsKilled': 0,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': True,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8128,
#    'perk0Var1': 380,
#    'perk0Var2': 10,
#    'perk0Var3': 0,
#    'perk1': 8126,
#    'perk1Var1': 245,
#    'perk1Var2': 0,
#    'perk1Var3': 0,
#    'perk2': 8138,
#    'perk2Var1': 18,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8105,
#    'perk3Var1': 13,
#    'perk3Var2': 5,
#    'perk3Var3': 0,
#    'perk4': 8234,
#    'perk4Var1': 5202,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8232,
#    'perk5Var1': 3,
#    'perk5Var2': 10,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8100,
#    'perkSubStyle': 8200,
#    'statPerk0': 5005,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 10,
#    'creepsPerMinDeltas': {'0-10': 0},
#    'xpPerMinDeltas': {'0-10': 269.7},
#    'goldPerMinDeltas': {'0-10': 252.2},
#    'csDiffPerMinDeltas': {'0-10': 1.6399999999999995},
#    'xpDiffPerMinDeltas': {'0-10': 95.60000000000004},
#    'damageTakenPerMinDeltas': {'0-10': 529.2},
#    'damageTakenDiffPerMinDeltas': {'0-10': -102.77999999999997},
#    'role': 'DUO_SUPPORT',
#    'lane': 'NONE'}},
#  {'_id': ObjectId('60f661fab831580f0b91331d'),
#   'participantId': 3,
#   'teamId': 100,
#   'championId': 78,
#   'spell1Id': 4,
#   'spell2Id': 11,
#   'stats': {'participantId': 3,
#    'win': True,
#    'item0': 6632,
#    'item1': 1031,
#    'item2': 2055,
#    'item3': 3047,
#    'item4': 3066,
#    'item5': 1028,
#    'item6': 3364,
#    'kills': 7,
#    'deaths': 3,
#    'assists': 7,
#    'largestKillingSpree': 5,
#    'largestMultiKill': 1,
#    'killingSprees': 1,
#    'longestTimeSpentLiving': 464,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 74259,
#    'magicDamageDealt': 7745,
#    'physicalDamageDealt': 53310,
#    'trueDamageDealt': 13203,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 9779,
#    'magicDamageDealtToChampions': 1022,
#    'physicalDamageDealtToChampions': 7947,
#    'trueDamageDealtToChampions': 809,
#    'totalHeal': 4489,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 12310,
#    'damageDealtToObjectives': 18169,
#    'damageDealtToTurrets': 0,
#    'visionScore': 17,
#    'timeCCingOthers': 26,
#    'totalDamageTaken': 12841,
#    'magicalDamageTaken': 2798,
#    'physicalDamageTaken': 9507,
#    'trueDamageTaken': 536,
#    'goldEarned': 7195,
#    'goldSpent': 7125,
#    'turretKills': 0,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 1,
#    'neutralMinionsKilled': 68,
#    'neutralMinionsKilledTeamJungle': 48,
#    'neutralMinionsKilledEnemyJungle': 4,
#    'totalTimeCrowdControlDealt': 419,
#    'champLevel': 10,
#    'visionWardsBoughtInGame': 3,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 4,
#    'wardsKilled': 1,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8128,
#    'perk0Var1': 435,
#    'perk0Var2': 11,
#    'perk0Var3': 0,
#    'perk1': 8126,
#    'perk1Var1': 361,
#    'perk1Var2': 0,
#    'perk1Var3': 0,
#    'perk2': 8138,
#    'perk2Var1': 18,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8105,
#    'perk3Var1': 13,
#    'perk3Var2': 5,
#    'perk3Var3': 0,
#    'perk4': 8234,
#    'perk4Var1': 6022,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8232,
#    'perk5Var1': 6,
#    'perk5Var2': 20,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8100,
#    'perkSubStyle': 8200,
#    'statPerk0': 5008,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 3,
#    'creepsPerMinDeltas': {'10-20': 0.1, '0-10': 0},
#    'xpPerMinDeltas': {'10-20': 471.4, '0-10': 239.3},
#    'goldPerMinDeltas': {'10-20': 435.79999999999995, '0-10': 227.4},
#    'csDiffPerMinDeltas': {'10-20': -0.9, '0-10': 0},
#    'xpDiffPerMinDeltas': {'10-20': 133.7, '0-10': -32.39999999999998},
#    'damageTakenPerMinDeltas': {'10-20': 734.3, '0-10': 549.8},
#    'damageTakenDiffPerMinDeltas': {'10-20': -180.70000000000005,
#     '0-10': -197.1},
#    'role': 'NONE',
#    'lane': 'JUNGLE'}},
#  {'_id': ObjectId('60f661fab831580f0b91331e'),
#   'participantId': 7,
#   'teamId': 200,
#   'championId': 78,
#   'spell1Id': 4,
#   'spell2Id': 11,
#   'stats': {'participantId': 7,
#    'win': True,
#    'item0': 6632,
#    'item1': 2031,
#    'item2': 3047,
#    'item3': 3066,
#    'item4': 0,
#    'item5': 0,
#    'item6': 3364,
#    'kills': 6,
#    'deaths': 0,
#    'assists': 2,
#    'largestKillingSpree': 6,
#    'largestMultiKill': 1,
#    'killingSprees': 1,
#    'longestTimeSpentLiving': 0,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 54076,
#    'magicDamageDealt': 5352,
#    'physicalDamageDealt': 39960,
#    'trueDamageDealt': 8762,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 5476,
#    'magicDamageDealtToChampions': 410,
#    'physicalDamageDealtToChampions': 4420,
#    'trueDamageDealtToChampions': 644,
#    'totalHeal': 4369,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 7806,
#    'damageDealtToObjectives': 15115,
#    'damageDealtToTurrets': 383,
#    'visionScore': 16,
#    'timeCCingOthers': 14,
#    'totalDamageTaken': 9820,
#    'magicalDamageTaken': 2931,
#    'physicalDamageTaken': 6856,
#    'trueDamageTaken': 32,
#    'goldEarned': 6491,
#    'goldSpent': 5775,
#    'turretKills': 1,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 12,
#    'neutralMinionsKilled': 68,
#    'neutralMinionsKilledTeamJungle': 40,
#    'neutralMinionsKilledEnemyJungle': 0,
#    'totalTimeCrowdControlDealt': 273,
#    'champLevel': 10,
#    'visionWardsBoughtInGame': 1,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 2,
#    'wardsKilled': 3,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8128,
#    'perk0Var1': 317,
#    'perk0Var2': 8,
#    'perk0Var3': 0,
#    'perk1': 8126,
#    'perk1Var1': 257,
#    'perk1Var2': 0,
#    'perk1Var3': 0,
#    'perk2': 8138,
#    'perk2Var1': 9,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8105,
#    'perk3Var1': 13,
#    'perk3Var2': 5,
#    'perk3Var3': 0,
#    'perk4': 8234,
#    'perk4Var1': 4246,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8232,
#    'perk5Var1': 4,
#    'perk5Var2': 50,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8100,
#    'perkSubStyle': 8200,
#    'statPerk0': 5008,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 7,
#    'creepsPerMinDeltas': {'0-10': 0.5},
#    'xpPerMinDeltas': {'0-10': 351.6},
#    'goldPerMinDeltas': {'0-10': 302},
#    'csDiffPerMinDeltas': {'0-10': 1.0000000000000002},
#    'xpDiffPerMinDeltas': {'0-10': 28},
#    'damageTakenPerMinDeltas': {'0-10': 599.3},
#    'damageTakenDiffPerMinDeltas': {'0-10': -80.48000000000008},
#    'role': 'DUO_SUPPORT',
#    'lane': 'NONE'}},
#  {'_id': ObjectId('60f661fab831580f0b91331f'),
#   'participantId': 3,
#   'teamId': 100,
#   'championId': 78,
#   'spell1Id': 4,
#   'spell2Id': 11,
#   'stats': {'participantId': 3,
#    'win': True,
#    'item0': 6632,
#    'item1': 2031,
#    'item2': 2055,
#    'item3': 3075,
#    'item4': 3066,
#    'item5': 3047,
#    'item6': 3364,
#    'kills': 2,
#    'deaths': 4,
#    'assists': 10,
#    'largestKillingSpree': 0,
#    'largestMultiKill': 1,
#    'killingSprees': 0,
#    'longestTimeSpentLiving': 887,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 101501,
#    'magicDamageDealt': 8529,
#    'physicalDamageDealt': 75024,
#    'trueDamageDealt': 17948,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 6926,
#    'magicDamageDealtToChampions': 894,
#    'physicalDamageDealtToChampions': 5477,
#    'trueDamageDealtToChampions': 553,
#    'totalHeal': 4559,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 18828,
#    'damageDealtToObjectives': 27335,
#    'damageDealtToTurrets': 1316,
#    'visionScore': 20,
#    'timeCCingOthers': 23,
#    'totalDamageTaken': 22738,
#    'magicalDamageTaken': 8723,
#    'physicalDamageTaken': 12296,
#    'trueDamageTaken': 1717,
#    'goldEarned': 9147,
#    'goldSpent': 8625,
#    'turretKills': 1,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 28,
#    'neutralMinionsKilled': 86,
#    'neutralMinionsKilledTeamJungle': 45,
#    'neutralMinionsKilledEnemyJungle': 10,
#    'totalTimeCrowdControlDealt': 499,
#    'champLevel': 13,
#    'visionWardsBoughtInGame': 3,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 4,
#    'wardsKilled': 4,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8128,
#    'perk0Var1': 476,
#    'perk0Var2': 11,
#    'perk0Var3': 0,
#    'perk1': 8126,
#    'perk1Var1': 466,
#    'perk1Var2': 0,
#    'perk1Var3': 0,
#    'perk2': 8138,
#    'perk2Var1': 18,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8105,
#    'perk3Var1': 13,
#    'perk3Var2': 5,
#    'perk3Var3': 0,
#    'perk4': 8234,
#    'perk4Var1': 7910,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8232,
#    'perk5Var1': 6,
#    'perk5Var2': 20,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8100,
#    'perkSubStyle': 8200,
#    'statPerk0': 5005,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 3,
#    'creepsPerMinDeltas': {'10-20': 2.2, '0-10': 0},
#    'xpPerMinDeltas': {'10-20': 527.9, '0-10': 272.1},
#    'goldPerMinDeltas': {'10-20': 378.9, '0-10': 238.3},
#    'csDiffPerMinDeltas': {'10-20': 0.9000000000000001, '0-10': -0.1},
#    'xpDiffPerMinDeltas': {'10-20': 38.30000000000001,
#     '0-10': -79.49999999999997},
#    'damageTakenPerMinDeltas': {'10-20': 643.2, '0-10': 495},
#    'damageTakenDiffPerMinDeltas': {'10-20': 19.299999999999955,
#     '0-10': -172.19999999999996},
#    'role': 'NONE',
#    'lane': 'JUNGLE'}},
#  {'_id': ObjectId('60f661fab831580f0b913320'),
#   'participantId': 9,
#   'teamId': 200,
#   'championId': 78,
#   'spell1Id': 4,
#   'spell2Id': 11,
#   'stats': {'participantId': 9,
#    'win': True,
#    'item0': 6632,
#    'item1': 3742,
#    'item2': 2055,
#    'item3': 4401,
#    'item4': 3111,
#    'item5': 1029,
#    'item6': 3364,
#    'kills': 11,
#    'deaths': 8,
#    'assists': 16,
#    'largestKillingSpree': 3,
#    'largestMultiKill': 2,
#    'killingSprees': 3,
#    'longestTimeSpentLiving': 449,
#    'doubleKills': 1,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 126709,
#    'magicDamageDealt': 11514,
#    'physicalDamageDealt': 104281,
#    'trueDamageDealt': 10912,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 14181,
#    'magicDamageDealtToChampions': 1072,
#    'physicalDamageDealtToChampions': 11634,
#    'trueDamageDealtToChampions': 1475,
#    'totalHeal': 8843,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 39082,
#    'damageDealtToObjectives': 26824,
#    'damageDealtToTurrets': 1704,
#    'visionScore': 38,
#    'timeCCingOthers': 27,
#    'totalDamageTaken': 32473,
#    'magicalDamageTaken': 13246,
#    'physicalDamageTaken': 17450,
#    'trueDamageTaken': 1777,
#    'goldEarned': 12668,
#    'goldSpent': 11375,
#    'turretKills': 0,
#    'inhibitorKills': 1,
#    'totalMinionsKilled': 11,
#    'neutralMinionsKilled': 120,
#    'neutralMinionsKilledTeamJungle': 75,
#    'neutralMinionsKilledEnemyJungle': 12,
#    'totalTimeCrowdControlDealt': 473,
#    'champLevel': 16,
#    'visionWardsBoughtInGame': 5,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 5,
#    'wardsKilled': 5,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
# ...
#    'totalDamageDealtToChampions': 6482,
#    'magicDamageDealtToChampions': 696,
#    'physicalDamageDealtToChampions': 5377,
#    'trueDamageDealtToChampions': 408,
#    'totalHeal': 9088,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 22470,
#    'damageDealtToObjectives': 11785,
#    'damageDealtToTurrets': 246,
#    'visionScore': 27,
#    'timeCCingOthers': 17,
#    'totalDamageTaken': 20756,
#    'magicalDamageTaken': 6721,
#    'physicalDamageTaken': 13533,
#    'trueDamageTaken': 500,
#    'goldEarned': 8733,
#    'goldSpent': 7875,
#    'turretKills': 1,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 12,
#    'neutralMinionsKilled': 134,
#    'neutralMinionsKilledTeamJungle': 90,
#    'neutralMinionsKilledEnemyJungle': 14,
#    'totalTimeCrowdControlDealt': 683,
#    'champLevel': 15,
#    'visionWardsBoughtInGame': 1,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 6,
#    'wardsKilled': 5,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8128,
#    'perk0Var1': 399,
#    'perk0Var2': 10,
#    'perk0Var3': 0,
#    'perk1': 8143,
#    'perk1Var1': 183,
#    'perk1Var2': 0,
#    'perk1Var3': 0,
#    'perk2': 8138,
#    'perk2Var1': 18,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8105,
#    'perk3Var1': 13,
#    'perk3Var2': 5,
#    'perk3Var3': 0,
#    'perk4': 8234,
#    'perk4Var1': 8980,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8232,
#    'perk5Var1': 5,
#    'perk5Var2': 50,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8100,
#    'perkSubStyle': 8200,
#    'statPerk0': 5005,
#    'statPerk1': 5008,
#    'statPerk2': 5003},
#   'timeline': {'participantId': 3,
#    'creepsPerMinDeltas': {'10-20': 0.6, '0-10': 0.1},
#    'xpPerMinDeltas': {'10-20': 485.3, '0-10': 284.4},
#    'goldPerMinDeltas': {'10-20': 322.2, '0-10': 209.8},
#    'csDiffPerMinDeltas': {'10-20': -1.5, '0-10': 0},
#    'xpDiffPerMinDeltas': {'10-20': -37.70000000000002,
#     '0-10': -0.10000000000002274},
#    'damageTakenPerMinDeltas': {'10-20': 672.7, '0-10': 525},
#    'damageTakenDiffPerMinDeltas': {'10-20': 5, '0-10': -71.6},
#    'role': 'NONE',
#    'lane': 'JUNGLE'}},
#  {'_id': ObjectId('60f661fab831580f0b913410'),
#   'participantId': 5,
#   'teamId': 100,
#   'championId': 78,
#   'spell1Id': 4,
#   'spell2Id': 11,
#   'stats': {'participantId': 5,
#    'win': True,
#    'item0': 6632,
#    'item1': 2031,
#    'item2': 3066,
#    'item3': 1028,
#    'item4': 3047,
#    'item5': 1031,
#    'item6': 3364,
#    'kills': 3,
#    'deaths': 3,
#    'assists': 7,
#    'largestKillingSpree': 2,
#    'largestMultiKill': 1,
#    'killingSprees': 1,
#    'longestTimeSpentLiving': 750,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 94112,
#    'magicDamageDealt': 8315,
#    'physicalDamageDealt': 78661,
#    'trueDamageDealt': 7136,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 7552,
#    'magicDamageDealtToChampions': 460,
#    'physicalDamageDealtToChampions': 6585,
#    'trueDamageDealtToChampions': 506,
#    'totalHeal': 7434,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 16790,
#    'damageDealtToObjectives': 12913,
#    'damageDealtToTurrets': 362,
#    'visionScore': 19,
#    'timeCCingOthers': 18,
#    'totalDamageTaken': 17074,
#    'magicalDamageTaken': 4877,
#    'physicalDamageTaken': 11783,
#    'trueDamageTaken': 414,
#    'goldEarned': 8251,
#    'goldSpent': 6975,
#    'turretKills': 1,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 18,
#    'neutralMinionsKilled': 105,
#    'neutralMinionsKilledTeamJungle': 70,
#    'neutralMinionsKilledEnemyJungle': 0,
#    'totalTimeCrowdControlDealt': 522,
#    'champLevel': 12,
#    'visionWardsBoughtInGame': 1,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 4,
#    'wardsKilled': 1,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8128,
#    'perk0Var1': 484,
#    'perk0Var2': 12,
#    'perk0Var3': 0,
#    'perk1': 8143,
#    'perk1Var1': 189,
#    'perk1Var2': 0,
#    'perk1Var3': 0,
#    'perk2': 8138,
#    'perk2Var1': 18,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8105,
#    'perk3Var1': 10,
#    'perk3Var2': 4,
#    'perk3Var3': 0,
#    'perk4': 8234,
#    'perk4Var1': 8152,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8232,
#    'perk5Var1': 4,
#    'perk5Var2': 40,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8100,
#    'perkSubStyle': 8200,
#    'statPerk0': 5005,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 5,
#    'creepsPerMinDeltas': {'10-20': 1.5999999999999999, '0-10': 0},
#    'xpPerMinDeltas': {'10-20': 436.7, '0-10': 337.8},
#    'goldPerMinDeltas': {'10-20': 367.9, '0-10': 246.5},
#    'csDiffPerMinDeltas': {'10-20': 0.9999999999999999, '0-10': -0.3},
#    'xpDiffPerMinDeltas': {'10-20': -84.80000000000004,
#     '0-10': 35.20000000000002},
#    'damageTakenPerMinDeltas': {'10-20': 999.5, '0-10': 507.1},
#    'damageTakenDiffPerMinDeltas': {'10-20': -244.3,
#     '0-10': -135.50000000000003},
#    'role': 'NONE',
#    'lane': 'JUNGLE'}},
#  {'_id': ObjectId('60f661fab831580f0b913414'),
#   'participantId': 10,
#   'teamId': 200,
#   'championId': 78,
#   'spell1Id': 4,
#   'spell2Id': 11,
#   'stats': {'participantId': 10,
#    'win': True,
#    'item0': 6632,
#    'item1': 2031,
#    'item2': 3075,
#    'item3': 0,
#    'item4': 3047,
#    'item5': 3742,
#    'item6': 3364,
#    'kills': 7,
#    'deaths': 4,
#    'assists': 11,
#    'largestKillingSpree': 4,
#    'largestMultiKill': 1,
#    'killingSprees': 2,
#    'longestTimeSpentLiving': 987,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 140151,
#    'magicDamageDealt': 15145,
#    'physicalDamageDealt': 117282,
#    'trueDamageDealt': 7723,
#    'largestCriticalStrike': 13,
#    'totalDamageDealtToChampions': 15254,
#    'magicDamageDealtToChampions': 1506,
#    'physicalDamageDealtToChampions': 12745,
#    'trueDamageDealtToChampions': 1003,
#    'totalHeal': 8478,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 31433,
#    'damageDealtToObjectives': 13027,
#    'damageDealtToTurrets': 2148,
#    'visionScore': 23,
#    'timeCCingOthers': 27,
#    'totalDamageTaken': 26101,
#    'magicalDamageTaken': 6646,
#    'physicalDamageTaken': 17515,
#    'trueDamageTaken': 1940,
#    'goldEarned': 11499,
#    'goldSpent': 10725,
#    'turretKills': 0,
#    'inhibitorKills': 1,
#    'totalMinionsKilled': 32,
#    'neutralMinionsKilled': 123,
#    'neutralMinionsKilledTeamJungle': 87,
#    'neutralMinionsKilledEnemyJungle': 5,
#    'totalTimeCrowdControlDealt': 697,
#    'champLevel': 16,
#    'visionWardsBoughtInGame': 3,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 4,
#    'wardsKilled': 1,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8128,
#    'perk0Var1': 952,
#    'perk0Var2': 17,
#    'perk0Var3': 0,
#    'perk1': 8143,
#    'perk1Var1': 419,
#    'perk1Var2': 0,
#    'perk1Var3': 0,
#    'perk2': 8138,
#    'perk2Var1': 18,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8105,
#    'perk3Var1': 13,
#    'perk3Var2': 5,
#    'perk3Var3': 0,
#    'perk4': 8234,
#    'perk4Var1': 12980,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8232,
#    'perk5Var1': 4,
#    'perk5Var2': 50,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8100,
#    'perkSubStyle': 8200,
#    'statPerk0': 5005,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 10,
#    'creepsPerMinDeltas': {'10-20': 0.5, '0-10': 1, '20-30': 1.5},
#    'xpPerMinDeltas': {'10-20': 500, '0-10': 326.2, '20-30': 572.4},
#    'goldPerMinDeltas': {'10-20': 396.2, '0-10': 306.1, '20-30': 362.9},
#    'csDiffPerMinDeltas': {'10-20': -0.5,
#     '0-10': -0.10000000000000003,
#     '20-30': -2.2},
#    'xpDiffPerMinDeltas': {'10-20': 4.399999999999977,
#     '0-10': -51.80000000000001,
#     '20-30': -48.39999999999998},
#    'damageTakenPerMinDeltas': {'10-20': 974.1, '0-10': 493.9, '20-30': 1104.7},
#    'damageTakenDiffPerMinDeltas': {'10-20': 202.2,
#     '0-10': -142.69999999999996,
#     '20-30': 86.30000000000007},
#    'role': 'NONE',
#    'lane': 'JUNGLE'}},
#  {'_id': ObjectId('60f661fab831580f0b913469'),
#   'participantId': 1,
#   'teamId': 100,
#   'championId': 78,
#   'spell1Id': 4,
#   'spell2Id': 11,
#   'stats': {'participantId': 1,
#    'win': True,
#    'item0': 3047,
#    'item1': 3143,
#    'item2': 3075,
#    'item3': 3742,
#    'item4': 6632,
#    'item5': 3066,
#    'item6': 3364,
#    'kills': 4,
#    'deaths': 7,
#    'assists': 16,
#    'largestKillingSpree': 0,
#    'largestMultiKill': 1,
#    'killingSprees': 0,
#    'longestTimeSpentLiving': 679,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 195693,
#    'magicDamageDealt': 20818,
#    'physicalDamageDealt': 164284,
#    'trueDamageDealt': 10590,
#    'largestCriticalStrike': 32,
#    'totalDamageDealtToChampions': 20953,
#    'magicDamageDealtToChampions': 2941,
#    'physicalDamageDealtToChampions': 16732,
#    'trueDamageDealtToChampions': 1280,
#    'totalHeal': 12964,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 58669,
#    'damageDealtToObjectives': 28707,
#    'damageDealtToTurrets': 2091,
#    'visionScore': 40,
#    'timeCCingOthers': 38,
#    'totalDamageTaken': 38029,
#    'magicalDamageTaken': 6401,
#    'physicalDamageTaken': 27046,
#    'trueDamageTaken': 4581,
#    'goldEarned': 14365,
#    'goldSpent': 14075,
#    'turretKills': 2,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 39,
#    'neutralMinionsKilled': 170,
#    'neutralMinionsKilledTeamJungle': 110,
#    'neutralMinionsKilledEnemyJungle': 9,
#    'totalTimeCrowdControlDealt': 882,
#    'champLevel': 17,
#    'visionWardsBoughtInGame': 1,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 4,
#    'wardsKilled': 10,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8128,
#    'perk0Var1': 984,
#    'perk0Var2': 18,
#    'perk0Var3': 0,
#    'perk1': 8143,
#    'perk1Var1': 523,
#    'perk1Var2': 0,
#    'perk1Var3': 0,
#    'perk2': 8138,
#    'perk2Var1': 18,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8105,
#    'perk3Var1': 13,
#    'perk3Var2': 5,
#    'perk3Var3': 0,
#    'perk4': 8234,
#    'perk4Var1': 19805,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8232,
#    'perk5Var1': 12,
#    'perk5Var2': 50,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8100,
#    'perkSubStyle': 8200,
#    'statPerk0': 5008,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 1,
#    'creepsPerMinDeltas': {'10-20': 0.4, '0-10': 0, '30-end': 1.4, '20-30': 1},
#    'xpPerMinDeltas': {'10-20': 470.4,
#     '0-10': 306.4,
#     '30-end': 423.8,
#     '20-30': 547.1},
#    'goldPerMinDeltas': {'10-20': 372,
#     '0-10': 250.1,
#     '30-end': 327.8,
#     '20-30': 328},
#    'csDiffPerMinDeltas': {'10-20': -0.5,
#     '0-10': -0.6,
#     '30-end': -0.19999999999999996,
#     '20-30': -1},
#    'xpDiffPerMinDeltas': {'10-20': 84.6,
#     '0-10': -78.60000000000002,
#     '30-end': -49.89999999999998,
#     '20-30': -85.69999999999996},
#    'damageTakenPerMinDeltas': {'10-20': 721.6999999999999,
#     '0-10': 409.4,
#     '30-end': 1181.5,
#     '20-30': 1095},
#    'damageTakenDiffPerMinDeltas': {'10-20': -213.9,
#     '0-10': -501.2,
#     '30-end': 381.2,
#     '20-30': -118.40000000000003},
#    'role': 'NONE',
#    'lane': 'JUNGLE'}},
#  {'_id': ObjectId('60f661fab831580f0b913474'),
#   'participantId': 8,
#   'teamId': 200,
#   'championId': 78,
#   'spell1Id': 4,
#   'spell2Id': 11,
#   'stats': {'participantId': 8,
#    'win': True,
#    'item0': 3047,
#    'item1': 2031,
#    'item2': 6632,
#    'item3': 1031,
#    'item4': 3066,
#    'item5': 1028,
#    'item6': 3364,
#    'kills': 2,
#    'deaths': 5,
#    'assists': 8,
#    'largestKillingSpree': 0,
#    'largestMultiKill': 1,
#    'killingSprees': 0,
#    'longestTimeSpentLiving': 532,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 109919,
#    'magicDamageDealt': 9262,
#    'physicalDamageDealt': 91072,
#    'trueDamageDealt': 9585,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 8919,
#    'magicDamageDealtToChampions': 597,
#    'physicalDamageDealtToChampions': 7482,
#    'trueDamageDealtToChampions': 839,
#    'totalHeal': 9228,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 23158,
#    'damageDealtToObjectives': 18019,
#    'damageDealtToTurrets': 973,
#    'visionScore': 17,
#    'timeCCingOthers': 23,
#    'totalDamageTaken': 22461,
#    'magicalDamageTaken': 3320,
#    'physicalDamageTaken': 18911,
#    'trueDamageTaken': 230,
#    'goldEarned': 8884,
#    'goldSpent': 6975,
#    'turretKills': 0,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 27,
#    'neutralMinionsKilled': 111,
#    'neutralMinionsKilledTeamJungle': 63,
#    'neutralMinionsKilledEnemyJungle': 11,
#    'totalTimeCrowdControlDealt': 519,
#    'champLevel': 13,
#    'visionWardsBoughtInGame': 1,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 3,
#    'wardsKilled': 4,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': True,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'perk0': 8128,
#    'perk0Var1': 424,
#    'perk0Var2': 11,
#    'perk0Var3': 0,
#    'perk1': 8126,
#    'perk1Var1': 490,
#    'perk1Var2': 0,
#    'perk1Var3': 0,
#    'perk2': 8138,
#    'perk2Var1': 18,
#    'perk2Var2': 0,
#    'perk2Var3': 0,
#    'perk3': 8105,
#    'perk3Var1': 13,
#    'perk3Var2': 5,
#    'perk3Var3': 0,
#    'perk4': 8234,
#    'perk4Var1': 9396,
#    'perk4Var2': 0,
#    'perk4Var3': 0,
#    'perk5': 8232,
#    'perk5Var1': 6,
#    'perk5Var2': 20,
#    'perk5Var3': 0,
#    'perkPrimaryStyle': 8100,
#    'perkSubStyle': 8200,
#    'statPerk0': 5008,
#    'statPerk1': 5008,
#    'statPerk2': 5002},
#   'timeline': {'participantId': 8,
#    'creepsPerMinDeltas': {'10-20': 0.6000000000000001,
#     '0-10': 0.6000000000000001},
#    'xpPerMinDeltas': {'10-20': 300.20000000000005, '0-10': 323},
#    'goldPerMinDeltas': {'10-20': 301.20000000000005, '0-10': 238.8},
#    'csDiffPerMinDeltas': {'10-20': -0.8999999999999999,
#     '0-10': -0.8999999999999999},
#    'xpDiffPerMinDeltas': {'10-20': -220.49999999999997,
#     '0-10': -12.400000000000006},
#    'damageTakenPerMinDeltas': {'10-20': 905.1, '0-10': 761},
#    'damageTakenDiffPerMinDeltas': {'10-20': 217.39999999999998,
#     '0-10': 89.39999999999992},
#    'role': 'NONE',
#    'lane': 'JUNGLE'}}]

# %%
# d점멸 f점멸 승률비교

# %%
# 첫번째 용 먹었을 때 승률 비교

# %%
# 챔피언별 승률 비교

# %%
# 포지션별 승률비교

# %%
# 게임 시간 별 승률 비교

# %%
# 상위 플레이어 플레이 통계와 비교
